# %% [markdown]
# # StrassenNets: Deep Learning with a Multiplication Budget
#
# This notebook provides a step-by-step implementation to reproduce part of the experiments in *StrassenNets: Deep Learning with a Multiplication Budget* by Michael Tschannen, Aran Khanna, and Anima Anandkumar (http://bit.ly/2BJZj5a).
#
# #### Paper abstract
#
# A large fraction of the arithmetic operations required to evaluate deep neural networks (DNNs) are due to matrix multiplications, both in convolutional and fully connected layers. Matrix multiplications can be cast as $2$-layer sum-product (SP) networks (arithmetic circuits), disentangling multiplications and additions. We leverage this observation for end-to-end learning of low-cost (in terms of multiplications) approximations of linear operations in DNN layers. Specifically, we propose to replace matrix multiplication operations by sum-product networks, with widths corresponding to the budget of multiplications we want to allocate to each layer, and learning the edges of the SP networks from data. Experiments on CIFAR-10 and ImageNet show that this method applied to ResNet yields significantly higher accuracy than existing methods for a given multiplication budget, or leads to the same or higher accuracy compared to existing methods while using significantly fewer multiplications. Furthermore, our approach allows fine-grained control of the tradeoff between arithmetic complexity and accuracy of DNN models. Finally, we demonstrate that the proposed framework can rediscover Strassen's algorithm, i.e., it can learn to multiply $2 \times 2$ matrices using only $7$ multiplications instead of $8$.
#
#
# #### Learning fast matrix multiplications via sum-product networks
# $\renewcommand{\vec}{\mathrm{vec}}$Given square matrices $A, B \in \mathbb{R}^{n \times n}$, the product $C = A B$ can be represented as a $2$-layer sum-product (SP) network (or ``Strassen network'')
#
# $$
#     \label{eq:strnet}
#     \vec(C) = W_C [ (W_B \vec(B)) \odot (W_A \vec(A))] \qquad \qquad (1)
# $$
#
# where $W_A, W_B \in \mathbb{K}^{r \times n^2}$ and $W_C \in \mathbb{K}^{n^2 \times r}$, $\mathbb{K}:= \{-1,0,1\}$ are fixed, and $\odot$ denotes the element-wise product.
#
# <img src="files/spnetwork.png" alt="spnetwork" style="width: 400px;"/>
#
# 1. $A, B\in \mathbb{R}^{2 \times 2}$: Strassen's matrix multiplication algorithm (https://en.wikipedia.org/wiki/Strassen_algorithm) tells us ternary weights that satisfy (1) for $r=7$ (instead of $r = 8$).
# 2. General case $A \in \mathbb{R}^{k \times m}$, $B \in \mathbb{R}^{m \times n}$: $C = A B$ can be written in the form (1) if $r \geq nmk$.
# 3. If $A \in \mathbb{R}^{k \times m}$ is fixed and $B \in \mathbb{R}^{m \times n}$ concentrates on low-dimensional subspace of $\mathbb{R}^{k \times m}$: Can find $W_A, W_B$ s.t. (1) holds approximately even when $r \ll nmk$
#
# *Idea:* Leverage item 3 to learn low-cost (in terms of multiplications) approximate linear operations in neural network layers by associating $A$ with (pretrained) weights/filters and $B$ with corresponding activations/feature maps, and by learning $W_A$, $W_B$, $W_C$ end-to-end. Please see the paper for a more in-depth description of the method.
#
# In this notebook, we demonstrate this idea by compressing the 2D convolution layers of ResNet-20 trained on CIFAR-10.
#
# #### Outline of the notebook:
# 1. Implement the ternary quantization operator to learn ternary weights $W_B$ and $W_C$
# 2. Implement the SP 2D convolution layer (i.e. a Strassen network for 2D convolutions)
# 3. Implement residual blocks with SP layers and use these to construct a SP-ResNet-20
# 4. Define iterators and the training loop
# 5. Train the network
#
# #### Requirements
#
# The code is based on Apache MXNet 0.12 (http://mxnet.incubator.apache.org/install/index.html) and the gluon package.

# %% [markdown]
# ## 1. Implement the ternary quantization operator
#
# Following the tutorial from [1] to define custom gluon operators, we define an operator implementing the ternarization method proposed in [2]. Using the notation from [2], this method quantizes the entries of a given input tensor to values $\{-\alpha, 0, \alpha\}$ ($\alpha$ corresponds to `scale` below) based on a threshold $\Delta$ (corresponding to `thresh` below) on the full precision entries. $\alpha$ and $\Delta$ are determinined by approximately solving an optimization problem, see [2]. The operator will be used to quanzie $W_B$ and $W_C$ (the factor $\alpha$ can be absorbed into $\tilde a = W_A \vec(A)$ after training to ensure that the entries of $W_B$ and $W_C$ are in $\{-1,0,1\}$).
#
# [1] https://github.com/apache/incubator-mxnet/blob/master/docs/tutorials/gluon/customop.md
#
# [2] F. Li, B. Zhang, B. Liu, Ternary Weight Networks, 2016, https://arxiv.org/abs/1605.04711v2

# %%
import mxnet as mx
import numpy as np

# define the quantization operator
class TerQuant(mx.operator.CustomOp):
    # define forward pass as described in [1]
    def forward(self, is_train, req, in_data, out_data, aux):
        full_data = in_data[0]

        # compute $\Delta$ as in [1], Eq. (6)
        thresh = mx.nd.mean(mx.nd.abs(full_data), axis=()).asnumpy()[0] * 0.7

        # ternarize weights
        quant_data = mx.nd.greater(full_data, thresh*mx.nd.ones(full_data.shape, full_data.context))\
            - mx.nd.lesser(full_data, (-1.0)*thresh*mx.nd.ones(full_data.shape, full_data.context))

        # compute $\alpha$ as in [1], Eq. (5)
        scale = mx.nd.sum(mx.nd.multiply(full_data, quant_data), axis=()).asnumpy()[0]\
            / mx.nd.sum(mx.nd.abs(quant_data), axis=()).asnumpy()[0]

        # rescale ternary weights
        quant_data = scale * quant_data
        self.assign(out_data[0], req[0], quant_data)

    # define backward pass: simply pass on gradient from previous operation (derivative of the identity function)
    def backward(self, req, out_grad, in_data, out_data, in_grad, aux):
        self.assign(in_grad[0], req[0], out_grad[0])

# wrap the operator and provide functions to get information about input, output etc.
@mx.operator.register('ter_quant')
class TerQuantProp(mx.operator.CustomOpProp):
    def __init__(self):
        super(TerQuantProp, self).__init__(True)

    def list_arguments(self):
        return ['data']

    def list_outputs(self):
        return ['output']

    def infer_shape(self, in_shapes):
        data_shape = in_shapes[0]
        output_shape = data_shape
        return (data_shape,), (output_shape,), ()

    def create_operator(self, ctx, in_shapes, in_dtypes):
        return TerQuant()

# %% [markdown]
# ## 2. Implement the SP 2DConvLayer
# $\newcommand{\cin}{c_\mathrm{in}}\newcommand{\cout}{c_\mathrm{out}}$We are now ready to implement the SP 2D convolution layer (as a gluon `HybridBlock` object). Specifically, we compress the computation of $\cout \times p \times p$ output elements of the convolution from $\cin \times (p - 1 + k) \times (p - 1 + k)$ input elements by applying (see figure below)
#
# 1. a $p$-strided 2D convolution with a *ternary* filter of size $r \times \cin \times (p - 1 + k) \times (p - 1 + k)$ (corresponding to multiplication with $W_B$),
# 2. a channel-wise multiplication with an $r \times 1 \times 1$ *full-precision* filter $\tilde a = W_A \vec(A)$ (corresponding to the filters of the original convolution),
# 3. a $1/p$-strided transposed 2D convolution with a *ternary* filter of size $\cout \times r \times p \times p$ (corresponding to multiplication with $W_C$).
#
# <img src="files/sp2dconv.png" alt="spnetwork" style="width: 600px;"/>
#
# As we will pretrain the convolutions described in items 1 and 3 above with full-precision weights, we include a variable `mode` that determines whether quantization is active or not. Furthermore, we include the original convolution to selectively replace the SP convolutions with ordinary ones (not used in this notebook).

# %%
from mxnet import gluon, autograd
from mxnet.gluon.block import HybridBlock
from mxnet.base import numeric_types
from math import ceil

class SumProd2DConv(mx.gluon.HybridBlock):
    r"""
    nbr_mul : int
        Width of the sum-product network, corresponding to the number of multiplications r used to compute an
        $p_x$ x $p_y$ x channels activation element
    target_layer_shape:
        Shape of the filter to be replaced by the sum-product network
    target_layer_key:
        Name of the target layer in the original ResNet (to enable loading from a pretrained network)
    out_patch : int
        size ($p_x$, $p_y$) of the output patch for spatial compression
    kernel, stride, pad : specifics of the 2D convolution
    """
    
    def __init__(self, nbr_mul, target_layer_shape, target_layer_key, out_patch=(1,1), kernel=(3,3), stride=(1,1), pad=(1,1), prefix=None, **kwargs):
        # Use same prefix as parent layer for loading the shared paramters to be compressed
        super(SumProd2DConv, self).__init__(prefix=prefix, **kwargs)

        if isinstance(stride, numeric_types):
            stride = (stride,)*len(kernel)
        if isinstance(pad, numeric_types):
            pad = (pad,)*len(kernel)

        self._nbr_mul = nbr_mul
        # corresponds to $p$ in the description above
        self._out_patch = out_patch
        self._kernel = kernel
        self._stride = stride
        self._pad = pad

        # compute kernel shapes and stride for $W_B$
        self._sp_data_weight_kernel = ((self._out_patch[0]-1)*self._stride[0]+self._kernel[0], (self._out_patch[1]-1)*self._stride[1]+self._kernel[1])
        self._sp_data_weight_stride = (self._out_patch[0]*self._stride[0], self._out_patch[1]*self._stride[1])

        # filters for the original convolution
        self.filter_weights = self.params.get(target_layer_key, shape=target_layer_shape)

        # Assuming the default NCHW layout, determine shapes of $W_B$ and $W_C$
        filter_weights_shape = list(target_layer_shape)
        sp_data_weights_shape = filter_weights_shape.copy()
        sp_data_weights_shape[0] = nbr_mul
        sp_data_weights_shape[2] = self._sp_data_weight_kernel[0]
        sp_data_weights_shape[3] = self._sp_data_weight_kernel[1]
        sp_out_weights_shape = filter_weights_shape.copy()
        sp_out_weights_shape[0] = nbr_mul
        sp_out_weights_shape[1] = filter_weights_shape[0]
        sp_out_weights_shape[2] = self._out_patch[0]
        sp_out_weights_shape[3] = self._out_patch[1]

        ## SP network weights
        # $\tilde a = W_A \vec(A)$
        self.sp_in_weights = self.params.get('sp_in_weights', shape=(1,self._nbr_mul,1,1))
        # $W_B$
        self.sp_data_weights = self.params.get('sp_data_weights', shape=sp_data_weights_shape)
        # $W_C$
        self.sp_out_weights =  self.params.get('sp_out_weights', shape=sp_out_weights_shape)

        # SP network batchnorm parameters
        self.sp_batchnorm_gamma = self.params.get('sp_batchnorm_gamma', shape=(1,self._nbr_mul,1,1))
        self.sp_batchnorm_beta = self.params.get('sp_batchnorm_beta', shape=(1,self._nbr_mul,1,1))
        self.sp_batchnorm_running_mean = self.params.get('sp_batchnorm_running_mean', shape=(1,self._nbr_mul,1,1))
        self.sp_batchnorm_running_var = self.params.get('sp_batchnorm_running_var', shape=(1,self._nbr_mul,1,1))

        # mode: 1: original convolution; 2: SP network without ternary quantization; 3: SP network with ternary quantization
        self.sp_mode = self.params.get('sp_mode', shape=(1,), dtype=np.uint8)


    def forward(self, data):
        with data.context:
            mode = self.sp_mode.data().asnumpy()[0]
            filter_weights = self.filter_weights.data()

            if mode == 0:
                # perform original convolution
                conv_out = mx.nd.Convolution(data=data,
                                  weight=filter_weights,
                                  bias=None,
                                  no_bias=True,
                                  kernel=self._kernel,
                                  stride=self._stride,
                                  pad=self._pad,
                                  num_filter=filter_weights.shape[0])

                return conv_out
            else:
                sp_data_weights = self.sp_data_weights.data()
                sp_out_weights = self.sp_out_weights.data()

                # quantzie $W_B$ and $W_C$ if desired
                if mode == 2:
                    sp_data_weights = mx.nd.Custom(sp_data_weights, op_type='ter_quant')
                    sp_out_weights = mx.nd.Custom(sp_out_weights, op_type='ter_quant')

                pad_x = self._pad[0] + ceil((data.shape[2]%self._sp_data_weight_stride[0])/2)
                pad_y = self._pad[1] + ceil((data.shape[3]%self._sp_data_weight_stride[1])/2)

                # compute $W_B \vec(B)$
                sp_data_mul = mx.nd.Convolution(data=data,
                                  weight=sp_data_weights,
                                  bias=None,
                                  no_bias=True,
                                  kernel=self._sp_data_weight_kernel,
                                  stride=self._sp_data_weight_stride,
                                  pad=(pad_x, pad_y),
                                  num_filter = self._nbr_mul)

                # apply batchnorm to $W_B \vec(B)$
                sp_data_mul_norm = mx.nd.BatchNorm(data=sp_data_mul,
                                              gamma=self.sp_batchnorm_gamma.data(),
                                              beta=self.sp_batchnorm_beta.data(),
                                              moving_mean=self.sp_batchnorm_running_mean.data(),
                                              moving_var=self.sp_batchnorm_running_var.data(),
                                              fix_gamma=True)

                # apply non-negativity constraint to $\tilde a = W_A \vec(A)$
                with mx.autograd.pause():
                    self.sp_in_weights.set_data(mx.nd.clip(data=self.sp_in_weights.data(), a_min=0.0, a_max=100.0))
                
                # compute $(W_A \vec(A)) \odot (W_B \vec(B))$
                sp_mul = mx.nd.multiply(self.sp_in_weights.data(), sp_data_mul_norm)
                
                # compute $W_C[(W_A \vec(A)) \odot (W_B \vec(B))]$
                sp_out = mx.nd.Deconvolution(data = sp_mul,
                                  weight = sp_out_weights,
                                  bias = None,
                                  no_bias = True,
                                  kernel = self._out_patch,
                                  stride = self._out_patch,
                                  target_shape = (data.shape[2]//self._stride[0], data.shape[3]//self._stride[1]),
                                  num_filter = filter_weights.shape[0])

                return sp_out

# %% [markdown]
# ## 3. Implement the sum-product residual unit
#
# We continue by defining the residual unit as proposed in [3] using sum-product 2D convolutions. The code block below is adapted from [4] and looks lengthy, but there are only small modifications compared to [4]. Specifically, we replace ordinary 2D convolutions by sum-product 2D convolutions and add parameters for the sum-product convolutions.
#
# [3] K. He, X. Zhang, S. Ren, J. Sun, Deep Residual Learning for Image Recognition, 2016, http://arxiv.org/abs/1512.03385
#
# [4] https://github.com/apache/incubator-mxnet/blob/master/python/mxnet/gluon/model_zoo/vision/resnet.py

# %%
from mxnet.gluon import nn

class BasicBlockV1SumProd(HybridBlock):
    r"""
    Parameters
    ----------
    channels : int
        Number of output channels.
    stride : int
        Stride size.
    nbr_mul : int
        Width of the sum-product network, corresponding to the number of multiplications r used to compute an
        $p_x$ x $p_y$ x channels activation element
    out_patch : int
        size ($p_x$, $p_y$) of the output patch for spatial compression
    conv_idx : int
        index of the convolution, used for parameter names
    downsample : bool, default False
        Whether to downsample the input.
    in_channels : int, default 0
        Number of input channels. Default is 0, to infer from the graph.
    quant_down : bool
        Whether to quantize ResNet 1x1 convolution projection layers
    """
    def __init__(self, channels, stride, nbr_mul, out_patch=(1,1), conv_idx=0, downsample=False, in_channels=0, quant_down=True, **kwargs):
        super(BasicBlockV1SumProd, self).__init__(**kwargs)
        self.body = nn.HybridSequential(prefix='')

        prefix1 = 'conv%i_'%conv_idx
        # shape of the original convolution
        orig_shape1 = (channels, in_channels, 3, 3)
        # kernel of the original convolution
        kernel = (3,3)

        self.body.add(SumProd2DConv(nbr_mul=nbr_mul,
                                      target_layer_shape=orig_shape1,
                                      target_layer_key='weight',
                                      out_patch=out_patch,
                                      kernel=kernel,
                                      stride=stride,
                                      prefix=prefix1))

        self.body.add(nn.BatchNorm())
        self.body.add(nn.Activation('relu'))
        
        prefix2 = 'conv%i_'%(conv_idx+1)
        orig_shape2 = (channels, channels, 3, 3)

        self.body.add(SumProd2DConv(nbr_mul=nbr_mul,
                                      target_layer_shape=orig_shape2,
                                      target_layer_key='weight',
                                      out_patch=out_patch,
                                      kernel=kernel,
                                      stride=1,
                                      prefix=prefix2))

        self.body.add(nn.BatchNorm())
        
        if downsample:
            self.downsample = nn.HybridSequential(prefix='')

            # Quantize projection layer if required
            if quant_down:
                prefix_ds = 'conv%i_'%(conv_idx+2)
                orig_shape_ds = (channels, in_channels, 1, 1)

                self.downsample.add(SumProd2DConv(nbr_mul=nbr_mul,
                                              target_layer_shape=orig_shape_ds,
                                              target_layer_key='weight',
                                              out_patch=(1,1),
                                              kernel=(1,1),
                                              stride=stride,
                                              pad=(0,0),
                                              prefix=prefix_ds))
            else:
                self.downsample.add(nn.Conv2D(channels, kernel_size=1, strides=stride,
                                              use_bias=False, in_channels=in_channels))

            self.downsample.add(nn.BatchNorm())
        else:
            self.downsample = None

    def hybrid_forward(self, F, x):
        residual = x

        x = self.body(x)

        if self.downsample:
            residual = self.downsample(residual)

        x = F.Activation(residual+x, act_type='relu')

        return x

# %% [markdown]
# ## 4. Implement the sum-product ResNet
#
# Again, we modify the code to construct ResNet (as a gluon `HybridBlock` object) for various dephts from [4], replacing ordinary 2D convolutions by sum-product 2D convolutions, and the fully connected output layer by a sum-product network if desired. As before, we add in some parameters for the sum-product networks.

# %%
from mxnet.gluon.model_zoo.vision.resnet import _conv3x3

class ResNetV1SumProd(HybridBlock):
    r"""ResNet V1 model from
    `"Deep Residual Learning for Image Recognition"
    <http://arxiv.org/abs/1512.03385>`_ paper.

    Parameters
    ----------
    block : HybridBlock
        Class for the residual block. Options are BasicBlockV1, BottleneckV1.
    layers : list of int
        Numbers of layers in each block
    channels : list of int
        Numbers of channels in each block. Length should be one larger than layers list.
    nbr_mul : int
        Width of the sum-product network, corresponding to the number of multiplications r used to compute an
        $p_x$ x $p_y$ x channels activation element
    out_patch : int
        size ($p_x$, $p_y$) of the output patch for spatial compression
    classes : int, default 1000
        Number of classification classes.
    thumbnail : bool, default False
        Enable thumbnail.
    quant_down : bool
        Whether to quantize ResNet 1x1 convolution projection layers
    """
    def __init__(self, layers, channels, nbr_mul, out_patch, classes=1000, thumbnail=False, quant_down=True, prefix='resnetv10_', **kwargs):
        super(ResNetV1SumProd, self).__init__(prefix, **kwargs)
        
        with self.name_scope():
            self.features = nn.HybridSequential(prefix='')
            # Thumbnail determines the characteristics of the first layer. If thumbnail==True, 3x3 convolutions are used
            # and no pooling is performed (this setting is used for CIFAR). Otherwise, 7x7 filters with max-pooling are used.
            if thumbnail:
                # replace first layer with a sum-product layer if desired
                if nbr_mul[0] > 0:
                    orig_shape = (channels[0], 3, 3, 3)

                    self.features.add(SumProd2DConv(nbr_mul = nbr_mul[0],
                                                  target_layer_shape = orig_shape,
                                                  target_layer_key = 'weight',
                                                  kernel = (3, 3),
                                                  stride = (1, 1),
                                                  out_patch = out_patch[0],
                                                  prefix = 'conv0_'))
                else:
                    self.features.add(_conv3x3(channels[0], 1, 3))

            else:
                # replace first layer with a sum-product layer if desired
                if nbr_mul[0] > 0:
                    orig_shape = (channels[0], 3, 7, 7)

                    self.features.add(SumProd2DConv(nbr_mul = nbr_mul[0],
                                                  target_layer_shape = orig_shape,
                                                  target_layer_key = 'weight',
                                                  kernel = (7, 7),
                                                  stride = (2, 2),
                                                  pad = (3,3),
                                                  out_patch = out_patch[0],
                                                  prefix = 'conv0_'))
                else:
                    self.features.add(nn.Conv2D(channels[0], 7, 2, 3, use_bias=False,
                                                in_channels=3))
                self.features.add(nn.BatchNorm())
                self.features.add(nn.Activation('relu'))
                self.features.add(nn.MaxPool2D(3, 2, 1))

            for i, num_layer in enumerate(layers):
                stride = 1 if i == 0 else 2
                self.features.add(self._make_sumprod_layer(num_layer, channels[i+1], stride,
                                                   nbr_mul[i+1], out_patch[i+1], i+1, in_channels=channels[i], quant_down=quant_down))

            self.classifier = nn.HybridSequential(prefix='')
            self.classifier.add(nn.GlobalAvgPool2D())
            self.classifier.add(nn.Flatten())
            self.classifier.add(nn.Dense(classes, in_units=channels[-1]))

    # stack residual blocks as described in [2]
    def _make_sumprod_layer(self, layers, channels, stride, nbr_mul, out_patch, stage_index, in_channels=0, quant_down=True):
        layer = nn.HybridSequential(prefix='stage%d_'%stage_index)
        with layer.name_scope():
            layer.add(BasicBlockV1SumProd(channels, stride, nbr_mul, out_patch, 0, channels != in_channels, in_channels=in_channels, quant_down=quant_down, prefix=''))
            nbr_conv = 2 if channels == in_channels else 3
            for i in range(layers-1):
                layer.add(BasicBlockV1SumProd(channels, 1, nbr_mul, out_patch, nbr_conv, False, in_channels=channels, quant_down=quant_down, prefix=''))
                nbr_conv += 2
        return layer

    def hybrid_forward(self, F, x):
        x = self.features(x)
        x = self.classifier(x)

        return x

# %% [markdown]
# # 5. Training the network
#
# We are now ready to train and evaluate the SP-ResNet-20 on CIFAR-10 as described in the paper.
#
# We start by defining the SP-Resnet-20. The parameters below realize the configuration for $p=1$ and $r=c_\mathrm{out}$ in Table 1 (first row, first column) in the paper, and can be modified for other configurations. Furthermore, the context can be modified below (use `ctx = [mx.cpu(0)]` if you don't have a GPU available, or extend to a list of devices for parallel training).

# %%
# CIFAR-10 has 10 classes
classes = 10
# structure of ResNet-20
res_units = [3, 3, 3]
res_channels = [16, 16, 32, 64]
# choose the width of the sum-product convolution networks (i.e., $r$) to be equal to the number of output channels
# don't compress the last layer (encoded by nbr_mul=0)
nbr_mul = [16, 16, 32, 64, 0]
# don't do spatial compression (out. patch=1x1)
out_patch = [(1,1)]*4
# quantize ResNet 1x1 convolution projection layers
quant_down = True
# use 3x3 kernels for the first convolution layer, don't do pooling after the first convolution layer
thumbnail = True

# construct ResNet HybridBlock object
sp_resnet = ResNetV1SumProd(res_units, res_channels, nbr_mul, out_patch, classes, thumbnail, quant_down)

# define context
ctx = [mx.gpu(0)]

# %% [markdown]
# Next, we initialize the network parameters. As we first train all weights at full precision first, `sp_mode` is set to  1. `sp_in_weights` (corresponding to $\tilde a = W_A \mathrm{vec}(A)$) is initialized to 1s and Xavier initialization is used for `sp_data_weights` and `sp_out_weights` (corresponding to $W_B$ and $W_C$, respectively), and for the fully connected output layer. Furthermore, optimization is deactivated for the auxiliary batchnorm variables.

# %%
# helper function to filter and intialize paramters whose name contains a given substring
def initialize_by_key(net, key, init, context, force_reinit=False):
    for k, p in net.collect_params().items():
        if key in k:
            p.initialize(init=init, ctx=context, force_reinit=force_reinit)

# initialize SP networks
initialize_by_key(sp_resnet, 'sp_mode', mx.init.One(), ctx)
initialize_by_key(sp_resnet, 'sp_in_weights', mx.init.One(), ctx)
initialize_by_key(sp_resnet, 'sp_data_weights', mx.init.Xavier(magnitude=2), ctx)
initialize_by_key(sp_resnet, 'sp_out_weights', mx.init.Xavier(magnitude=2), ctx)

# intialize batchnorm parameters
initialize_by_key(sp_resnet, 'gamma', mx.init.One(), ctx)
initialize_by_key(sp_resnet, 'beta', mx.init.Zero(), ctx)
initialize_by_key(sp_resnet, 'running_mean', mx.init.Zero(), ctx)
initialize_by_key(sp_resnet, 'running_var', mx.init.Zero(), ctx)

# initialize fully connected layer
initialize_by_key(sp_resnet, 'dense0_weight', mx.init.Xavier(magnitude=2), ctx) #mx.init.Normal(1)
initialize_by_key(sp_resnet, 'dense0_bias', mx.init.Zero(), ctx)

# deactivate optimization for original convolutions as they are not used here
for k, p in sp_resnet.collect_params().items():
    if 'conv' in k and 'sp' not in k:
        p.initialize(init=mx.init.Xavier(magnitude=2), ctx=ctx)
        p.grad_req = 'null'

# deactivate optimization for batchnorm auxiliary variables
for k, p in sp_resnet.collect_params().items():
    if 'running_mean' in k or 'running_var' in k or 'sp_mode' in k:
        p.grad_req = 'null'

# %% [markdown]
# We continue by defining a testing routine and a training loop. This again looks lengthy but is standard and adapted from [5] with slight modifications.
#
# [5] https://github.com/apache/incubator-mxnet/blob/master/example/gluon/image_classification.py

# %%
import time

# testing routine
def test(net, val_data, context):
    metric = mx.metric.Accuracy()
    val_data.reset()
    for batch in val_data:
        data = gluon.utils.split_and_load(batch.data[0], ctx_list=context, batch_axis=0)
        label = gluon.utils.split_and_load(batch.label[0], ctx_list=context, batch_axis=0)
        outputs = []
        for x in data:
            outputs.append(net(x))
        metric.update(label, outputs)
    return metric.get()


# training routine
def train(net, lr, mom, wd, epochs, scheduler, context, train_data, val_data, log_interval):
    # define trainer, metric, loss
    trainer = gluon.Trainer(net.collect_params(), 'sgd',
                            {'learning_rate': lr, 'wd': wd, 'momentum': mom, 'lr_scheduler': scheduler},
                            kvstore = 'device')
    metric = mx.metric.Accuracy()
    loss = gluon.loss.SoftmaxCrossEntropyLoss()

    for epoch in range(epochs):
        tic = time.time()
        train_data.reset()
        metric.reset()
        btic = time.time()
        # loop through batches
        for i, batch in enumerate(train_data):
            data = gluon.utils.split_and_load(batch.data[0], ctx_list=ctx, batch_axis=0)
            label = gluon.utils.split_and_load(batch.label[0], ctx_list=ctx, batch_axis=0)
            outputs = []
            Ls = []
            with autograd.record():
                # forward pass 
                for x, y in zip(data, label):
                    z = net(x)
                    L = loss(z, y)
                    Ls.append(L)
                    outputs.append(z)
                # backward pass
                for L in Ls:
                    L.backward()
            # SGD step
            trainer.step(batch.data[0].shape[0])
            metric.update(label, outputs)
            if log_interval and not (i+1)%log_interval:
                name, acc = metric.get()
                print('Epoch[%d] Batch [%d]\tSpeed: %f samples/sec\t%s=%f'%(
                               epoch, i, batch_size/(time.time()-btic), name, acc))
            btic = time.time()

        name, acc = metric.get()
        print('[Epoch %d] training: %s=%f'%(epoch, name, acc))
        print('[Epoch %d] time cost: %f'%(epoch, time.time()-tic))
        name, val_acc = test(net, val_data, context)
        print('[Epoch %d] validation: %s=%f'%(epoch, name, val_acc))

# %% [markdown]
# Now, we define the iterators, employing the same data augmentation procedures as described in [3], Sec. 4.2. The CIFAR-10 data set should be downloaded automatically if not available locally (otherwise, you can donwload it manually from http://data.mxnet.io/mxnet/data/cifar10.zip, create a subfolder 'data' in the folder containing this notebook, and extract it there).

# %%
mx.random.seed(321)
np.random.seed(321)

data_shape = (3, 32, 32)
batch_size = 128

# download CIFAR-10 if necessary
import os.path
if (not os.path.isfile("data/cifar/train.rec")) or (not os.path.isfile("data/cifar/test.rec")):
    zip_file_path = mx.test_utils.download('http://data.mxnet.io/mxnet/data/cifar10.zip', dirname='data')
    import zipfile
    with zipfile.ZipFile(zip_file_path) as zf:
        zf.extractall('data')

# training set iterator
train_data = mx.io.ImageRecordIter(
    path_imgrec   = "data/cifar/train.rec",
    data_shape    = data_shape,
    batch_size    = batch_size,
    mean_r        = 125.3,
    mean_g        = 123.0,
    mean_b        = 113.9,
    std_r         = 63.0,
    std_g         = 62.1,
    std_b         = 66.7,
    dtype         = 'float32',
    rand_crop     = True,
    max_crop_size = 32,
    min_crop_size = 32,
    pad           = 4,
    fill_value    = 0,
    shuffle       = True,
    rand_mirror   = True,
    shuffle_chunk_seed  = 123)

# validation set iterator
val_data = mx.io.ImageRecordIter(
    mean_r      = 125.3,
    mean_g      = 123.0,
    mean_b      = 113.9,
    std_r       = 63.0,
    std_g       = 62.1,
    std_b       = 66.7,
    dtype       = 'float32',
    path_imgrec = "data/cifar/test.rec",
    rand_crop   = False,
    rand_mirror = False,
    data_shape  = data_shape,
    batch_size  = batch_size)

# %% [markdown]
# Specify optimizer paramters, regularization, and learning rate schedule (150-50-50 epochs x0.1)...

# %%
epochs = 250
learning_rate = 0.1
momentum = 0.9
weight_decay = 0.0001

train_set_size = 50000
# introduce auxiliary variable to translate steps into epochs
schedule_factor = ceil(train_set_size/batch_size)
scheduler = mx.lr_scheduler.MultiFactorScheduler([150*schedule_factor, 200*schedule_factor, 250*schedule_factor], factor=0.1)

log_interval = 50

# %% [markdown]
# ... and train the SP-ResNet-20 from scratch with full precision entries for $W_B$, $W_C$.

# %%
train(sp_resnet, learning_rate, momentum, weight_decay, epochs, scheduler, ctx, train_data, val_data, log_interval)
# Out:
# Epoch[0] Batch [49]	Speed: 3995.050839 samples/sec	accuracy=0.201719
# Epoch[0] Batch [99]	Speed: 3854.505270 samples/sec	accuracy=0.241641
# Epoch[0] Batch [149]	Speed: 3657.756799 samples/sec	accuracy=0.273281
# Epoch[0] Batch [199]	Speed: 3812.353803 samples/sec	accuracy=0.295234
# Epoch[0] Batch [249]	Speed: 3524.694630 samples/sec	accuracy=0.314375
# Epoch[0] Batch [299]	Speed: 3733.663291 samples/sec	accuracy=0.330885
# Epoch[0] Batch [349]	Speed: 2852.707068 samples/sec	accuracy=0.346763
# [Epoch 0] training: accuracy=0.358376
# [Epoch 0] time cost: 16.123975
# [Epoch 0] validation: accuracy=0.440961
# Epoch[1] Batch [49]	Speed: 3640.888889 samples/sec	accuracy=0.485156
# Epoch[1] Batch [99]	Speed: 3708.799027 samples/sec	accuracy=0.492422
# Epoch[1] Batch [149]	Speed: 3799.484165 samples/sec	accuracy=0.505104
# Epoch[1] Batch [199]	Speed: 3762.656724 samples/sec	accuracy=0.511836
# Epoch[1] Batch [249]	Speed: 3774.295661 samples/sec	accuracy=0.518594
# Epoch[1] Batch [299]	Speed: 3988.017560 samples/sec	accuracy=0.527552
# Epoch[1] Batch [349]	Speed: 1991.316632 samples/sec	accuracy=0.536629
# [Epoch 1] training: accuracy=0.540801
# [Epoch 1] time cost: 14.418656
# [Epoch 1] validation: accuracy=0.535958
# Epoch[2] Batch [49]	Speed: 4031.470391 samples/sec	accuracy=0.610938
# Epoch[2] Batch [99]	Speed: 3840.113529 samples/sec	accuracy=0.613359
# Epoch[2] Batch [149]	Speed: 2664.067685 samples/sec	accuracy=0.614740
# Epoch[2] Batch [199]	Speed: 3844.403237 samples/sec	accuracy=0.617656
# Epoch[2] Batch [249]	Speed: 3393.364043 samples/sec	accuracy=0.621875
# Epoch[2] Batch [299]	Speed: 3842.944761 samples/sec	accuracy=0.625182
# Epoch[2] Batch [349]	Speed: 3740.244198 samples/sec	accuracy=0.629375
# [Epoch 2] training: accuracy=0.632252
# [Epoch 2] time cost: 14.635556
# [Epoch 2] validation: accuracy=0.621595
# Epoch[3] Batch [49]	Speed: 3633.816235 samples/sec	accuracy=0.660000
# Epoch[3] Batch [99]	Speed: 3693.591502 samples/sec	accuracy=0.666328
# Epoch[3] Batch [149]	Speed: 2788.461781 samples/sec	accuracy=0.666510
# Epoch[3] Batch [199]	Speed: 3807.163102 samples/sec	accuracy=0.669336
# Epoch[3] Batch [249]	Speed: 3676.820272 samples/sec	accuracy=0.670219
# Epoch[3] Batch [299]	Speed: 3938.631433 samples/sec	accuracy=0.671693
# Epoch[3] Batch [349]	Speed: 3850.690078 samples/sec	accuracy=0.676004
# [Epoch 3] training: accuracy=0.678808
# [Epoch 3] time cost: 14.540682
# [Epoch 3] validation: accuracy=0.668770
# Epoch[4] Batch [49]	Speed: 3906.333945 samples/sec	accuracy=0.696406
# Epoch[4] Batch [99]	Speed: 2232.998561 samples/sec	accuracy=0.702656
# Epoch[4] Batch [149]	Speed: 3726.613949 samples/sec	accuracy=0.705729
# Epoch[4] Batch [199]	Speed: 3863.575869 samples/sec	accuracy=0.707461
# Epoch[4] Batch [249]	Speed: 3205.754501 samples/sec	accuracy=0.709469
# Epoch[4] Batch [299]	Speed: 3715.678202 samples/sec	accuracy=0.710052
# Epoch[4] Batch [349]	Speed: 2825.353844 samples/sec	accuracy=0.714107
# [Epoch 4] training: accuracy=0.715373
# [Epoch 4] time cost: 14.823233
# [Epoch 4] validation: accuracy=0.711138
# Epoch[5] Batch [49]	Speed: 3783.098885 samples/sec	accuracy=0.738125
# Epoch[5] Batch [99]	Speed: 3732.702807 samples/sec	accuracy=0.738359
# Epoch[5] Batch [149]	Speed: 3864.437989 samples/sec	accuracy=0.737448
# Epoch[5] Batch [199]	Speed: 3347.680765 samples/sec	accuracy=0.736367
# Epoch[5] Batch [249]	Speed: 3748.522657 samples/sec	accuracy=0.737094
# Epoch[5] Batch [299]	Speed: 2742.579523 samples/sec	accuracy=0.738255
# Epoch[5] Batch [349]	Speed: 2515.336522 samples/sec	accuracy=0.741607
# [Epoch 5] training: accuracy=0.741767
# [Epoch 5] time cost: 14.617910
# [Epoch 5] validation: accuracy=0.746194
# Epoch[6] Batch [49]	Speed: 3024.232984 samples/sec	accuracy=0.759531
# Epoch[6] Batch [99]	Speed: 3885.019987 samples/sec	accuracy=0.759062
# Epoch[6] Batch [149]	Speed: 4083.848656 samples/sec	accuracy=0.758698
# Epoch[6] Batch [199]	Speed: 3235.799513 samples/sec	accuracy=0.759258
# Epoch[6] Batch [249]	Speed: 2201.987236 samples/sec	accuracy=0.760969
# Epoch[6] Batch [299]	Speed: 3896.665713 samples/sec	accuracy=0.760964
# Epoch[6] Batch [349]	Speed: 3767.541611 samples/sec	accuracy=0.761540
# [Epoch 6] training: accuracy=0.761469
# [Epoch 6] time cost: 15.184485
# [Epoch 6] validation: accuracy=0.734575
# Epoch[7] Batch [49]	Speed: 1881.743790 samples/sec	accuracy=0.769844
# Epoch[7] Batch [99]	Speed: 3921.141363 samples/sec	accuracy=0.773359
# Epoch[7] Batch [149]	Speed: 3949.700295 samples/sec	accuracy=0.772448
# Epoch[7] Batch [199]	Speed: 3800.963652 samples/sec	accuracy=0.772266
# Epoch[7] Batch [249]	Speed: 3519.795659 samples/sec	accuracy=0.772906
# Epoch[7] Batch [299]	Speed: 3608.027688 samples/sec	accuracy=0.772943
# Epoch[7] Batch [349]	Speed: 3869.786152 samples/sec	accuracy=0.774665
# [Epoch 7] training: accuracy=0.774980
# [Epoch 7] time cost: 14.602977
# [Epoch 7] validation: accuracy=0.729567
# Epoch[8] Batch [49]	Speed: 3858.466678 samples/sec	accuracy=0.782188
# Epoch[8] Batch [99]	Speed: 3836.217109 samples/sec	accuracy=0.782344
# Epoch[8] Batch [149]	Speed: 3879.153115 samples/sec	accuracy=0.780937
# Epoch[8] Batch [199]	Speed: 1793.365664 samples/sec	accuracy=0.779336
# Epoch[8] Batch [249]	Speed: 2684.663296 samples/sec	accuracy=0.780844
# Epoch[8] Batch [299]	Speed: 3926.245709 samples/sec	accuracy=0.780964
# Epoch[8] Batch [349]	Speed: 4085.775586 samples/sec	accuracy=0.782879
# [Epoch 8] training: accuracy=0.782569
# [Epoch 8] time cost: 14.686705
# [Epoch 8] validation: accuracy=0.763350
# Epoch[9] Batch [49]	Speed: 2698.440419 samples/sec	accuracy=0.792813
# Epoch[16] Batch [349]	Speed: 3809.945938 samples/sec	accuracy=0.829754
# [Epoch 16] training: accuracy=0.829464
# [Epoch 16] time cost: 13.826482
# [Epoch 16] validation: accuracy=0.795787
# Epoch[17] Batch [49]	Speed: 3851.214909 samples/sec	accuracy=0.825000
# Epoch[17] Batch [99]	Speed: 3755.077302 samples/sec	accuracy=0.831484
# Epoch[17] Batch [149]	Speed: 3739.957590 samples/sec	accuracy=0.828438
# Epoch[17] Batch [199]	Speed: 3879.461456 samples/sec	accuracy=0.827070
# Epoch[17] Batch [249]	Speed: 2950.407562 samples/sec	accuracy=0.827906
# Epoch[17] Batch [299]	Speed: 3579.950869 samples/sec	accuracy=0.828359
# Epoch[17] Batch [349]	Speed: 3818.590495 samples/sec	accuracy=0.829464
# [Epoch 17] training: accuracy=0.829803
# [Epoch 17] time cost: 13.992058
# [Epoch 17] validation: accuracy=0.800080
# Epoch[18] Batch [49]	Speed: 3835.531938 samples/sec	accuracy=0.827031
# Epoch[18] Batch [99]	Speed: 3944.447880 samples/sec	accuracy=0.832656
# Epoch[18] Batch [149]	Speed: 3735.351827 samples/sec	accuracy=0.834688
# Epoch[18] Batch [199]	Speed: 3698.782705 samples/sec	accuracy=0.833086
# Epoch[18] Batch [249]	Speed: 3524.578931 samples/sec	accuracy=0.833281
# Epoch[18] Batch [299]	Speed: 3036.531481 samples/sec	accuracy=0.833802
# Epoch[18] Batch [349]	Speed: 3870.232500 samples/sec	accuracy=0.834442
# [Epoch 18] training: accuracy=0.834275
# [Epoch 18] time cost: 14.280908
# [Epoch 18] validation: accuracy=0.813101
# Epoch[19] Batch [49]	Speed: 3984.761577 samples/sec	accuracy=0.837500
# Epoch[19] Batch [99]	Speed: 4100.912134 samples/sec	accuracy=0.839141
# Epoch[19] Batch [149]	Speed: 3697.891020 samples/sec	accuracy=0.836875
# Epoch[19] Batch [199]	Speed: 3995.169757 samples/sec	accuracy=0.834805
# Epoch[19] Batch [249]	Speed: 3724.907459 samples/sec	accuracy=0.832750
# Epoch[19] Batch [299]	Speed: 3494.434325 samples/sec	accuracy=0.833620
# Epoch[19] Batch [349]	Speed: 3781.313650 samples/sec	accuracy=0.834241
# [Epoch 19] training: accuracy=0.834719
# [Epoch 19] time cost: 13.666683
# [Epoch 19] validation: accuracy=0.790064
# Epoch[20] Batch [49]	Speed: 3616.339492 samples/sec	accuracy=0.844219
# Epoch[20] Batch [99]	Speed: 3804.626972 samples/sec	accuracy=0.839141
# Epoch[20] Batch [149]	Speed: 3699.012064 samples/sec	accuracy=0.837865
# Epoch[20] Batch [199]	Speed: 1284.678291 samples/sec	accuracy=0.837109
# Epoch[20] Batch [249]	Speed: 2443.765815 samples/sec	accuracy=0.837562
# Epoch[20] Batch [299]	Speed: 3792.934487 samples/sec	accuracy=0.837266
# Epoch[20] Batch [349]	Speed: 2505.581332 samples/sec	accuracy=0.838080
# [Epoch 20] training: accuracy=0.838375
# [Epoch 20] time cost: 14.469571
# [Epoch 20] validation: accuracy=0.797175
# Epoch[21] Batch [49]	Speed: 3471.701815 samples/sec	accuracy=0.843281
# Epoch[21] Batch [99]	Speed: 4069.053449 samples/sec	accuracy=0.840938
# Epoch[21] Batch [149]	Speed: 3833.696887 samples/sec	accuracy=0.839792
# Epoch[21] Batch [199]	Speed: 3585.856919 samples/sec	accuracy=0.840742
# Epoch[21] Batch [249]	Speed: 2880.641470 samples/sec	accuracy=0.839781
# Epoch[21] Batch [299]	Speed: 3884.176762 samples/sec	accuracy=0.839922
# Epoch[21] Batch [349]	Speed: 3509.373077 samples/sec	accuracy=0.840223
# [Epoch 21] training: accuracy=0.839423
# [Epoch 21] time cost: 13.661896
# [Epoch 21] validation: accuracy=0.792668
# Epoch[22] Batch [49]	Speed: 3322.611644 samples/sec	accuracy=0.846250
# Epoch[22] Batch [99]	Speed: 3803.279343 samples/sec	accuracy=0.845000
# Epoch[22] Batch [149]	Speed: 3834.217096 samples/sec	accuracy=0.846250
# Epoch[22] Batch [199]	Speed: 3686.844429 samples/sec	accuracy=0.843789
# Epoch[22] Batch [249]	Speed: 3614.489117 samples/sec	accuracy=0.843375
# Epoch[22] Batch [299]	Speed: 3867.305216 samples/sec	accuracy=0.844063
# Epoch[22] Batch [349]	Speed: 3826.210585 samples/sec	accuracy=0.843616
# [Epoch 22] training: accuracy=0.843470
# [Epoch 22] time cost: 14.314837
# [Epoch 22] validation: accuracy=0.824018
# Epoch[23] Batch [49]	Speed: 3877.780192 samples/sec	accuracy=0.844531
# Epoch[23] Batch [99]	Speed: 3947.231950 samples/sec	accuracy=0.847578
# Epoch[23] Batch [149]	Speed: 3731.924398 samples/sec	accuracy=0.844792
# Epoch[23] Batch [199]	Speed: 3120.326591 samples/sec	accuracy=0.843906
# Epoch[23] Batch [249]	Speed: 2114.805671 samples/sec	accuracy=0.843125
# Epoch[23] Batch [299]	Speed: 3806.839153 samples/sec	accuracy=0.843021
# Epoch[23] Batch [349]	Speed: 3796.072291 samples/sec	accuracy=0.844330
# [Epoch 23] training: accuracy=0.844331
# [Epoch 23] time cost: 13.955546
# [Epoch 23] validation: accuracy=0.811098
# Epoch[24] Batch [49]	Speed: 2721.585854 samples/sec	accuracy=0.850781
# Epoch[24] Batch [99]	Speed: 3272.405900 samples/sec	accuracy=0.850156
# Epoch[24] Batch [149]	Speed: 3056.533342 samples/sec	accuracy=0.850938
# Epoch[24] Batch [199]	Speed: 3082.081807 samples/sec	accuracy=0.849102
# Epoch[24] Batch [249]	Speed: 3570.475061 samples/sec	accuracy=0.848500
# Epoch[24] Batch [299]	Speed: 3974.289801 samples/sec	accuracy=0.847969
# Epoch[24] Batch [349]	Speed: 3858.189391 samples/sec	accuracy=0.847634
# [Epoch 24] training: accuracy=0.847367
# [Epoch 24] time cost: 14.476196
# [Epoch 24] validation: accuracy=0.806171
# Epoch[25] Batch [49]	Speed: 3814.764714 samples/sec	accuracy=0.849688
# Epoch[25] Batch [99]	Speed: 2905.287119 samples/sec	accuracy=0.847656
# Epoch[25] Batch [149]	Speed: 3911.342795 samples/sec	accuracy=0.845938
# Epoch[25] Batch [199]	Speed: 3885.301143 samples/sec	accuracy=0.847500
# Epoch[25] Batch [249]	Speed: 3572.280635 samples/sec	accuracy=0.846406
# Epoch[25] Batch [299]	Speed: 3608.051936 samples/sec	accuracy=0.846771
# Epoch[25] Batch [349]	Speed: 3720.364448 samples/sec	accuracy=0.847902
# [Epoch 25] training: accuracy=0.848046
# [Epoch 25] time cost: 14.085783
# [Epoch 25] validation: accuracy=0.782853
# Epoch[26] Batch [49]	Speed: 3646.948339 samples/sec	accuracy=0.847187
# Epoch[26] Batch [99]	Speed: 3760.679971 samples/sec	accuracy=0.848203
# Epoch[26] Batch [149]	Speed: 3897.882237 samples/sec	accuracy=0.848385
# Epoch[26] Batch [199]	Speed: 2931.158069 samples/sec	accuracy=0.847617
# Epoch[26] Batch [249]	Speed: 3730.213042 samples/sec	accuracy=0.848500
# Epoch[26] Batch [299]	Speed: 3905.112141 samples/sec	accuracy=0.849609
# Epoch[26] Batch [349]	Speed: 3824.466170 samples/sec	accuracy=0.849554
# [Epoch 26] training: accuracy=0.848638
# [Epoch 26] time cost: 14.586091
# [Epoch 26] validation: accuracy=0.792869
# Epoch[27] Batch [49]	Speed: 3479.013407 samples/sec	accuracy=0.857500
# Epoch[27] Batch [99]	Speed: 3774.906041 samples/sec	accuracy=0.855000
# Epoch[27] Batch [149]	Speed: 3168.613808 samples/sec	accuracy=0.855208
# Epoch[27] Batch [199]	Speed: 3997.103168 samples/sec	accuracy=0.853789
# Epoch[27] Batch [249]	Speed: 3718.251600 samples/sec	accuracy=0.852344
# Epoch[27] Batch [299]	Speed: 3894.602191 samples/sec	accuracy=0.852760
# Epoch[27] Batch [349]	Speed: 3755.628936 samples/sec	accuracy=0.853326
# [Epoch 27] training: accuracy=0.852562
# [Epoch 27] time cost: 13.921139
# [Epoch 27] validation: accuracy=0.793069
# Epoch[28] Batch [49]	Speed: 3819.079445 samples/sec	accuracy=0.847969
# Epoch[28] Batch [99]	Speed: 3445.654748 samples/sec	accuracy=0.849219
# Epoch[28] Batch [149]	Speed: 3849.834080 samples/sec	accuracy=0.850208
# Epoch[28] Batch [199]	Speed: 3132.451788 samples/sec	accuracy=0.850703
# Epoch[28] Batch [249]	Speed: 2621.849664 samples/sec	accuracy=0.851812
# Epoch[28] Batch [299]	Speed: 3880.639209 samples/sec	accuracy=0.852109
# Epoch[28] Batch [349]	Speed: 3818.101670 samples/sec	accuracy=0.852165
# [Epoch 28] training: accuracy=0.851922
# [Epoch 28] time cost: 14.189382
# [Epoch 28] validation: accuracy=0.835537
# Epoch[29] Batch [49]	Speed: 3757.232221 samples/sec	accuracy=0.856094
# Epoch[29] Batch [99]	Speed: 4130.793057 samples/sec	accuracy=0.852812
# Epoch[29] Batch [149]	Speed: 3405.784959 samples/sec	accuracy=0.851823
# Epoch[29] Batch [199]	Speed: 3810.621998 samples/sec	accuracy=0.851211
# Epoch[29] Batch [249]	Speed: 3411.455027 samples/sec	accuracy=0.850594
# Epoch[29] Batch [299]	Speed: 3877.696167 samples/sec	accuracy=0.851875
# Epoch[29] Batch [349]	Speed: 3890.566275 samples/sec	accuracy=0.853772
# [Epoch 29] training: accuracy=0.853305
# [Epoch 29] time cost: 13.854174
# [Epoch 29] validation: accuracy=0.818610
# Epoch[30] Batch [49]	Speed: 2406.715823 samples/sec	accuracy=0.848750
# Epoch[30] Batch [99]	Speed: 3721.963562 samples/sec	accuracy=0.852734
# Epoch[30] Batch [149]	Speed: 3825.774332 samples/sec	accuracy=0.852760
# Epoch[30] Batch [199]	Speed: 4003.601214 samples/sec	accuracy=0.853164
# Epoch[30] Batch [249]	Speed: 3691.331275 samples/sec	accuracy=0.852719
# Epoch[30] Batch [299]	Speed: 3996.418824 samples/sec	accuracy=0.852526
# Epoch[30] Batch [349]	Speed: 3613.807877 samples/sec	accuracy=0.853058
# [Epoch 30] training: accuracy=0.853880
# [Epoch 30] time cost: 13.609262
# [Epoch 30] validation: accuracy=0.824018
# Epoch[31] Batch [49]	Speed: 3842.477183 samples/sec	accuracy=0.862969
# Epoch[31] Batch [99]	Speed: 2612.841099 samples/sec	accuracy=0.858203
# Epoch[31] Batch [149]	Speed: 3856.609620 samples/sec	accuracy=0.855313
# Epoch[31] Batch [199]	Speed: 3798.758293 samples/sec	accuracy=0.855234
# Epoch[31] Batch [249]	Speed: 3355.023822 samples/sec	accuracy=0.855906
# Epoch[31] Batch [299]	Speed: 3907.784052 samples/sec	accuracy=0.856458
# Epoch[31] Batch [349]	Speed: 3760.785346 samples/sec	accuracy=0.856406
# [Epoch 31] training: accuracy=0.856310
# [Epoch 31] time cost: 13.973273
# [Epoch 31] validation: accuracy=0.829527
# Epoch[32] Batch [49]	Speed: 3822.042985 samples/sec	accuracy=0.861094
# Epoch[32] Batch [99]	Speed: 3719.230426 samples/sec	accuracy=0.858516
# Epoch[32] Batch [149]	Speed: 3919.681327 samples/sec	accuracy=0.857240
# Epoch[32] Batch [199]	Speed: 3893.359479 samples/sec	accuracy=0.855117
# Epoch[32] Batch [249]	Speed: 2573.451661 samples/sec	accuracy=0.855656
# Epoch[32] Batch [299]	Speed: 3761.628553 samples/sec	accuracy=0.855859
# Epoch[32] Batch [349]	Speed: 3792.264689 samples/sec	accuracy=0.856563
# [Epoch 32] training: accuracy=0.856937
# [Epoch 32] time cost: 13.985967
# [Epoch 32] validation: accuracy=0.817544
# Epoch[33] Batch [49]	Speed: 3834.299247 samples/sec	accuracy=0.863437
# Epoch[33] Batch [99]	Speed: 3812.462093 samples/sec	accuracy=0.859297
# Epoch[33] Batch [149]	Speed: 3593.633736 samples/sec	accuracy=0.860365
# Epoch[33] Batch [199]	Speed: 3551.391210 samples/sec	accuracy=0.857539
# Epoch[33] Batch [249]	Speed: 3853.979541 samples/sec	accuracy=0.857875
# Epoch[33] Batch [299]	Speed: 3593.032472 samples/sec	accuracy=0.857500
# Epoch[33] Batch [349]	Speed: 3891.807204 samples/sec	accuracy=0.857879
# [Epoch 33] training: accuracy=0.857677
# [Epoch 33] time cost: 13.777997
# [Epoch 33] validation: accuracy=0.829227
# Epoch[34] Batch [49]	Speed: 3865.717972 samples/sec	accuracy=0.855781
# Epoch[34] Batch [99]	Speed: 1954.987736 samples/sec	accuracy=0.855234
# Epoch[34] Batch [149]	Speed: 3831.699500 samples/sec	accuracy=0.856771
# Epoch[34] Batch [199]	Speed: 3946.071443 samples/sec	accuracy=0.856445
# Epoch[34] Batch [249]	Speed: 3758.573723 samples/sec	accuracy=0.857062
# Epoch[34] Batch [299]	Speed: 3605.023482 samples/sec	accuracy=0.858724
# Epoch[34] Batch [349]	Speed: 3952.957420 samples/sec	accuracy=0.859375
# [Epoch 34] training: accuracy=0.859034
# [Epoch 34] time cost: 14.262979
# [Epoch 34] validation: accuracy=0.842748
# Epoch[35] Batch [49]	Speed: 3935.542106 samples/sec	accuracy=0.868594
# Epoch[35] Batch [99]	Speed: 3804.600010 samples/sec	accuracy=0.865156
# Epoch[35] Batch [149]	Speed: 3641.012350 samples/sec	accuracy=0.865833
# Epoch[35] Batch [199]	Speed: 3784.085483 samples/sec	accuracy=0.862773
# Epoch[35] Batch [249]	Speed: 3797.334239 samples/sec	accuracy=0.862156
# Epoch[35] Batch [299]	Speed: 3832.930519 samples/sec	accuracy=0.862083
# Epoch[35] Batch [349]	Speed: 3739.775225 samples/sec	accuracy=0.862634
# [Epoch 35] training: accuracy=0.861533
# [Epoch 35] time cost: 14.051878
# [Epoch 35] validation: accuracy=0.837640
# Epoch[36] Batch [49]	Speed: 3774.799873 samples/sec	accuracy=0.857656
# Epoch[36] Batch [99]	Speed: 3826.537840 samples/sec	accuracy=0.859375
# Epoch[36] Batch [149]	Speed: 3756.758978 samples/sec	accuracy=0.860625
# Epoch[36] Batch [199]	Speed: 3480.908184 samples/sec	accuracy=0.861680
# Epoch[36] Batch [249]	Speed: 3714.958288 samples/sec	accuracy=0.862219
# Epoch[36] Batch [299]	Speed: 3474.690225 samples/sec	accuracy=0.863073
# Epoch[36] Batch [349]	Speed: 3577.612965 samples/sec	accuracy=0.863125
# [Epoch 36] training: accuracy=0.862292
# [Epoch 36] time cost: 13.989904
# [Epoch 36] validation: accuracy=0.842748
# Epoch[37] Batch [49]	Speed: 3598.234042 samples/sec	accuracy=0.866875
# Epoch[37] Batch [99]	Speed: 3673.826160 samples/sec	accuracy=0.864609
# Epoch[37] Batch [149]	Speed: 3327.492265 samples/sec	accuracy=0.864844
# Epoch[37] Batch [199]	Speed: 3891.017430 samples/sec	accuracy=0.863164
# Epoch[37] Batch [249]	Speed: 3557.934126 samples/sec	accuracy=0.864156
# Epoch[37] Batch [299]	Speed: 3808.216319 samples/sec	accuracy=0.864766
# Epoch[37] Batch [349]	Speed: 4038.171870 samples/sec	accuracy=0.865469
# [Epoch 37] training: accuracy=0.864924
# [Epoch 37] time cost: 13.905051
# [Epoch 37] validation: accuracy=0.843149
# Epoch[38] Batch [49]	Speed: 3763.448007 samples/sec	accuracy=0.865938
# Epoch[38] Batch [99]	Speed: 3224.837290 samples/sec	accuracy=0.860078
# Epoch[38] Batch [149]	Speed: 3731.224108 samples/sec	accuracy=0.862708
# Epoch[38] Batch [199]	Speed: 3824.220989 samples/sec	accuracy=0.863828
# Epoch[38] Batch [249]	Speed: 3613.661930 samples/sec	accuracy=0.862781
# Epoch[38] Batch [299]	Speed: 3557.462608 samples/sec	accuracy=0.862891
# Epoch[38] Batch [349]	Speed: 3801.824975 samples/sec	accuracy=0.864732
# [Epoch 38] training: accuracy=0.864630
# [Epoch 38] time cost: 14.075155
# [Epoch 38] validation: accuracy=0.829026
# Epoch[39] Batch [49]	Speed: 2889.540856 samples/sec	accuracy=0.866094
# Epoch[39] Batch [99]	Speed: 3778.333136 samples/sec	accuracy=0.862969
# Epoch[39] Batch [149]	Speed: 3845.587342 samples/sec	accuracy=0.865729
# Epoch[39] Batch [199]	Speed: 4035.197426 samples/sec	accuracy=0.864766
# Epoch[39] Batch [249]	Speed: 3714.315744 samples/sec	accuracy=0.865313
# Epoch[39] Batch [299]	Speed: 4024.006776 samples/sec	accuracy=0.864271
# Epoch[39] Batch [349]	Speed: 3809.594482 samples/sec	accuracy=0.864888
# [Epoch 39] training: accuracy=0.864944
# [Epoch 39] time cost: 14.156489
# [Epoch 39] validation: accuracy=0.841647
# Epoch[40] Batch [49]	Speed: 3896.241523 samples/sec	accuracy=0.870313
# Epoch[40] Batch [99]	Speed: 3708.107388 samples/sec	accuracy=0.866172
# Epoch[40] Batch [149]	Speed: 3666.199429 samples/sec	accuracy=0.866458
# Epoch[40] Batch [199]	Speed: 4015.849680 samples/sec	accuracy=0.865352
# Epoch[40] Batch [249]	Speed: 3812.705769 samples/sec	accuracy=0.866500
# Epoch[40] Batch [299]	Speed: 3968.267749 samples/sec	accuracy=0.867109
# Epoch[40] Batch [349]	Speed: 3891.750781 samples/sec	accuracy=0.867545
# [Epoch 40] training: accuracy=0.867387
# [Epoch 40] time cost: 13.758765
# [Epoch 40] validation: accuracy=0.840091
# Epoch[41] Batch [49]	Speed: 3892.597298 samples/sec	accuracy=0.869844
# Epoch[41] Batch [99]	Speed: 3932.054403 samples/sec	accuracy=0.868672
# Epoch[41] Batch [149]	Speed: 2741.249187 samples/sec	accuracy=0.869062
# Epoch[41] Batch [199]	Speed: 3650.395126 samples/sec	accuracy=0.867148
# Epoch[41] Batch [249]	Speed: 2803.196057 samples/sec	accuracy=0.866656
# Epoch[41] Batch [299]	Speed: 3779.423672 samples/sec	accuracy=0.864948
# Epoch[41] Batch [349]	Speed: 3870.678952 samples/sec	accuracy=0.865603
# [Epoch 41] training: accuracy=0.865829
# [Epoch 41] time cost: 13.894866
# [Epoch 41] validation: accuracy=0.835537
# Epoch[42] Batch [49]	Speed: 3802.498155 samples/sec	accuracy=0.862812
# Epoch[42] Batch [99]	Speed: 3176.656975 samples/sec	accuracy=0.865313
# Epoch[42] Batch [149]	Speed: 3757.416292 samples/sec	accuracy=0.865521
# Epoch[42] Batch [199]	Speed: 3830.933931 samples/sec	accuracy=0.866406
# Epoch[42] Batch [249]	Speed: 3751.010725 samples/sec	accuracy=0.864938
# Epoch[42] Batch [299]	Speed: 4012.218251 samples/sec	accuracy=0.864870
# Epoch[42] Batch [349]	Speed: 3831.972991 samples/sec	accuracy=0.866094
# [Epoch 42] training: accuracy=0.866086
# [Epoch 42] time cost: 13.921444
# [Epoch 42] validation: accuracy=0.829728
# Epoch[43] Batch [49]	Speed: 3801.609608 samples/sec	accuracy=0.874375
# Epoch[43] Batch [99]	Speed: 3813.843332 samples/sec	accuracy=0.867031
# Epoch[43] Batch [149]	Speed: 3601.106161 samples/sec	accuracy=0.865885
# Epoch[43] Batch [199]	Speed: 2547.998424 samples/sec	accuracy=0.866680
# Epoch[43] Batch [249]	Speed: 3874.841483 samples/sec	accuracy=0.864062
# Epoch[43] Batch [299]	Speed: 3033.683178 samples/sec	accuracy=0.865000
# Epoch[43] Batch [349]	Speed: 3621.511093 samples/sec	accuracy=0.866049
# [Epoch 43] training: accuracy=0.866268
# [Epoch 43] time cost: 14.318908
# [Epoch 43] validation: accuracy=0.826422
# Epoch[44] Batch [49]	Speed: 3837.341320 samples/sec	accuracy=0.871875
# Epoch[44] Batch [99]	Speed: 3819.432653 samples/sec	accuracy=0.867812
# Epoch[44] Batch [149]	Speed: 3506.920236 samples/sec	accuracy=0.869531
# Epoch[44] Batch [199]	Speed: 3591.253910 samples/sec	accuracy=0.867539
# Epoch[44] Batch [249]	Speed: 3685.047684 samples/sec	accuracy=0.865500
# Epoch[44] Batch [299]	Speed: 3678.130156 samples/sec	accuracy=0.867083
# Epoch[44] Batch [349]	Speed: 3855.750989 samples/sec	accuracy=0.867768
# [Epoch 44] training: accuracy=0.867407
# [Epoch 44] time cost: 14.243127
# [Epoch 44] validation: accuracy=0.826823
# Epoch[45] Batch [49]	Speed: 3993.089714 samples/sec	accuracy=0.873437
# Epoch[45] Batch [99]	Speed: 3637.854383 samples/sec	accuracy=0.871016
# Epoch[45] Batch [149]	Speed: 3797.683436 samples/sec	accuracy=0.871615
# Epoch[45] Batch [199]	Speed: 3837.478463 samples/sec	accuracy=0.870195
# Epoch[45] Batch [249]	Speed: 2916.825557 samples/sec	accuracy=0.870313
# Epoch[45] Batch [299]	Speed: 2152.002854 samples/sec	accuracy=0.869818
# Epoch[45] Batch [349]	Speed: 3812.624540 samples/sec	accuracy=0.870893
# [Epoch 45] training: accuracy=0.870192
# [Epoch 45] time cost: 14.369019
# [Epoch 45] validation: accuracy=0.825921
# Epoch[46] Batch [49]	Speed: 3669.105890 samples/sec	accuracy=0.866563
# Epoch[46] Batch [99]	Speed: 3921.656930 samples/sec	accuracy=0.867656
# Epoch[46] Batch [149]	Speed: 2935.068075 samples/sec	accuracy=0.866667
# Epoch[46] Batch [199]	Speed: 3687.097632 samples/sec	accuracy=0.866992
# Epoch[46] Batch [249]	Speed: 3838.164330 samples/sec	accuracy=0.868156
# Epoch[46] Batch [299]	Speed: 3943.289009 samples/sec	accuracy=0.869036
# Epoch[46] Batch [349]	Speed: 3679.920160 samples/sec	accuracy=0.869509
# [Epoch 46] training: accuracy=0.869565
# [Epoch 46] time cost: 13.788782
# [Epoch 46] validation: accuracy=0.814002
# Epoch[47] Batch [49]	Speed: 3704.065185 samples/sec	accuracy=0.869219
# Epoch[47] Batch [99]	Speed: 3733.481540 samples/sec	accuracy=0.869062
# Epoch[47] Batch [149]	Speed: 3952.637286 samples/sec	accuracy=0.868906
# Epoch[47] Batch [199]	Speed: 3909.149843 samples/sec	accuracy=0.869102
# Epoch[47] Batch [249]	Speed: 3084.809046 samples/sec	accuracy=0.868844
# Epoch[47] Batch [299]	Speed: 3759.863520 samples/sec	accuracy=0.869167
# Epoch[47] Batch [349]	Speed: 2486.791416 samples/sec	accuracy=0.871071
# [Epoch 47] training: accuracy=0.870793
# [Epoch 47] time cost: 14.151264
# [Epoch 47] validation: accuracy=0.843149
# Epoch[48] Batch [49]	Speed: 3516.982607 samples/sec	accuracy=0.869687
# Epoch[48] Batch [99]	Speed: 3646.948339 samples/sec	accuracy=0.872109
# Epoch[48] Batch [149]	Speed: 3908.011618 samples/sec	accuracy=0.871667
# Epoch[48] Batch [199]	Speed: 3579.354175 samples/sec	accuracy=0.872227
# Epoch[48] Batch [249]	Speed: 2934.233921 samples/sec	accuracy=0.873031
# Epoch[48] Batch [299]	Speed: 3870.093005 samples/sec	accuracy=0.873516
# Epoch[48] Batch [349]	Speed: 3782.032870 samples/sec	accuracy=0.873638
# [Epoch 48] training: accuracy=0.873681
# [Epoch 48] time cost: 14.680833
# [Epoch 48] validation: accuracy=0.832971
# Epoch[49] Batch [49]	Speed: 3800.344817 samples/sec	accuracy=0.875469
# Epoch[49] Batch [99]	Speed: 3724.829928 samples/sec	accuracy=0.870625
# Epoch[49] Batch [149]	Speed: 3921.427772 samples/sec	accuracy=0.870052
# Epoch[49] Batch [199]	Speed: 3927.998010 samples/sec	accuracy=0.868242
# Epoch[49] Batch [249]	Speed: 3784.805758 samples/sec	accuracy=0.868656
# Epoch[49] Batch [299]	Speed: 3837.341320 samples/sec	accuracy=0.868620
# Epoch[49] Batch [349]	Speed: 3914.850930 samples/sec	accuracy=0.871116
# [Epoch 49] training: accuracy=0.870584
# [Epoch 49] time cost: 13.562549
# [Epoch 49] validation: accuracy=0.838341
# Epoch[50] Batch [49]	Speed: 4062.741019 samples/sec	accuracy=0.878437
# Epoch[50] Batch [99]	Speed: 3790.791965 samples/sec	accuracy=0.872891
# Epoch[50] Batch [149]	Speed: 3868.364103 samples/sec	accuracy=0.871979
# Epoch[50] Batch [199]	Speed: 3908.922145 samples/sec	accuracy=0.870703
# Epoch[50] Batch [249]	Speed: 3680.222868 samples/sec	accuracy=0.867906
# Epoch[50] Batch [299]	Speed: 2383.518742 samples/sec	accuracy=0.869036
# Epoch[50] Batch [349]	Speed: 3919.023235 samples/sec	accuracy=0.870134
# [Epoch 50] training: accuracy=0.870553
# [Epoch 50] time cost: 13.810094
# [Epoch 50] validation: accuracy=0.835737
# Epoch[51] Batch [49]	Speed: 3271.867436 samples/sec	accuracy=0.871250
# Epoch[51] Batch [99]	Speed: 3686.211572 samples/sec	accuracy=0.869687
# Epoch[51] Batch [149]	Speed: 3908.666016 samples/sec	accuracy=0.872292
# Epoch[51] Batch [199]	Speed: 3772.704295 samples/sec	accuracy=0.870469
# Epoch[51] Batch [249]	Speed: 3791.836142 samples/sec	accuracy=0.870812
# Epoch[51] Batch [299]	Speed: 3686.844429 samples/sec	accuracy=0.872109
# Epoch[51] Batch [349]	Speed: 3848.095645 samples/sec	accuracy=0.873192
# [Epoch 51] training: accuracy=0.873541
# [Epoch 51] time cost: 13.921997
# [Epoch 51] validation: accuracy=0.831130
# Epoch[52] Batch [49]	Speed: 3789.186661 samples/sec	accuracy=0.870000
# Epoch[52] Batch [99]	Speed: 3956.978058 samples/sec	accuracy=0.869844
# Epoch[52] Batch [149]	Speed: 3683.404311 samples/sec	accuracy=0.873698
# Epoch[52] Batch [199]	Speed: 3992.970919 samples/sec	accuracy=0.874648
# Epoch[52] Batch [249]	Speed: 2867.792935 samples/sec	accuracy=0.874906
# Epoch[52] Batch [299]	Speed: 3801.582688 samples/sec	accuracy=0.875182
# Epoch[52] Batch [349]	Speed: 3199.964905 samples/sec	accuracy=0.875871
# [Epoch 52] training: accuracy=0.875040
# [Epoch 52] time cost: 14.241928
# [Epoch 52] validation: accuracy=0.799379
# Epoch[53] Batch [49]	Speed: 4042.520007 samples/sec	accuracy=0.874844
# Epoch[53] Batch [99]	Speed: 3939.932132 samples/sec	accuracy=0.870469
# Epoch[53] Batch [149]	Speed: 3836.820262 samples/sec	accuracy=0.871979
# Epoch[53] Batch [199]	Speed: 3605.071897 samples/sec	accuracy=0.871758
# Epoch[53] Batch [249]	Speed: 3542.346244 samples/sec	accuracy=0.873281
# Epoch[53] Batch [299]	Speed: 3684.744182 samples/sec	accuracy=0.873516
# Epoch[53] Batch [349]	Speed: 3839.234772 samples/sec	accuracy=0.873929
# [Epoch 53] training: accuracy=0.873237
# [Epoch 53] time cost: 14.001139
# [Epoch 53] validation: accuracy=0.843750
# Epoch[54] Batch [49]	Speed: 3782.432555 samples/sec	accuracy=0.877344
# Epoch[54] Batch [99]	Speed: 3783.978799 samples/sec	accuracy=0.876563
# Epoch[54] Batch [149]	Speed: 3552.025618 samples/sec	accuracy=0.874062
# Epoch[54] Batch [199]	Speed: 3836.902525 samples/sec	accuracy=0.872969
# Epoch[54] Batch [249]	Speed: 3730.420395 samples/sec	accuracy=0.873938
# Epoch[54] Batch [299]	Speed: 3956.803078 samples/sec	accuracy=0.873307
# Epoch[54] Batch [349]	Speed: 3007.461148 samples/sec	accuracy=0.874576
# [Epoch 54] training: accuracy=0.874381
# [Epoch 54] time cost: 14.379252
# [Epoch 54] validation: accuracy=0.834135
# Epoch[55] Batch [49]	Speed: 3809.270119 samples/sec	accuracy=0.877188
# Epoch[55] Batch [99]	Speed: 2993.909871 samples/sec	accuracy=0.874219
# Epoch[55] Batch [149]	Speed: 3786.701124 samples/sec	accuracy=0.876146
# Epoch[55] Batch [199]	Speed: 3627.849337 samples/sec	accuracy=0.875625
# Epoch[55] Batch [249]	Speed: 3604.466800 samples/sec	accuracy=0.874344
# Epoch[55] Batch [299]	Speed: 3851.353047 samples/sec	accuracy=0.875078
# Epoch[55] Batch [349]	Speed: 3818.753464 samples/sec	accuracy=0.876585
# [Epoch 55] training: accuracy=0.875821
# [Epoch 55] time cost: 14.035908
# [Epoch 55] validation: accuracy=0.836238
# Epoch[56] Batch [49]	Speed: 3137.944427 samples/sec	accuracy=0.870469
# Epoch[56] Batch [99]	Speed: 3842.532186 samples/sec	accuracy=0.874687
# Epoch[56] Batch [149]	Speed: 3902.869422 samples/sec	accuracy=0.874219
# Epoch[56] Batch [199]	Speed: 3959.604623 samples/sec	accuracy=0.875938
# Epoch[56] Batch [249]	Speed: 3736.391685 samples/sec	accuracy=0.874719
# Epoch[56] Batch [299]	Speed: 3783.498795 samples/sec	accuracy=0.875234
# Epoch[56] Batch [349]	Speed: 3612.786498 samples/sec	accuracy=0.876696
# [Epoch 56] training: accuracy=0.876339
# [Epoch 56] time cost: 13.543413
# [Epoch 56] validation: accuracy=0.822290
# Epoch[57] Batch [49]	Speed: 2761.553796 samples/sec	accuracy=0.872656
# Epoch[57] Batch [99]	Speed: 3585.090664 samples/sec	accuracy=0.871484
# Epoch[57] Batch [149]	Speed: 3801.663447 samples/sec	accuracy=0.872240
# Epoch[57] Batch [199]	Speed: 2855.149610 samples/sec	accuracy=0.873594
# Epoch[57] Batch [249]	Speed: 3649.303352 samples/sec	accuracy=0.874219
# Epoch[57] Batch [299]	Speed: 3601.855113 samples/sec	accuracy=0.875104
# Epoch[57] Batch [349]	Speed: 3765.269222 samples/sec	accuracy=0.875290
# [Epoch 57] training: accuracy=0.874361
# [Epoch 57] time cost: 14.469441
# [Epoch 57] validation: accuracy=0.820713
# Epoch[58] Batch [49]	Speed: 2553.621887 samples/sec	accuracy=0.878281
# Epoch[58] Batch [99]	Speed: 3831.699500 samples/sec	accuracy=0.875703
# Epoch[58] Batch [149]	Speed: 3878.032289 samples/sec	accuracy=0.876250
# Epoch[58] Batch [199]	Speed: 3897.005132 samples/sec	accuracy=0.875977
# Epoch[58] Batch [249]	Speed: 3783.792116 samples/sec	accuracy=0.876406
# Epoch[58] Batch [299]	Speed: 4003.034030 samples/sec	accuracy=0.876953
# Epoch[58] Batch [349]	Speed: 3860.047971 samples/sec	accuracy=0.877567
# [Epoch 58] training: accuracy=0.877163
# [Epoch 58] time cost: 14.120548
# [Epoch 58] validation: accuracy=0.849960
# Epoch[59] Batch [49]	Speed: 2431.733885 samples/sec	accuracy=0.878750
# Epoch[59] Batch [99]	Speed: 3827.219801 samples/sec	accuracy=0.875781
# Epoch[59] Batch [149]	Speed: 2860.138683 samples/sec	accuracy=0.875677
# Epoch[59] Batch [199]	Speed: 3932.976169 samples/sec	accuracy=0.876523
# Epoch[59] Batch [249]	Speed: 2903.762883 samples/sec	accuracy=0.876594
# Epoch[59] Batch [299]	Speed: 3652.456388 samples/sec	accuracy=0.875729
# Epoch[59] Batch [349]	Speed: 3996.835353 samples/sec	accuracy=0.877054
# [Epoch 59] training: accuracy=0.877478
# [Epoch 59] time cost: 14.736687
# [Epoch 59] validation: accuracy=0.837340
# Epoch[60] Batch [49]	Speed: 3640.321076 samples/sec	accuracy=0.871719
# Epoch[60] Batch [99]	Speed: 3687.198923 samples/sec	accuracy=0.872969
# Epoch[60] Batch [149]	Speed: 4189.231103 samples/sec	accuracy=0.874167
# Epoch[60] Batch [199]	Speed: 3730.964808 samples/sec	accuracy=0.874297
# Epoch[60] Batch [249]	Speed: 3744.418025 samples/sec	accuracy=0.874469
# Epoch[60] Batch [299]	Speed: 3917.450433 samples/sec	accuracy=0.875260
# Epoch[60] Batch [349]	Speed: 3876.296287 samples/sec	accuracy=0.876696
# [Epoch 60] training: accuracy=0.876918
# [Epoch 60] time cost: 13.505339
# [Epoch 60] validation: accuracy=0.816907
# Epoch[61] Batch [49]	Speed: 3688.972419 samples/sec	accuracy=0.880156
# Epoch[61] Batch [99]	Speed: 3997.400782 samples/sec	accuracy=0.877500
# Epoch[61] Batch [149]	Speed: 4005.034816 samples/sec	accuracy=0.875833
# Epoch[61] Batch [199]	Speed: 3380.650173 samples/sec	accuracy=0.875273
# Epoch[61] Batch [249]	Speed: 3802.390430 samples/sec	accuracy=0.875250
# Epoch[61] Batch [299]	Speed: 4052.804143 samples/sec	accuracy=0.877109
# Epoch[61] Batch [349]	Speed: 4021.474835 samples/sec	accuracy=0.878415
# [Epoch 61] training: accuracy=0.877684
# [Epoch 61] time cost: 13.523559
# [Epoch 61] validation: accuracy=0.825621
# Epoch[62] Batch [49]	Speed: 3851.325418 samples/sec	accuracy=0.880469
# Epoch[62] Batch [99]	Speed: 3926.733898 samples/sec	accuracy=0.877812
# Epoch[62] Batch [149]	Speed: 3781.127230 samples/sec	accuracy=0.878646
# Epoch[62] Batch [199]	Speed: 3224.721070 samples/sec	accuracy=0.879687
# Epoch[62] Batch [249]	Speed: 3846.055677 samples/sec	accuracy=0.879906
# Epoch[62] Batch [299]	Speed: 3935.022883 samples/sec	accuracy=0.880208
# Epoch[62] Batch [349]	Speed: 3929.924472 samples/sec	accuracy=0.880469
# [Epoch 62] training: accuracy=0.880874
# [Epoch 62] time cost: 13.465948
# [Epoch 62] validation: accuracy=0.814503
# Epoch[63] Batch [49]	Speed: 3823.757956 samples/sec	accuracy=0.872656
# Epoch[63] Batch [99]	Speed: 1714.590657 samples/sec	accuracy=0.878516
# Epoch[63] Batch [149]	Speed: 3696.337969 samples/sec	accuracy=0.878542
# Epoch[63] Batch [199]	Speed: 4061.941818 samples/sec	accuracy=0.878477
# Epoch[63] Batch [249]	Speed: 3592.743937 samples/sec	accuracy=0.879031
# Epoch[63] Batch [299]	Speed: 4070.133141 samples/sec	accuracy=0.879141
# Epoch[63] Batch [349]	Speed: 3961.649918 samples/sec	accuracy=0.880223
# [Epoch 63] training: accuracy=0.880068
# [Epoch 63] time cost: 13.846181
# [Epoch 63] validation: accuracy=0.823017
# Epoch[64] Batch [49]	Speed: 2877.229650 samples/sec	accuracy=0.877656
# Epoch[64] Batch [99]	Speed: 4205.837194 samples/sec	accuracy=0.873516
# Epoch[64] Batch [149]	Speed: 4042.489568 samples/sec	accuracy=0.875208
# Epoch[64] Batch [199]	Speed: 4080.310330 samples/sec	accuracy=0.875352
# Epoch[64] Batch [249]	Speed: 2934.394298 samples/sec	accuracy=0.876625
# Epoch[64] Batch [299]	Speed: 3955.607792 samples/sec	accuracy=0.876276
# Epoch[64] Batch [349]	Speed: 3915.993144 samples/sec	accuracy=0.877946
# [Epoch 64] training: accuracy=0.878916
# [Epoch 64] time cost: 13.718241
# [Epoch 64] validation: accuracy=0.848991
# Epoch[65] Batch [49]	Speed: 3770.796426 samples/sec	accuracy=0.878750
# Epoch[65] Batch [99]	Speed: 4105.396507 samples/sec	accuracy=0.876719
# Epoch[65] Batch [149]	Speed: 3982.249229 samples/sec	accuracy=0.878646
# Epoch[65] Batch [199]	Speed: 2626.480072 samples/sec	accuracy=0.877305
# Epoch[65] Batch [249]	Speed: 3793.953034 samples/sec	accuracy=0.877062
# Epoch[65] Batch [299]	Speed: 3807.784159 samples/sec	accuracy=0.876901
# Epoch[65] Batch [349]	Speed: 2017.545639 samples/sec	accuracy=0.878036
# [Epoch 65] training: accuracy=0.879076
# [Epoch 65] time cost: 13.763207
# [Epoch 65] validation: accuracy=0.847256
# Epoch[66] Batch [49]	Speed: 3978.088665 samples/sec	accuracy=0.887500
# Epoch[66] Batch [99]	Speed: 4049.747015 samples/sec	accuracy=0.883984
# Epoch[66] Batch [149]	Speed: 4021.625457 samples/sec	accuracy=0.883542
# Epoch[66] Batch [199]	Speed: 3892.484408 samples/sec	accuracy=0.880938
# Epoch[66] Batch [249]	Speed: 3596.739458 samples/sec	accuracy=0.879750
# Epoch[66] Batch [299]	Speed: 3696.999766 samples/sec	accuracy=0.879896
# Epoch[66] Batch [349]	Speed: 3865.968503 samples/sec	accuracy=0.881071
# [Epoch 66] training: accuracy=0.880789
# [Epoch 66] time cost: 13.341733
# [Epoch 66] validation: accuracy=0.847055
# Epoch[67] Batch [49]	Speed: 4155.379778 samples/sec	accuracy=0.884062
# Epoch[67] Batch [99]	Speed: 4072.386917 samples/sec	accuracy=0.880156
# Epoch[67] Batch [149]	Speed: 2505.464402 samples/sec	accuracy=0.879948
# Epoch[67] Batch [199]	Speed: 3847.213231 samples/sec	accuracy=0.878398
# Epoch[67] Batch [249]	Speed: 3716.912988 samples/sec	accuracy=0.879219
# Epoch[67] Batch [299]	Speed: 4026.994944 samples/sec	accuracy=0.880078
# Epoch[67] Batch [349]	Speed: 4064.155762 samples/sec	accuracy=0.881205
# [Epoch 67] training: accuracy=0.880854
# [Epoch 67] time cost: 13.057359
# [Epoch 67] validation: accuracy=0.835337
# Epoch[68] Batch [49]	Speed: 4089.821833 samples/sec	accuracy=0.881094
# Epoch[68] Batch [99]	Speed: 3981.038522 samples/sec	accuracy=0.879531
# Epoch[68] Batch [149]	Speed: 4079.535201 samples/sec	accuracy=0.880365
# Epoch[68] Batch [199]	Speed: 2620.109476 samples/sec	accuracy=0.881953
# Epoch[68] Batch [249]	Speed: 2360.536204 samples/sec	accuracy=0.881875
# Epoch[68] Batch [299]	Speed: 3919.481015 samples/sec	accuracy=0.881667
# Epoch[68] Batch [349]	Speed: 2994.444232 samples/sec	accuracy=0.882567
# [Epoch 68] training: accuracy=0.881953
# [Epoch 68] time cost: 13.897341
# [Epoch 68] validation: accuracy=0.848658
# Epoch[69] Batch [49]	Speed: 4115.214717 samples/sec	accuracy=0.881094
# Epoch[69] Batch [99]	Speed: 1811.935025 samples/sec	accuracy=0.876719
# Epoch[69] Batch [149]	Speed: 3801.717288 samples/sec	accuracy=0.878802
# Epoch[69] Batch [199]	Speed: 3708.517217 samples/sec	accuracy=0.879336
# Epoch[69] Batch [249]	Speed: 3571.258836 samples/sec	accuracy=0.878313
# Epoch[69] Batch [299]	Speed: 3868.698609 samples/sec	accuracy=0.878932
# Epoch[69] Batch [349]	Speed: 3889.382490 samples/sec	accuracy=0.880424
# [Epoch 69] training: accuracy=0.880108
# [Epoch 69] time cost: 13.494515
# [Epoch 69] validation: accuracy=0.840946
# Epoch[70] Batch [49]	Speed: 3734.832115 samples/sec	accuracy=0.887188
# Epoch[70] Batch [99]	Speed: 3729.902054 samples/sec	accuracy=0.884141
# Epoch[70] Batch [149]	Speed: 3885.582341 samples/sec	accuracy=0.884635
# Epoch[70] Batch [199]	Speed: 3476.647835 samples/sec	accuracy=0.884883
# Epoch[70] Batch [249]	Speed: 3703.196496 samples/sec	accuracy=0.883750
# Epoch[70] Batch [299]	Speed: 3925.097508 samples/sec	accuracy=0.883802
# Epoch[70] Batch [349]	Speed: 3902.841050 samples/sec	accuracy=0.883661
# [Epoch 70] training: accuracy=0.882932
# [Epoch 70] time cost: 13.473171
# [Epoch 70] validation: accuracy=0.843650
# Epoch[71] Batch [49]	Speed: 3914.137385 samples/sec	accuracy=0.892656
# Epoch[71] Batch [99]	Speed: 3863.186650 samples/sec	accuracy=0.884219
# Epoch[71] Batch [149]	Speed: 3968.385078 samples/sec	accuracy=0.884479
# Epoch[71] Batch [199]	Speed: 3950.979239 samples/sec	accuracy=0.882227
# Epoch[71] Batch [249]	Speed: 3598.282275 samples/sec	accuracy=0.882500
# Epoch[71] Batch [299]	Speed: 3805.247202 samples/sec	accuracy=0.882188
# Epoch[71] Batch [349]	Speed: 3668.905296 samples/sec	accuracy=0.884085
# [Epoch 71] training: accuracy=0.884716
# [Epoch 71] time cost: 13.773838
# [Epoch 71] validation: accuracy=0.832332
# Epoch[72] Batch [49]	Speed: 4040.329565 samples/sec	accuracy=0.881250
# Epoch[72] Batch [99]	Speed: 3803.521845 samples/sec	accuracy=0.878359
# Epoch[72] Batch [149]	Speed: 3028.190444 samples/sec	accuracy=0.879427
# Epoch[72] Batch [199]	Speed: 4036.289570 samples/sec	accuracy=0.880391
# Epoch[72] Batch [249]	Speed: 3007.343222 samples/sec	accuracy=0.880500
# Epoch[72] Batch [299]	Speed: 3104.610107 samples/sec	accuracy=0.881615
# Epoch[72] Batch [349]	Speed: 3780.461595 samples/sec	accuracy=0.882277
# [Epoch 72] training: accuracy=0.882013
# [Epoch 72] time cost: 14.297826
# [Epoch 72] validation: accuracy=0.836036
# Epoch[73] Batch [49]	Speed: 4016.090006 samples/sec	accuracy=0.882812
# Epoch[73] Batch [99]	Speed: 3860.547596 samples/sec	accuracy=0.884687
# Epoch[73] Batch [149]	Speed: 3929.723111 samples/sec	accuracy=0.885208
# Epoch[73] Batch [199]	Speed: 4024.398909 samples/sec	accuracy=0.883711
# Epoch[73] Batch [249]	Speed: 3793.202473 samples/sec	accuracy=0.882969
# Epoch[73] Batch [299]	Speed: 3988.224939 samples/sec	accuracy=0.882292
# Epoch[73] Batch [349]	Speed: 3810.594951 samples/sec	accuracy=0.883415
# [Epoch 73] training: accuracy=0.883652
# [Epoch 73] time cost: 13.465791
# [Epoch 73] validation: accuracy=0.828826
# Epoch[74] Batch [49]	Speed: 4097.938417 samples/sec	accuracy=0.879219
# Epoch[74] Batch [99]	Speed: 4106.526986 samples/sec	accuracy=0.877344
# Epoch[74] Batch [149]	Speed: 3556.543507 samples/sec	accuracy=0.877083
# Epoch[74] Batch [199]	Speed: 3991.189854 samples/sec	accuracy=0.875469
# Epoch[74] Batch [249]	Speed: 3907.926277 samples/sec	accuracy=0.876500
# Epoch[74] Batch [299]	Speed: 3064.419144 samples/sec	accuracy=0.877292
# Epoch[74] Batch [349]	Speed: 3999.574706 samples/sec	accuracy=0.879241
# [Epoch 74] training: accuracy=0.879908
# [Epoch 74] time cost: 13.191012
# [Epoch 74] validation: accuracy=0.849159
# Epoch[75] Batch [49]	Speed: 4143.865388 samples/sec	accuracy=0.880938
# Epoch[75] Batch [99]	Speed: 3998.323667 samples/sec	accuracy=0.877969
# Epoch[75] Batch [149]	Speed: 3673.775880 samples/sec	accuracy=0.879531
# Epoch[75] Batch [199]	Speed: 2243.215095 samples/sec	accuracy=0.879258
# Epoch[75] Batch [249]	Speed: 3058.832077 samples/sec	accuracy=0.879313
# Epoch[75] Batch [299]	Speed: 3934.273135 samples/sec	accuracy=0.880495
# Epoch[75] Batch [349]	Speed: 2674.578974 samples/sec	accuracy=0.881942
# [Epoch 75] training: accuracy=0.881674
# [Epoch 75] time cost: 13.902251
# [Epoch 75] validation: accuracy=0.822516
# Epoch[76] Batch [49]	Speed: 3825.229156 samples/sec	accuracy=0.877812
# Epoch[76] Batch [99]	Speed: 4099.816052 samples/sec	accuracy=0.883281
# Epoch[76] Batch [149]	Speed: 3941.725613 samples/sec	accuracy=0.882552
# Epoch[76] Batch [199]	Speed: 3860.825221 samples/sec	accuracy=0.881484
# Epoch[76] Batch [249]	Speed: 3878.032289 samples/sec	accuracy=0.880188
# Epoch[76] Batch [299]	Speed: 2346.576592 samples/sec	accuracy=0.880885
# Epoch[76] Batch [349]	Speed: 3434.654929 samples/sec	accuracy=0.881830
# [Epoch 76] training: accuracy=0.882373
# [Epoch 76] time cost: 13.659685
# [Epoch 76] validation: accuracy=0.840445
# Epoch[77] Batch [49]	Speed: 3807.163102 samples/sec	accuracy=0.887969
# Epoch[77] Batch [99]	Speed: 2911.889614 samples/sec	accuracy=0.882578
# Epoch[77] Batch [149]	Speed: 2816.549301 samples/sec	accuracy=0.882083
# Epoch[77] Batch [199]	Speed: 3999.098028 samples/sec	accuracy=0.882266
# Epoch[77] Batch [249]	Speed: 3925.126205 samples/sec	accuracy=0.882281
# Epoch[77] Batch [299]	Speed: 3892.569075 samples/sec	accuracy=0.882656
# Epoch[77] Batch [349]	Speed: 2397.687091 samples/sec	accuracy=0.883371
# [Epoch 77] training: accuracy=0.882973
# [Epoch 77] time cost: 13.581352
# [Epoch 77] validation: accuracy=0.832632
# Epoch[78] Batch [49]	Speed: 3838.850442 samples/sec	accuracy=0.890781
# Epoch[78] Batch [99]	Speed: 3909.576849 samples/sec	accuracy=0.884609
# Epoch[78] Batch [149]	Speed: 4149.021322 samples/sec	accuracy=0.884896
# Epoch[78] Batch [199]	Speed: 3749.569862 samples/sec	accuracy=0.886289
# Epoch[78] Batch [249]	Speed: 4051.427864 samples/sec	accuracy=0.885375
# Epoch[78] Batch [299]	Speed: 2525.156094 samples/sec	accuracy=0.884609
# Epoch[78] Batch [349]	Speed: 3980.300648 samples/sec	accuracy=0.884375
# [Epoch 78] training: accuracy=0.885410
# [Epoch 78] time cost: 13.368570
# [Epoch 78] validation: accuracy=0.828726
# Epoch[79] Batch [49]	Speed: 3805.301145 samples/sec	accuracy=0.886563
# Epoch[79] Batch [99]	Speed: 3280.083286 samples/sec	accuracy=0.885625
# Epoch[79] Batch [149]	Speed: 3892.202211 samples/sec	accuracy=0.886302
# Epoch[79] Batch [199]	Speed: 3847.378653 samples/sec	accuracy=0.883047
# Epoch[79] Batch [249]	Speed: 3930.356028 samples/sec	accuracy=0.883062
# Epoch[79] Batch [299]	Speed: 3670.410282 samples/sec	accuracy=0.882604
# Epoch[79] Batch [349]	Speed: 3809.702616 samples/sec	accuracy=0.883594
# [Epoch 79] training: accuracy=0.883834
# [Epoch 79] time cost: 13.628694
# [Epoch 79] validation: accuracy=0.846354
# Epoch[80] Batch [49]	Speed: 4065.048171 samples/sec	accuracy=0.885625
# Epoch[80] Batch [99]	Speed: 3964.751106 samples/sec	accuracy=0.883125
# Epoch[80] Batch [149]	Speed: 3942.912523 samples/sec	accuracy=0.883698
# Epoch[80] Batch [199]	Speed: 3975.466967 samples/sec	accuracy=0.884414
# Epoch[80] Batch [249]	Speed: 3877.836211 samples/sec	accuracy=0.885094
# Epoch[80] Batch [299]	Speed: 4017.953509 samples/sec	accuracy=0.885599
# Epoch[80] Batch [349]	Speed: 3511.645585 samples/sec	accuracy=0.886786
# [Epoch 80] training: accuracy=0.886909
# [Epoch 80] time cost: 13.075113
# [Epoch 80] validation: accuracy=0.834949
# Epoch[81] Batch [49]	Speed: 3506.668269 samples/sec	accuracy=0.885156
# Epoch[81] Batch [99]	Speed: 3675.611976 samples/sec	accuracy=0.884766
# Epoch[81] Batch [149]	Speed: 3925.728935 samples/sec	accuracy=0.883073
# Epoch[81] Batch [199]	Speed: 2353.561492 samples/sec	accuracy=0.883828
# Epoch[81] Batch [249]	Speed: 3588.181631 samples/sec	accuracy=0.883844
# Epoch[81] Batch [299]	Speed: 3903.664015 samples/sec	accuracy=0.882891
# Epoch[81] Batch [349]	Speed: 4068.066802 samples/sec	accuracy=0.883460
# [Epoch 81] training: accuracy=0.883632
# [Epoch 81] time cost: 13.477776
# [Epoch 81] validation: accuracy=0.826222
# Epoch[82] Batch [49]	Speed: 3649.477000 samples/sec	accuracy=0.881719
# Epoch[82] Batch [99]	Speed: 4037.928894 samples/sec	accuracy=0.878672
# Epoch[82] Batch [149]	Speed: 3853.813551 samples/sec	accuracy=0.881875
# Epoch[82] Batch [199]	Speed: 4032.802848 samples/sec	accuracy=0.880586
# Epoch[82] Batch [249]	Speed: 2630.185882 samples/sec	accuracy=0.881094
# Epoch[82] Batch [299]	Speed: 2441.765189 samples/sec	accuracy=0.882370
# Epoch[82] Batch [349]	Speed: 3987.217872 samples/sec	accuracy=0.882589
# [Epoch 82] training: accuracy=0.883494
# [Epoch 82] time cost: 13.735600
# [Epoch 82] validation: accuracy=0.821815
# Epoch[83] Batch [49]	Speed: 4001.870314 samples/sec	accuracy=0.885781
# Epoch[83] Batch [99]	Speed: 4076.097182 samples/sec	accuracy=0.882266
# Epoch[83] Batch [149]	Speed: 3260.382668 samples/sec	accuracy=0.883646
# Epoch[83] Batch [199]	Speed: 4028.324444 samples/sec	accuracy=0.884414
# Epoch[83] Batch [249]	Speed: 3661.398841 samples/sec	accuracy=0.882687
# Epoch[83] Batch [299]	Speed: 3750.093684 samples/sec	accuracy=0.883177
# Epoch[83] Batch [349]	Speed: 2995.981585 samples/sec	accuracy=0.883951
# [Epoch 83] training: accuracy=0.883332
# [Epoch 83] time cost: 13.914133
# [Epoch 83] validation: accuracy=0.833934
# Epoch[84] Batch [49]	Speed: 4019.216865 samples/sec	accuracy=0.888594
# Epoch[84] Batch [99]	Speed: 3944.389920 samples/sec	accuracy=0.882969
# Epoch[84] Batch [149]	Speed: 3960.305629 samples/sec	accuracy=0.886458
# Epoch[84] Batch [199]	Speed: 3873.331881 samples/sec	accuracy=0.884727
# Epoch[84] Batch [249]	Speed: 2456.288201 samples/sec	accuracy=0.885406
# Epoch[84] Batch [299]	Speed: 2497.155312 samples/sec	accuracy=0.885729
# Epoch[84] Batch [349]	Speed: 3803.333229 samples/sec	accuracy=0.885804
# [Epoch 84] training: accuracy=0.886049
# [Epoch 84] time cost: 14.147071
# [Epoch 84] validation: accuracy=0.847256
# Epoch[85] Batch [49]	Speed: 3860.408798 samples/sec	accuracy=0.879687
# Epoch[85] Batch [99]	Speed: 3863.103257 samples/sec	accuracy=0.882578
# Epoch[85] Batch [149]	Speed: 3932.256002 samples/sec	accuracy=0.885521
# Epoch[85] Batch [199]	Speed: 3356.492104 samples/sec	accuracy=0.885352
# Epoch[85] Batch [249]	Speed: 3501.796403 samples/sec	accuracy=0.884844
# Epoch[85] Batch [299]	Speed: 3846.524127 samples/sec	accuracy=0.884714
# Epoch[85] Batch [349]	Speed: 4003.720642 samples/sec	accuracy=0.885804
# [Epoch 85] training: accuracy=0.885958
# [Epoch 85] time cost: 13.795506
# [Epoch 85] validation: accuracy=0.830529
# Epoch[86] Batch [49]	Speed: 2334.485255 samples/sec	accuracy=0.884375
# Epoch[86] Batch [99]	Speed: 3841.404933 samples/sec	accuracy=0.883594
# Epoch[86] Batch [149]	Speed: 4039.599946 samples/sec	accuracy=0.883125
# Epoch[86] Batch [199]	Speed: 3998.502339 samples/sec	accuracy=0.881797
# Epoch[86] Batch [249]	Speed: 3854.090209 samples/sec	accuracy=0.882313
# Epoch[86] Batch [299]	Speed: 3935.917187 samples/sec	accuracy=0.882917
# ...
# Epoch[224] Batch [99]	Speed: 3646.378635 samples/sec	accuracy=0.987187
# Epoch[224] Batch [149]	Speed: 3849.364824 samples/sec	accuracy=0.987656
# Epoch[224] Batch [199]	Speed: 3998.651244 samples/sec	accuracy=0.986875
# Epoch[224] Batch [249]	Speed: 3695.930827 samples/sec	accuracy=0.987094
# Epoch[224] Batch [299]	Speed: 3838.301533 samples/sec	accuracy=0.987214
# Epoch[224] Batch [349]	Speed: 3946.332498 samples/sec	accuracy=0.987344
# [Epoch 224] training: accuracy=0.987132
# [Epoch 224] time cost: 13.454503
# [Epoch 224] validation: accuracy=0.912480
# Epoch[225] Batch [49]	Speed: 3833.751639 samples/sec	accuracy=0.987187
# Epoch[225] Batch [99]	Speed: 3891.525105 samples/sec	accuracy=0.987656
# Epoch[225] Batch [149]	Speed: 3741.938693 samples/sec	accuracy=0.987135
# Epoch[225] Batch [199]	Speed: 3749.308006 samples/sec	accuracy=0.987500
# Epoch[225] Batch [249]	Speed: 3722.841079 samples/sec	accuracy=0.987219
# Epoch[225] Batch [299]	Speed: 3810.838387 samples/sec	accuracy=0.987500
# Epoch[225] Batch [349]	Speed: 1966.106400 samples/sec	accuracy=0.987656
# [Epoch 225] training: accuracy=0.987552
# [Epoch 225] time cost: 14.033943
# [Epoch 225] validation: accuracy=0.913562
# Epoch[226] Batch [49]	Speed: 3483.098770 samples/sec	accuracy=0.987500
# Epoch[226] Batch [99]	Speed: 3901.649785 samples/sec	accuracy=0.987422
# Epoch[226] Batch [149]	Speed: 3872.493721 samples/sec	accuracy=0.987969
# Epoch[226] Batch [199]	Speed: 3903.891101 samples/sec	accuracy=0.987695
# Epoch[226] Batch [249]	Speed: 3931.708852 samples/sec	accuracy=0.987531
# Epoch[226] Batch [299]	Speed: 3733.533467 samples/sec	accuracy=0.987292
# Epoch[226] Batch [349]	Speed: 3915.650410 samples/sec	accuracy=0.987277
# [Epoch 226] training: accuracy=0.987099
# [Epoch 226] time cost: 13.510834
# [Epoch 226] validation: accuracy=0.911158
# Epoch[227] Batch [49]	Speed: 3883.249637 samples/sec	accuracy=0.989531
# Epoch[227] Batch [99]	Speed: 4046.419994 samples/sec	accuracy=0.988828
# Epoch[227] Batch [149]	Speed: 3342.282961 samples/sec	accuracy=0.988698
# Epoch[227] Batch [199]	Speed: 4101.789421 samples/sec	accuracy=0.988398
# Epoch[227] Batch [249]	Speed: 3534.487060 samples/sec	accuracy=0.988437
# Epoch[227] Batch [299]	Speed: 3855.335660 samples/sec	accuracy=0.988281
# Epoch[227] Batch [349]	Speed: 3783.205519 samples/sec	accuracy=0.988393
# [Epoch 227] training: accuracy=0.988131
# [Epoch 227] time cost: 13.269480
# [Epoch 227] validation: accuracy=0.913462
# Epoch[228] Batch [49]	Speed: 3779.237438 samples/sec	accuracy=0.989219
# Epoch[228] Batch [99]	Speed: 3974.525178 samples/sec	accuracy=0.989297
# Epoch[228] Batch [149]	Speed: 3899.750937 samples/sec	accuracy=0.989115
# Epoch[228] Batch [199]	Speed: 3698.145743 samples/sec	accuracy=0.988555
# Epoch[228] Batch [249]	Speed: 3569.383100 samples/sec	accuracy=0.988500
# Epoch[228] Batch [299]	Speed: 4019.848841 samples/sec	accuracy=0.988281
# Epoch[228] Batch [349]	Speed: 2585.336184 samples/sec	accuracy=0.988393
# [Epoch 228] training: accuracy=0.988491
# [Epoch 228] time cost: 14.187026
# [Epoch 228] validation: accuracy=0.912360
# Epoch[229] Batch [49]	Speed: 3316.556574 samples/sec	accuracy=0.987031
# Epoch[229] Batch [99]	Speed: 3424.795305 samples/sec	accuracy=0.987734
# Epoch[229] Batch [149]	Speed: 3984.347560 samples/sec	accuracy=0.987344
# Epoch[229] Batch [199]	Speed: 2950.034684 samples/sec	accuracy=0.986992
# Epoch[229] Batch [249]	Speed: 3783.845452 samples/sec	accuracy=0.987313
# Epoch[229] Batch [299]	Speed: 4164.114172 samples/sec	accuracy=0.987552
# Epoch[229] Batch [349]	Speed: 4178.536553 samples/sec	accuracy=0.987656
# [Epoch 229] training: accuracy=0.987740
# [Epoch 229] time cost: 13.472111
# [Epoch 229] validation: accuracy=0.911859
# Epoch[230] Batch [49]	Speed: 3769.260935 samples/sec	accuracy=0.990469
# Epoch[230] Batch [99]	Speed: 3834.655277 samples/sec	accuracy=0.989609
# Epoch[230] Batch [149]	Speed: 3805.085383 samples/sec	accuracy=0.988073
# Epoch[230] Batch [199]	Speed: 4115.120088 samples/sec	accuracy=0.987500
# Epoch[230] Batch [249]	Speed: 3877.276097 samples/sec	accuracy=0.987531
# Epoch[230] Batch [299]	Speed: 3927.911795 samples/sec	accuracy=0.987266
# Epoch[230] Batch [349]	Speed: 3564.335540 samples/sec	accuracy=0.987746
# [Epoch 230] training: accuracy=0.987712
# [Epoch 230] time cost: 13.685243
# [Epoch 230] validation: accuracy=0.912760
# Epoch[231] Batch [49]	Speed: 3712.158424 samples/sec	accuracy=0.989375
# Epoch[231] Batch [99]	Speed: 4035.106441 samples/sec	accuracy=0.988594
# Epoch[231] Batch [149]	Speed: 3940.915452 samples/sec	accuracy=0.988385
# Epoch[231] Batch [199]	Speed: 3958.845479 samples/sec	accuracy=0.988008
# Epoch[231] Batch [249]	Speed: 1981.877928 samples/sec	accuracy=0.988031
# Epoch[231] Batch [299]	Speed: 3835.449734 samples/sec	accuracy=0.988125
# Epoch[231] Batch [349]	Speed: 3776.950923 samples/sec	accuracy=0.988504
# [Epoch 231] training: accuracy=0.988321
# [Epoch 231] time cost: 13.527256
# [Epoch 231] validation: accuracy=0.911358
# Epoch[232] Batch [49]	Speed: 3772.015120 samples/sec	accuracy=0.983906
# Epoch[232] Batch [99]	Speed: 3879.545558 samples/sec	accuracy=0.986016
# Epoch[232] Batch [149]	Speed: 3206.826820 samples/sec	accuracy=0.986458
# Epoch[232] Batch [199]	Speed: 4025.123047 samples/sec	accuracy=0.986641
# Epoch[232] Batch [249]	Speed: 3759.889851 samples/sec	accuracy=0.987156
# Epoch[232] Batch [299]	Speed: 3873.192162 samples/sec	accuracy=0.987161
# Epoch[232] Batch [349]	Speed: 2694.026114 samples/sec	accuracy=0.987299
# [Epoch 232] training: accuracy=0.987232
# [Epoch 232] time cost: 13.715734
# [Epoch 232] validation: accuracy=0.912777
# Epoch[233] Batch [49]	Speed: 3583.846198 samples/sec	accuracy=0.990938
# Epoch[233] Batch [99]	Speed: 4008.114554 samples/sec	accuracy=0.989141
# Epoch[233] Batch [149]	Speed: 3720.390229 samples/sec	accuracy=0.988802
# Epoch[233] Batch [199]	Speed: 4076.344773 samples/sec	accuracy=0.988320
# Epoch[233] Batch [249]	Speed: 3616.047202 samples/sec	accuracy=0.988250
# Epoch[233] Batch [299]	Speed: 3909.605319 samples/sec	accuracy=0.988099
# Epoch[233] Batch [349]	Speed: 3725.734653 samples/sec	accuracy=0.987946
# [Epoch 233] training: accuracy=0.988031
# [Epoch 233] time cost: 13.380625
# [Epoch 233] validation: accuracy=0.912059
# Epoch[234] Batch [49]	Speed: 4121.058622 samples/sec	accuracy=0.987187
# Epoch[234] Batch [99]	Speed: 4024.368742 samples/sec	accuracy=0.986563
# Epoch[234] Batch [149]	Speed: 2803.766996 samples/sec	accuracy=0.987292
# Epoch[234] Batch [199]	Speed: 4105.082595 samples/sec	accuracy=0.987695
# Epoch[234] Batch [249]	Speed: 3890.425311 samples/sec	accuracy=0.987812
# Epoch[234] Batch [299]	Speed: 2173.733656 samples/sec	accuracy=0.987682
# Epoch[234] Batch [349]	Speed: 4156.988533 samples/sec	accuracy=0.987835
# [Epoch 234] training: accuracy=0.987700
# [Epoch 234] time cost: 13.006138
# [Epoch 234] validation: accuracy=0.912660
# Epoch[235] Batch [49]	Speed: 4024.851465 samples/sec	accuracy=0.988125
# Epoch[235] Batch [99]	Speed: 3973.966202 samples/sec	accuracy=0.987578
# Epoch[235] Batch [149]	Speed: 3923.261782 samples/sec	accuracy=0.988177
# Epoch[235] Batch [199]	Speed: 3974.848868 samples/sec	accuracy=0.987617
# Epoch[235] Batch [249]	Speed: 3723.848153 samples/sec	accuracy=0.987406
# Epoch[235] Batch [299]	Speed: 3841.102611 samples/sec	accuracy=0.987318
# Epoch[235] Batch [349]	Speed: 3874.477953 samples/sec	accuracy=0.987500
# [Epoch 235] training: accuracy=0.987732
# [Epoch 235] time cost: 13.529035
# [Epoch 235] validation: accuracy=0.911659
# Epoch[236] Batch [49]	Speed: 3724.623195 samples/sec	accuracy=0.988750
# Epoch[236] Batch [99]	Speed: 3720.467575 samples/sec	accuracy=0.988359
# Epoch[236] Batch [149]	Speed: 2823.541014 samples/sec	accuracy=0.987969
# Epoch[236] Batch [199]	Speed: 3250.965303 samples/sec	accuracy=0.988008
# Epoch[236] Batch [249]	Speed: 2816.061769 samples/sec	accuracy=0.987844
# Epoch[236] Batch [299]	Speed: 3859.437494 samples/sec	accuracy=0.987370
# Epoch[236] Batch [349]	Speed: 3940.394809 samples/sec	accuracy=0.987857
# [Epoch 236] training: accuracy=0.987972
# [Epoch 236] time cost: 13.742738
# [Epoch 236] validation: accuracy=0.913762
# Epoch[237] Batch [49]	Speed: 3817.857304 samples/sec	accuracy=0.989219
# Epoch[237] Batch [99]	Speed: 3997.311493 samples/sec	accuracy=0.988516
# Epoch[237] Batch [149]	Speed: 3271.927257 samples/sec	accuracy=0.989219
# Epoch[237] Batch [199]	Speed: 4053.201909 samples/sec	accuracy=0.988555
# Epoch[237] Batch [249]	Speed: 3821.172478 samples/sec	accuracy=0.988062
# Epoch[237] Batch [299]	Speed: 2730.472236 samples/sec	accuracy=0.987891
# Epoch[237] Batch [349]	Speed: 4051.855940 samples/sec	accuracy=0.987812
# [Epoch 237] training: accuracy=0.987700
# [Epoch 237] time cost: 13.182709
# [Epoch 237] validation: accuracy=0.913261
# Epoch[238] Batch [49]	Speed: 4074.890604 samples/sec	accuracy=0.988281
# Epoch[238] Batch [99]	Speed: 3990.388893 samples/sec	accuracy=0.989297
# Epoch[238] Batch [149]	Speed: 3990.062667 samples/sec	accuracy=0.989010
# Epoch[238] Batch [199]	Speed: 4075.787735 samples/sec	accuracy=0.988711
# Epoch[238] Batch [249]	Speed: 3755.839125 samples/sec	accuracy=0.987969
# Epoch[238] Batch [299]	Speed: 4008.024786 samples/sec	accuracy=0.987500
# Epoch[238] Batch [349]	Speed: 4043.798861 samples/sec	accuracy=0.987857
# [Epoch 238] training: accuracy=0.987852
# [Epoch 238] time cost: 13.623228
# [Epoch 238] validation: accuracy=0.913462
# Epoch[239] Batch [49]	Speed: 3988.017560 samples/sec	accuracy=0.988281
# Epoch[239] Batch [99]	Speed: 3927.825583 samples/sec	accuracy=0.988047
# Epoch[239] Batch [149]	Speed: 4050.052520 samples/sec	accuracy=0.987865
# Epoch[239] Batch [199]	Speed: 4145.881401 samples/sec	accuracy=0.987578
# Epoch[239] Batch [249]	Speed: 3865.050049 samples/sec	accuracy=0.987313
# Epoch[239] Batch [299]	Speed: 3814.385267 samples/sec	accuracy=0.987318
# Epoch[239] Batch [349]	Speed: 3854.948100 samples/sec	accuracy=0.987455
# [Epoch 239] training: accuracy=0.987780
# [Epoch 239] time cost: 13.019986
# [Epoch 239] validation: accuracy=0.913662
# Epoch[240] Batch [49]	Speed: 4016.931374 samples/sec	accuracy=0.990625
# Epoch[240] Batch [99]	Speed: 2877.831148 samples/sec	accuracy=0.989844
# Epoch[240] Batch [149]	Speed: 3697.636332 samples/sec	accuracy=0.988750
# Epoch[240] Batch [199]	Speed: 3740.166028 samples/sec	accuracy=0.988047
# Epoch[240] Batch [249]	Speed: 2727.074177 samples/sec	accuracy=0.987844
# Epoch[240] Batch [299]	Speed: 3997.698440 samples/sec	accuracy=0.988021
# Epoch[240] Batch [349]	Speed: 3876.408240 samples/sec	accuracy=0.988170
# [Epoch 240] training: accuracy=0.988271
# [Epoch 240] time cost: 13.779610
# [Epoch 240] validation: accuracy=0.912085
# Epoch[241] Batch [49]	Speed: 3819.785927 samples/sec	accuracy=0.988125
# Epoch[241] Batch [99]	Speed: 3806.353332 samples/sec	accuracy=0.987656
# Epoch[241] Batch [149]	Speed: 3893.670083 samples/sec	accuracy=0.987865
# Epoch[241] Batch [199]	Speed: 4043.768403 samples/sec	accuracy=0.987656
# Epoch[241] Batch [249]	Speed: 3691.889726 samples/sec	accuracy=0.987812
# Epoch[241] Batch [299]	Speed: 2469.280250 samples/sec	accuracy=0.988255
# Epoch[241] Batch [349]	Speed: 3779.849417 samples/sec	accuracy=0.988616
# [Epoch 241] training: accuracy=0.988571
# [Epoch 241] time cost: 13.687999
# [Epoch 241] validation: accuracy=0.913061
# Epoch[242] Batch [49]	Speed: 3875.484819 samples/sec	accuracy=0.988125
# Epoch[242] Batch [99]	Speed: 3800.694569 samples/sec	accuracy=0.988203
# Epoch[242] Batch [149]	Speed: 4135.820907 samples/sec	accuracy=0.987969
# Epoch[242] Batch [199]	Speed: 4128.442442 samples/sec	accuracy=0.988125
# Epoch[242] Batch [249]	Speed: 2355.368469 samples/sec	accuracy=0.988125
# Epoch[242] Batch [299]	Speed: 3503.304548 samples/sec	accuracy=0.988437
# Epoch[242] Batch [349]	Speed: 4021.836346 samples/sec	accuracy=0.988482
# [Epoch 242] training: accuracy=0.988281
# [Epoch 242] time cost: 13.715631
# [Epoch 242] validation: accuracy=0.912059
# Epoch[243] Batch [49]	Speed: 3184.079995 samples/sec	accuracy=0.987656
# Epoch[243] Batch [99]	Speed: 3308.157228 samples/sec	accuracy=0.988125
# Epoch[243] Batch [149]	Speed: 2972.493187 samples/sec	accuracy=0.988073
# Epoch[243] Batch [199]	Speed: 4075.818677 samples/sec	accuracy=0.988047
# Epoch[243] Batch [249]	Speed: 3279.983089 samples/sec	accuracy=0.988594
# Epoch[243] Batch [299]	Speed: 3756.522401 samples/sec	accuracy=0.988672
# Epoch[243] Batch [349]	Speed: 3915.393398 samples/sec	accuracy=0.989040
# [Epoch 243] training: accuracy=0.988971
# [Epoch 243] time cost: 13.845931
# [Epoch 243] validation: accuracy=0.913161
# Epoch[244] Batch [49]	Speed: 3087.115021 samples/sec	accuracy=0.989688
# Epoch[244] Batch [99]	Speed: 3996.924621 samples/sec	accuracy=0.989453
# Epoch[244] Batch [149]	Speed: 3791.514795 samples/sec	accuracy=0.988854
# Epoch[244] Batch [199]	Speed: 3778.572468 samples/sec	accuracy=0.989297
# Epoch[244] Batch [249]	Speed: 3222.379084 samples/sec	accuracy=0.989125
# Epoch[244] Batch [299]	Speed: 3944.563804 samples/sec	accuracy=0.988906
# Epoch[244] Batch [349]	Speed: 2915.289193 samples/sec	accuracy=0.988638
# [Epoch 244] training: accuracy=0.988751
# [Epoch 244] time cost: 14.215833
# [Epoch 244] validation: accuracy=0.912360
# Epoch[245] Batch [49]	Speed: 3747.371407 samples/sec	accuracy=0.990000
# Epoch[245] Batch [99]	Speed: 4095.968750 samples/sec	accuracy=0.987969
# Epoch[245] Batch [149]	Speed: 3978.324493 samples/sec	accuracy=0.987969
# Epoch[245] Batch [199]	Speed: 3791.488019 samples/sec	accuracy=0.988555
# Epoch[245] Batch [249]	Speed: 3731.665001 samples/sec	accuracy=0.988594
# Epoch[245] Batch [299]	Speed: 3928.199194 samples/sec	accuracy=0.988854
# Epoch[245] Batch [349]	Speed: 4031.500665 samples/sec	accuracy=0.988839
# [Epoch 245] training: accuracy=0.988962
# [Epoch 245] time cost: 13.842251
# [Epoch 245] validation: accuracy=0.913462
# Epoch[246] Batch [49]	Speed: 3737.328052 samples/sec	accuracy=0.987656
# Epoch[246] Batch [99]	Speed: 3929.579295 samples/sec	accuracy=0.987500
# Epoch[246] Batch [149]	Speed: 3912.711075 samples/sec	accuracy=0.988125
# Epoch[246] Batch [199]	Speed: 3028.976343 samples/sec	accuracy=0.988516
# Epoch[246] Batch [249]	Speed: 3695.523775 samples/sec	accuracy=0.988594
# Epoch[246] Batch [299]	Speed: 3991.664649 samples/sec	accuracy=0.988177
# Epoch[246] Batch [349]	Speed: 4009.132206 samples/sec	accuracy=0.988437
# [Epoch 246] training: accuracy=0.988671
# [Epoch 246] time cost: 13.382385
# [Epoch 246] validation: accuracy=0.913662
# Epoch[247] Batch [49]	Speed: 3904.714509 samples/sec	accuracy=0.989375
# Epoch[247] Batch [99]	Speed: 2869.801108 samples/sec	accuracy=0.988437
# Epoch[247] Batch [149]	Speed: 3864.910927 samples/sec	accuracy=0.988021
# Epoch[247] Batch [199]	Speed: 3935.167098 samples/sec	accuracy=0.987734
# Epoch[247] Batch [249]	Speed: 3688.465532 samples/sec	accuracy=0.988031
# Epoch[247] Batch [299]	Speed: 2315.126595 samples/sec	accuracy=0.988047
# Epoch[247] Batch [349]	Speed: 3890.002478 samples/sec	accuracy=0.988304
# [Epoch 247] training: accuracy=0.988401
# [Epoch 247] time cost: 13.451901
# [Epoch 247] validation: accuracy=0.913061
# Epoch[248] Batch [49]	Speed: 4114.930842 samples/sec	accuracy=0.988125
# Epoch[248] Batch [99]	Speed: 3998.383222 samples/sec	accuracy=0.988594
# Epoch[248] Batch [149]	Speed: 3965.219631 samples/sec	accuracy=0.988594
# Epoch[248] Batch [199]	Speed: 3386.557194 samples/sec	accuracy=0.989062
# Epoch[248] Batch [249]	Speed: 3882.659878 samples/sec	accuracy=0.989000
# Epoch[248] Batch [299]	Speed: 4050.571985 samples/sec	accuracy=0.989271
# Epoch[248] Batch [349]	Speed: 3057.072886 samples/sec	accuracy=0.989263
# [Epoch 248] training: accuracy=0.988891
# [Epoch 248] time cost: 13.338642
# [Epoch 248] validation: accuracy=0.913469
# Epoch[249] Batch [49]	Speed: 3196.611563 samples/sec	accuracy=0.990625
# Epoch[249] Batch [99]	Speed: 2727.517525 samples/sec	accuracy=0.990703
# Epoch[249] Batch [149]	Speed: 3851.656984 samples/sec	accuracy=0.989896
# Epoch[249] Batch [199]	Speed: 4098.814433 samples/sec	accuracy=0.989570
# Epoch[249] Batch [249]	Speed: 3799.107752 samples/sec	accuracy=0.989500
# Epoch[249] Batch [299]	Speed: 3805.894614 samples/sec	accuracy=0.989167
# Epoch[249] Batch [349]	Speed: 3747.292938 samples/sec	accuracy=0.989420
# [Epoch 249] training: accuracy=0.989170
# [Epoch 249] time cost: 13.792157
# [Epoch 249] validation: accuracy=0.913662

# %% [markdown]
# The training should have led to a similar validation accuracy as reported in [3], Sec. 4.2. We next activate quantization for $W_B$, $W_C$ (by setting `sp_mode` to 2) and continue training for 40 epochs.

# %%
initialize_by_key(sp_resnet, 'sp_mode', mx.init.Constant(2), ctx, True)

epochs = 40
learning_rate = 0.01
scheduler = mx.lr_scheduler.MultiFactorScheduler([10*schedule_factor, 20*schedule_factor, 30*schedule_factor, 40*schedule_factor], factor=0.1)

train(sp_resnet, learning_rate, momentum, weight_decay, epochs, scheduler, ctx, train_data, val_data, log_interval)
# Out:
# Epoch[0] Batch [49]	Speed: 1015.650668 samples/sec	accuracy=0.752188
# Epoch[0] Batch [99]	Speed: 929.617626 samples/sec	accuracy=0.793750
# Epoch[0] Batch [149]	Speed: 1117.950040 samples/sec	accuracy=0.815729
# Epoch[0] Batch [199]	Speed: 1347.828049 samples/sec	accuracy=0.829961
# Epoch[0] Batch [249]	Speed: 1122.817951 samples/sec	accuracy=0.841406
# Epoch[0] Batch [299]	Speed: 1005.670031 samples/sec	accuracy=0.848385
# Epoch[0] Batch [349]	Speed: 1155.652136 samples/sec	accuracy=0.854799
# [Epoch 0] training: accuracy=0.859135
# [Epoch 0] time cost: 48.579850
# [Epoch 0] validation: accuracy=0.852264
# Epoch[1] Batch [49]	Speed: 1139.712970 samples/sec	accuracy=0.900312
# Epoch[1] Batch [99]	Speed: 851.494855 samples/sec	accuracy=0.899609
# Epoch[1] Batch [149]	Speed: 1065.097493 samples/sec	accuracy=0.897292
# Epoch[1] Batch [199]	Speed: 1061.093588 samples/sec	accuracy=0.895664
# Epoch[1] Batch [249]	Speed: 1176.695632 samples/sec	accuracy=0.896156
# Epoch[1] Batch [299]	Speed: 1138.280025 samples/sec	accuracy=0.897917
# Epoch[1] Batch [349]	Speed: 845.689745 samples/sec	accuracy=0.898326
# [Epoch 1] training: accuracy=0.898557
# [Epoch 1] time cost: 48.327556
# [Epoch 1] validation: accuracy=0.862280
# Epoch[2] Batch [49]	Speed: 1064.630714 samples/sec	accuracy=0.903906
# Epoch[2] Batch [99]	Speed: 1264.171573 samples/sec	accuracy=0.905937
# Epoch[2] Batch [149]	Speed: 1070.118403 samples/sec	accuracy=0.905885
# Epoch[2] Batch [199]	Speed: 822.698628 samples/sec	accuracy=0.905039
# Epoch[2] Batch [249]	Speed: 1046.717667 samples/sec	accuracy=0.904625
# Epoch[2] Batch [299]	Speed: 1004.349321 samples/sec	accuracy=0.905729
# Epoch[2] Batch [349]	Speed: 1041.286991 samples/sec	accuracy=0.906518
# [Epoch 2] training: accuracy=0.906310
# [Epoch 2] time cost: 48.396528
# [Epoch 2] validation: accuracy=0.853065
# Epoch[3] Batch [49]	Speed: 840.248523 samples/sec	accuracy=0.912031
# Epoch[3] Batch [99]	Speed: 1138.746001 samples/sec	accuracy=0.911875
# Epoch[3] Batch [149]	Speed: 1093.692971 samples/sec	accuracy=0.910885
# Epoch[3] Batch [199]	Speed: 1058.678940 samples/sec	accuracy=0.909531
# Epoch[3] Batch [249]	Speed: 1239.892360 samples/sec	accuracy=0.907844
# Epoch[3] Batch [299]	Speed: 1152.427252 samples/sec	accuracy=0.907031
# Epoch[3] Batch [349]	Speed: 816.573448 samples/sec	accuracy=0.907478
# [Epoch 3] training: accuracy=0.907452
# [Epoch 3] time cost: 48.224097
# [Epoch 3] validation: accuracy=0.858173
# Epoch[4] Batch [49]	Speed: 1244.658302 samples/sec	accuracy=0.909219
# Epoch[4] Batch [99]	Speed: 937.351549 samples/sec	accuracy=0.910625
# Epoch[4] Batch [149]	Speed: 1069.414971 samples/sec	accuracy=0.910625
# Epoch[4] Batch [199]	Speed: 961.796416 samples/sec	accuracy=0.909375
# Epoch[4] Batch [249]	Speed: 1076.694119 samples/sec	accuracy=0.910062
# Epoch[4] Batch [299]	Speed: 711.806650 samples/sec	accuracy=0.909609
# Epoch[4] Batch [349]	Speed: 1077.487169 samples/sec	accuracy=0.909554
# [Epoch 4] training: accuracy=0.909966
# [Epoch 4] time cost: 48.294883
# [Epoch 4] validation: accuracy=0.856771
# Epoch[5] Batch [49]	Speed: 1126.883391 samples/sec	accuracy=0.908125
# Epoch[5] Batch [99]	Speed: 984.954120 samples/sec	accuracy=0.906328
# Epoch[5] Batch [149]	Speed: 1106.783746 samples/sec	accuracy=0.907552
# Epoch[5] Batch [199]	Speed: 1150.306205 samples/sec	accuracy=0.908398
# Epoch[5] Batch [249]	Speed: 1037.706430 samples/sec	accuracy=0.910156
# Epoch[5] Batch [299]	Speed: 1203.786926 samples/sec	accuracy=0.909948
# Epoch[5] Batch [349]	Speed: 1022.589835 samples/sec	accuracy=0.910714
# [Epoch 5] training: accuracy=0.910216
# [Epoch 5] time cost: 48.623598
# [Epoch 5] validation: accuracy=0.858674
# Epoch[6] Batch [49]	Speed: 1188.874841 samples/sec	accuracy=0.911406
# Epoch[6] Batch [99]	Speed: 1059.912091 samples/sec	accuracy=0.910469
# Epoch[6] Batch [149]	Speed: 1118.483397 samples/sec	accuracy=0.910937
# Epoch[6] Batch [199]	Speed: 1213.278565 samples/sec	accuracy=0.911055
# Epoch[6] Batch [249]	Speed: 1060.841985 samples/sec	accuracy=0.911031
# Epoch[6] Batch [299]	Speed: 1069.287174 samples/sec	accuracy=0.910521
# Epoch[6] Batch [349]	Speed: 1075.624166 samples/sec	accuracy=0.910179
# [Epoch 6] training: accuracy=0.910106
# [Epoch 6] time cost: 48.839132
# [Epoch 6] validation: accuracy=0.863034
# Epoch[7] Batch [49]	Speed: 1231.137877 samples/sec	accuracy=0.904375
# Epoch[7] Batch [99]	Speed: 1114.806849 samples/sec	accuracy=0.905937
# Epoch[7] Batch [149]	Speed: 870.471144 samples/sec	accuracy=0.908438
# Epoch[7] Batch [199]	Speed: 909.754870 samples/sec	accuracy=0.908555
# Epoch[7] Batch [249]	Speed: 1109.489578 samples/sec	accuracy=0.908125
# Epoch[7] Batch [299]	Speed: 1153.722481 samples/sec	accuracy=0.907969
# Epoch[7] Batch [349]	Speed: 1162.211703 samples/sec	accuracy=0.909018
# [Epoch 7] training: accuracy=0.909347
# [Epoch 7] time cost: 47.591304
# [Epoch 7] validation: accuracy=0.865785
# Epoch[8] Batch [49]	Speed: 1132.803957 samples/sec	accuracy=0.907813
# Epoch[8] Batch [99]	Speed: 1032.904896 samples/sec	accuracy=0.907422
# Epoch[8] Batch [149]	Speed: 1112.349241 samples/sec	accuracy=0.908854
# Epoch[8] Batch [199]	Speed: 1109.682211 samples/sec	accuracy=0.908867
# Epoch[8] Batch [249]	Speed: 1148.163485 samples/sec	accuracy=0.907875
# Epoch[8] Batch [299]	Speed: 1045.378612 samples/sec	accuracy=0.908229
# Epoch[8] Batch [349]	Speed: 810.464162 samples/sec	accuracy=0.907857
# [Epoch 8] training: accuracy=0.907873
# [Epoch 8] time cost: 48.243156
# Epoch[10] Batch [299]	Speed: 1185.140269 samples/sec	accuracy=0.926016
# Epoch[10] Batch [349]	Speed: 979.757597 samples/sec	accuracy=0.929040
# [Epoch 10] training: accuracy=0.930467
# [Epoch 10] time cost: 48.324215
# [Epoch 10] validation: accuracy=0.896134
# Epoch[11] Batch [49]	Speed: 1084.265707 samples/sec	accuracy=0.941406
# Epoch[11] Batch [99]	Speed: 1151.517628 samples/sec	accuracy=0.940000
# Epoch[11] Batch [149]	Speed: 792.572112 samples/sec	accuracy=0.938906
# Epoch[11] Batch [199]	Speed: 1104.250044 samples/sec	accuracy=0.939727
# Epoch[11] Batch [249]	Speed: 1091.962307 samples/sec	accuracy=0.939813
# Epoch[11] Batch [299]	Speed: 1177.237480 samples/sec	accuracy=0.939948
# Epoch[11] Batch [349]	Speed: 1151.438598 samples/sec	accuracy=0.941562
# [Epoch 11] training: accuracy=0.942187
# [Epoch 11] time cost: 48.293900
# [Epoch 11] validation: accuracy=0.893229
# Epoch[12] Batch [49]	Speed: 1203.954297 samples/sec	accuracy=0.940781
# Epoch[12] Batch [99]	Speed: 953.095219 samples/sec	accuracy=0.939453
# Epoch[12] Batch [149]	Speed: 1135.633870 samples/sec	accuracy=0.940677
# Epoch[12] Batch [199]	Speed: 1136.862716 samples/sec	accuracy=0.941641
# Epoch[12] Batch [249]	Speed: 1096.267938 samples/sec	accuracy=0.942875
# Epoch[12] Batch [299]	Speed: 1036.420328 samples/sec	accuracy=0.942344
# Epoch[12] Batch [349]	Speed: 1159.435718 samples/sec	accuracy=0.943839
# [Epoch 12] training: accuracy=0.944154
# [Epoch 12] time cost: 48.307506
# [Epoch 12] validation: accuracy=0.895933
# Epoch[13] Batch [49]	Speed: 1089.929456 samples/sec	accuracy=0.943281
# Epoch[13] Batch [99]	Speed: 847.959137 samples/sec	accuracy=0.944531
# Epoch[13] Batch [149]	Speed: 1098.272846 samples/sec	accuracy=0.943125
# Epoch[13] Batch [199]	Speed: 1121.010346 samples/sec	accuracy=0.943516
# Epoch[13] Batch [249]	Speed: 1011.982553 samples/sec	accuracy=0.943781
# Epoch[13] Batch [299]	Speed: 1089.358873 samples/sec	accuracy=0.943776
# Epoch[13] Batch [349]	Speed: 848.951383 samples/sec	accuracy=0.944933
# [Epoch 13] training: accuracy=0.945433
# [Epoch 13] time cost: 48.135132
# [Epoch 13] validation: accuracy=0.895833
# Epoch[14] Batch [49]	Speed: 1050.716424 samples/sec	accuracy=0.941719
# Epoch[14] Batch [99]	Speed: 1056.256553 samples/sec	accuracy=0.942109
# Epoch[14] Batch [149]	Speed: 851.389529 samples/sec	accuracy=0.943177
# Epoch[14] Batch [199]	Speed: 1174.412460 samples/sec	accuracy=0.944258
# Epoch[14] Batch [249]	Speed: 903.588820 samples/sec	accuracy=0.944281
# Epoch[14] Batch [299]	Speed: 965.199364 samples/sec	accuracy=0.945234
# Epoch[14] Batch [349]	Speed: 1055.075430 samples/sec	accuracy=0.946049
# [Epoch 14] training: accuracy=0.946391
# [Epoch 14] time cost: 48.886878
# [Epoch 14] validation: accuracy=0.895866
# Epoch[15] Batch [49]	Speed: 1112.960320 samples/sec	accuracy=0.945625
# Epoch[15] Batch [99]	Speed: 1028.638101 samples/sec	accuracy=0.943594
# Epoch[15] Batch [149]	Speed: 1075.546591 samples/sec	accuracy=0.943125
# Epoch[15] Batch [199]	Speed: 1047.945595 samples/sec	accuracy=0.943320
# Epoch[15] Batch [249]	Speed: 779.633052 samples/sec	accuracy=0.943312
# Epoch[15] Batch [299]	Speed: 1155.361158 samples/sec	accuracy=0.944010
# Epoch[15] Batch [349]	Speed: 1056.688977 samples/sec	accuracy=0.944933
# [Epoch 15] training: accuracy=0.945352
# [Epoch 15] time cost: 47.566040
# [Epoch 15] validation: accuracy=0.896134
# Epoch[16] Batch [49]	Speed: 1096.899568 samples/sec	accuracy=0.951094
# Epoch[16] Batch [99]	Speed: 1193.534494 samples/sec	accuracy=0.948828
# Epoch[16] Batch [149]	Speed: 1115.413679 samples/sec	accuracy=0.948073
# Epoch[16] Batch [199]	Speed: 1149.454064 samples/sec	accuracy=0.947031
# Epoch[16] Batch [249]	Speed: 1061.750415 samples/sec	accuracy=0.946500
# Epoch[16] Batch [299]	Speed: 1185.255392 samples/sec	accuracy=0.946328
# Epoch[16] Batch [349]	Speed: 948.221898 samples/sec	accuracy=0.947701
# [Epoch 16] training: accuracy=0.947997
# [Epoch 16] time cost: 47.947451
# [Epoch 16] validation: accuracy=0.893329
# Epoch[17] Batch [49]	Speed: 924.405900 samples/sec	accuracy=0.942813
# Epoch[17] Batch [99]	Speed: 1046.105801 samples/sec	accuracy=0.942891
# Epoch[17] Batch [149]	Speed: 1056.707696 samples/sec	accuracy=0.942292
# Epoch[17] Batch [199]	Speed: 1062.258806 samples/sec	accuracy=0.941445
# Epoch[17] Batch [249]	Speed: 959.333616 samples/sec	accuracy=0.942219
# Epoch[17] Batch [299]	Speed: 884.435484 samples/sec	accuracy=0.942760
# Epoch[17] Batch [349]	Speed: 954.125072 samples/sec	accuracy=0.944196
# [Epoch 17] training: accuracy=0.944553
# [Epoch 17] time cost: 48.876224
# [Epoch 17] validation: accuracy=0.895933
# Epoch[18] Batch [49]	Speed: 1087.313673 samples/sec	accuracy=0.945000
# Epoch[18] Batch [99]	Speed: 1128.294882 samples/sec	accuracy=0.948359
# Epoch[18] Batch [149]	Speed: 1123.983905 samples/sec	accuracy=0.948438
# Epoch[18] Batch [199]	Speed: 1229.021290 samples/sec	accuracy=0.947656
# Epoch[18] Batch [249]	Speed: 1078.201264 samples/sec	accuracy=0.946500
# Epoch[18] Batch [299]	Speed: 1002.264340 samples/sec	accuracy=0.946094
# Epoch[18] Batch [349]	Speed: 1180.060560 samples/sec	accuracy=0.946496
# [Epoch 18] training: accuracy=0.947011
# [Epoch 18] time cost: 47.058622
# [Epoch 18] validation: accuracy=0.900541
# Epoch[19] Batch [49]	Speed: 1120.402089 samples/sec	accuracy=0.947187
# Epoch[19] Batch [99]	Speed: 907.153897 samples/sec	accuracy=0.943828
# Epoch[19] Batch [149]	Speed: 1021.922193 samples/sec	accuracy=0.944844
# Epoch[19] Batch [199]	Speed: 797.171236 samples/sec	accuracy=0.944844
# Epoch[19] Batch [249]	Speed: 1122.463474 samples/sec	accuracy=0.944906
# Epoch[19] Batch [299]	Speed: 836.371289 samples/sec	accuracy=0.945677
# Epoch[19] Batch [349]	Speed: 1131.655422 samples/sec	accuracy=0.946496
# [Epoch 19] training: accuracy=0.946074
# [Epoch 19] time cost: 47.020878
# [Epoch 19] validation: accuracy=0.892929
# Epoch[20] Batch [49]	Speed: 1143.176051 samples/sec	accuracy=0.947500
# Epoch[20] Batch [99]	Speed: 1191.494880 samples/sec	accuracy=0.944688
# Epoch[20] Batch [149]	Speed: 1062.761373 samples/sec	accuracy=0.944479
# Epoch[20] Batch [199]	Speed: 1114.075825 samples/sec	accuracy=0.946016
# Epoch[20] Batch [249]	Speed: 973.075244 samples/sec	accuracy=0.946875
# Epoch[20] Batch [299]	Speed: 1157.670629 samples/sec	accuracy=0.947812
# Epoch[20] Batch [349]	Speed: 1141.275671 samples/sec	accuracy=0.949375
# [Epoch 20] training: accuracy=0.950368
# [Epoch 20] time cost: 47.479411
# [Epoch 20] validation: accuracy=0.903746
# Epoch[21] Batch [49]	Speed: 1226.654067 samples/sec	accuracy=0.954375
# Epoch[21] Batch [99]	Speed: 1002.172665 samples/sec	accuracy=0.953047
# Epoch[21] Batch [149]	Speed: 1154.484135 samples/sec	accuracy=0.952292
# Epoch[21] Batch [199]	Speed: 1114.200679 samples/sec	accuracy=0.951914
# Epoch[21] Batch [249]	Speed: 1200.379456 samples/sec	accuracy=0.952094
# Epoch[21] Batch [299]	Speed: 1146.576980 samples/sec	accuracy=0.952604
# Epoch[21] Batch [349]	Speed: 1208.599808 samples/sec	accuracy=0.953906
# [Epoch 21] training: accuracy=0.954708
# [Epoch 21] time cost: 48.198591
# [Epoch 21] validation: accuracy=0.903145
# Epoch[22] Batch [49]	Speed: 955.753994 samples/sec	accuracy=0.953125
# Epoch[22] Batch [99]	Speed: 1140.342380 samples/sec	accuracy=0.952812
# Epoch[22] Batch [149]	Speed: 822.799497 samples/sec	accuracy=0.953698
# Epoch[22] Batch [199]	Speed: 1037.497873 samples/sec	accuracy=0.953750
# Epoch[22] Batch [249]	Speed: 1155.045475 samples/sec	accuracy=0.953438
# Epoch[22] Batch [299]	Speed: 1137.549236 samples/sec	accuracy=0.952786
# Epoch[22] Batch [349]	Speed: 1077.210442 samples/sec	accuracy=0.953906
# [Epoch 22] training: accuracy=0.954444
# [Epoch 22] time cost: 47.302513
# [Epoch 22] validation: accuracy=0.903184
# Epoch[23] Batch [49]	Speed: 1190.168907 samples/sec	accuracy=0.954063
# Epoch[23] Batch [99]	Speed: 1078.153629 samples/sec	accuracy=0.952578
# Epoch[23] Batch [149]	Speed: 1092.355563 samples/sec	accuracy=0.954063
# Epoch[23] Batch [199]	Speed: 1153.442386 samples/sec	accuracy=0.954688
# Epoch[23] Batch [249]	Speed: 1216.580546 samples/sec	accuracy=0.955094
# Epoch[23] Batch [299]	Speed: 878.496072 samples/sec	accuracy=0.955182
# Epoch[23] Batch [349]	Speed: 1069.233934 samples/sec	accuracy=0.955603
# [Epoch 23] training: accuracy=0.956202
# [Epoch 23] time cost: 48.000577
# [Epoch 23] validation: accuracy=0.902344
# Epoch[24] Batch [49]	Speed: 931.703609 samples/sec	accuracy=0.952969
# Epoch[24] Batch [99]	Speed: 1050.512883 samples/sec	accuracy=0.953516
# Epoch[24] Batch [149]	Speed: 1152.313470 samples/sec	accuracy=0.953490
# Epoch[24] Batch [199]	Speed: 668.888832 samples/sec	accuracy=0.954258
# Epoch[24] Batch [249]	Speed: 1132.230592 samples/sec	accuracy=0.954094
# Epoch[24] Batch [299]	Speed: 984.910753 samples/sec	accuracy=0.954531
# Epoch[24] Batch [349]	Speed: 701.862687 samples/sec	accuracy=0.954754
# [Epoch 24] training: accuracy=0.955148
# [Epoch 24] time cost: 47.801861
# [Epoch 24] validation: accuracy=0.903045
# Epoch[25] Batch [49]	Speed: 1102.513003 samples/sec	accuracy=0.954688
# Epoch[25] Batch [99]	Speed: 1046.034463 samples/sec	accuracy=0.952969
# Epoch[25] Batch [149]	Speed: 1184.063377 samples/sec	accuracy=0.952604
# Epoch[25] Batch [199]	Speed: 911.970946 samples/sec	accuracy=0.952227
# Epoch[25] Batch [249]	Speed: 1040.046401 samples/sec	accuracy=0.952719
# Epoch[25] Batch [299]	Speed: 721.501773 samples/sec	accuracy=0.952422
# Epoch[25] Batch [349]	Speed: 1073.640902 samples/sec	accuracy=0.953080
# [Epoch 25] training: accuracy=0.952945
# [Epoch 25] time cost: 48.213749
# [Epoch 25] validation: accuracy=0.904447
# Epoch[26] Batch [49]	Speed: 1065.786791 samples/sec	accuracy=0.949688
# Epoch[26] Batch [99]	Speed: 1192.595935 samples/sec	accuracy=0.950391
# Epoch[26] Batch [149]	Speed: 1218.051720 samples/sec	accuracy=0.951458
# Epoch[26] Batch [199]	Speed: 1197.559941 samples/sec	accuracy=0.951055
# Epoch[26] Batch [249]	Speed: 1053.628064 samples/sec	accuracy=0.951844
# Epoch[26] Batch [299]	Speed: 1046.415724 samples/sec	accuracy=0.951224
# Epoch[26] Batch [349]	Speed: 1124.247520 samples/sec	accuracy=0.953080
# [Epoch 26] training: accuracy=0.953345
# [Epoch 26] time cost: 48.116119
# [Epoch 26] validation: accuracy=0.900040
# Epoch[27] Batch [49]	Speed: 1209.869028 samples/sec	accuracy=0.956250
# Epoch[27] Batch [99]	Speed: 1268.161060 samples/sec	accuracy=0.954688
# Epoch[27] Batch [149]	Speed: 1104.334087 samples/sec	accuracy=0.954375
# Epoch[27] Batch [199]	Speed: 1067.303847 samples/sec	accuracy=0.954258
# Epoch[27] Batch [249]	Speed: 1084.984433 samples/sec	accuracy=0.953344
# Epoch[27] Batch [299]	Speed: 1161.447360 samples/sec	accuracy=0.953099
# Epoch[27] Batch [349]	Speed: 1122.397767 samples/sec	accuracy=0.954152
# [Epoch 27] training: accuracy=0.954487
# [Epoch 27] time cost: 48.275631
# [Epoch 27] validation: accuracy=0.905349
# Epoch[28] Batch [49]	Speed: 1015.725609 samples/sec	accuracy=0.953594
# Epoch[28] Batch [99]	Speed: 1107.710886 samples/sec	accuracy=0.953438
# Epoch[28] Batch [149]	Speed: 1116.615388 samples/sec	accuracy=0.954115
# Epoch[28] Batch [199]	Speed: 1033.987088 samples/sec	accuracy=0.953789
# Epoch[28] Batch [249]	Speed: 845.845635 samples/sec	accuracy=0.953875
# Epoch[28] Batch [299]	Speed: 976.116508 samples/sec	accuracy=0.953646
# Epoch[28] Batch [349]	Speed: 1222.428212 samples/sec	accuracy=0.955045
# [Epoch 28] training: accuracy=0.955143
# [Epoch 28] time cost: 48.884224
# [Epoch 28] validation: accuracy=0.900441
# Epoch[29] Batch [49]	Speed: 750.140300 samples/sec	accuracy=0.955156
# Epoch[29] Batch [99]	Speed: 1207.390267 samples/sec	accuracy=0.950078
# Epoch[29] Batch [149]	Speed: 1092.602325 samples/sec	accuracy=0.951979
# Epoch[29] Batch [199]	Speed: 1128.612717 samples/sec	accuracy=0.951094
# Epoch[29] Batch [249]	Speed: 987.579466 samples/sec	accuracy=0.952000
# Epoch[29] Batch [299]	Speed: 1187.194919 samples/sec	accuracy=0.953281
# Epoch[29] Batch [349]	Speed: 1133.554986 samples/sec	accuracy=0.953438
# [Epoch 29] training: accuracy=0.953726
# [Epoch 29] time cost: 48.473119
# [Epoch 29] validation: accuracy=0.899840
# Epoch[30] Batch [49]	Speed: 1127.799510 samples/sec	accuracy=0.953281
# Epoch[30] Batch [99]	Speed: 1044.894380 samples/sec	accuracy=0.952109
# Epoch[30] Batch [149]	Speed: 1052.502327 samples/sec	accuracy=0.952604
# Epoch[30] Batch [199]	Speed: 1088.157738 samples/sec	accuracy=0.953477
# Epoch[30] Batch [249]	Speed: 1216.649471 samples/sec	accuracy=0.954937
# Epoch[30] Batch [299]	Speed: 818.489367 samples/sec	accuracy=0.955052
# Epoch[30] Batch [349]	Speed: 1260.529625 samples/sec	accuracy=0.956317
# [Epoch 30] training: accuracy=0.956602
# [Epoch 30] time cost: 48.168323
# [Epoch 30] validation: accuracy=0.905558
# Epoch[31] Batch [49]	Speed: 996.375277 samples/sec	accuracy=0.956562
# Epoch[31] Batch [99]	Speed: 1181.319902 samples/sec	accuracy=0.955859
# Epoch[31] Batch [149]	Speed: 1218.322604 samples/sec	accuracy=0.956979
# Epoch[31] Batch [199]	Speed: 1061.057937 samples/sec	accuracy=0.957109
# Epoch[31] Batch [249]	Speed: 1099.728406 samples/sec	accuracy=0.957875
# Epoch[31] Batch [299]	Speed: 1054.710625 samples/sec	accuracy=0.957526
# Epoch[31] Batch [349]	Speed: 1202.632791 samples/sec	accuracy=0.958415
# [Epoch 31] training: accuracy=0.958820
# [Epoch 31] time cost: 47.274505
# [Epoch 31] validation: accuracy=0.906751
# Epoch[32] Batch [49]	Speed: 909.890553 samples/sec	accuracy=0.956719
# Epoch[32] Batch [99]	Speed: 1142.511900 samples/sec	accuracy=0.955781
# Epoch[32] Batch [149]	Speed: 1151.821500 samples/sec	accuracy=0.956250
# Epoch[32] Batch [199]	Speed: 759.511973 samples/sec	accuracy=0.956406
# Epoch[32] Batch [249]	Speed: 1110.363844 samples/sec	accuracy=0.956937
# Epoch[32] Batch [299]	Speed: 1227.515095 samples/sec	accuracy=0.957708
# Epoch[32] Batch [349]	Speed: 1204.062303 samples/sec	accuracy=0.958705
# [Epoch 32] training: accuracy=0.959195
# [Epoch 32] time cost: 47.985565
# [Epoch 32] validation: accuracy=0.907051
# Epoch[33] Batch [49]	Speed: 1171.925765 samples/sec	accuracy=0.955937
# Epoch[33] Batch [99]	Speed: 1152.085974 samples/sec	accuracy=0.956406
# Epoch[33] Batch [149]	Speed: 1191.264868 samples/sec	accuracy=0.956823
# Epoch[33] Batch [199]	Speed: 1073.877133 samples/sec	accuracy=0.955937
# Epoch[33] Batch [249]	Speed: 897.589822 samples/sec	accuracy=0.956438
# Epoch[33] Batch [299]	Speed: 1059.583667 samples/sec	accuracy=0.956302
# Epoch[33] Batch [349]	Speed: 1099.516694 samples/sec	accuracy=0.957612
# [Epoch 33] training: accuracy=0.957801
# [Epoch 33] time cost: 48.189878
# [Epoch 33] validation: accuracy=0.902544
# Epoch[34] Batch [49]	Speed: 1118.276049 samples/sec	accuracy=0.960938
# Epoch[34] Batch [99]	Speed: 1216.610872 samples/sec	accuracy=0.958047
# Epoch[34] Batch [149]	Speed: 914.180721 samples/sec	accuracy=0.958073
# Epoch[34] Batch [199]	Speed: 1107.144370 samples/sec	accuracy=0.957695
# Epoch[34] Batch [249]	Speed: 872.702569 samples/sec	accuracy=0.957781
# Epoch[34] Batch [299]	Speed: 1120.778663 samples/sec	accuracy=0.958073
# Epoch[34] Batch [349]	Speed: 1119.021927 samples/sec	accuracy=0.958147
# [Epoch 34] training: accuracy=0.958640
# [Epoch 34] time cost: 47.464797
# [Epoch 34] validation: accuracy=0.904748
# Epoch[35] Batch [49]	Speed: 988.532315 samples/sec	accuracy=0.958125
# Epoch[35] Batch [99]	Speed: 1071.692747 samples/sec	accuracy=0.957266
# Epoch[35] Batch [149]	Speed: 1204.748596 samples/sec	accuracy=0.956406
# Epoch[35] Batch [199]	Speed: 987.873853 samples/sec	accuracy=0.957305
# Epoch[35] Batch [249]	Speed: 990.922503 samples/sec	accuracy=0.958000
# Epoch[35] Batch [299]	Speed: 1019.889613 samples/sec	accuracy=0.957969
# Epoch[35] Batch [349]	Speed: 1141.744103 samples/sec	accuracy=0.958214
# [Epoch 35] training: accuracy=0.958574
# [Epoch 35] time cost: 48.849428
# [Epoch 35] validation: accuracy=0.903946
# Epoch[36] Batch [49]	Speed: 1081.496151 samples/sec	accuracy=0.955781
# Epoch[36] Batch [99]	Speed: 1148.561411 samples/sec	accuracy=0.954453
# Epoch[36] Batch [149]	Speed: 977.070472 samples/sec	accuracy=0.955365
# Epoch[36] Batch [199]	Speed: 1064.444962 samples/sec	accuracy=0.954570
# Epoch[36] Batch [249]	Speed: 899.382195 samples/sec	accuracy=0.955219
# Epoch[36] Batch [299]	Speed: 1052.174354 samples/sec	accuracy=0.955313
# Epoch[36] Batch [349]	Speed: 1010.599563 samples/sec	accuracy=0.956205
# [Epoch 36] training: accuracy=0.956382
# [Epoch 36] time cost: 48.584885
# [Epoch 36] validation: accuracy=0.904447
# Epoch[37] Batch [49]	Speed: 892.811739 samples/sec	accuracy=0.955781
# Epoch[37] Batch [99]	Speed: 1162.131199 samples/sec	accuracy=0.954922
# Epoch[37] Batch [149]	Speed: 1214.771993 samples/sec	accuracy=0.956667
# Epoch[37] Batch [199]	Speed: 1120.519011 samples/sec	accuracy=0.956680
# Epoch[37] Batch [249]	Speed: 1083.926396 samples/sec	accuracy=0.956688
# Epoch[37] Batch [299]	Speed: 1208.961781 samples/sec	accuracy=0.957240
# Epoch[37] Batch [349]	Speed: 1154.322789 samples/sec	accuracy=0.957790
# [Epoch 37] training: accuracy=0.958093
# [Epoch 37] time cost: 47.316989
# [Epoch 37] validation: accuracy=0.903846
# Epoch[38] Batch [49]	Speed: 1217.543445 samples/sec	accuracy=0.955781
# Epoch[38] Batch [99]	Speed: 1222.099858 samples/sec	accuracy=0.954375
# Epoch[38] Batch [149]	Speed: 1104.872718 samples/sec	accuracy=0.954792
# Epoch[38] Batch [199]	Speed: 1250.829222 samples/sec	accuracy=0.954063
# Epoch[38] Batch [249]	Speed: 1117.628875 samples/sec	accuracy=0.955281
# Epoch[38] Batch [299]	Speed: 1126.878660 samples/sec	accuracy=0.955182
# Epoch[38] Batch [349]	Speed: 1132.321336 samples/sec	accuracy=0.956071
# [Epoch 38] training: accuracy=0.956202
# [Epoch 38] time cost: 48.173148
# [Epoch 38] validation: accuracy=0.905360
# Epoch[39] Batch [49]	Speed: 1018.189410 samples/sec	accuracy=0.956875
# Epoch[39] Batch [99]	Speed: 1151.888225 samples/sec	accuracy=0.956250
# Epoch[39] Batch [149]	Speed: 1036.624449 samples/sec	accuracy=0.956458
# Epoch[39] Batch [199]	Speed: 1144.426161 samples/sec	accuracy=0.956406
# Epoch[39] Batch [249]	Speed: 1099.579749 samples/sec	accuracy=0.956063
# Epoch[39] Batch [299]	Speed: 1099.791485 samples/sec	accuracy=0.956354
# Epoch[39] Batch [349]	Speed: 1090.682302 samples/sec	accuracy=0.956719
# [Epoch 39] training: accuracy=0.956941
# [Epoch 39] time cost: 50.768927
# [Epoch 39] validation: accuracy=0.905148

# %% [markdown]
# Finally, we fix $W_B$, $W_C$ and only train $\tilde a$ for another 10 epochs.

# %%
for k, p in sp_resnet.collect_params().items():
    if 'sp_data_weights' in k or 'sp_out_weights' in k:
        p.grad_req = 'null'

epochs = 10
learning_rate = 0.001
scheduler = None

train(sp_resnet, learning_rate, momentum, weight_decay, epochs, scheduler, ctx, train_data, val_data, log_interval)
# Out:
# Epoch[0] Batch [49]	Speed: 801.545118 samples/sec	accuracy=0.953125
# Epoch[0] Batch [99]	Speed: 849.393277 samples/sec	accuracy=0.954844
# Epoch[0] Batch [149]	Speed: 1027.907432 samples/sec	accuracy=0.955573
# Epoch[0] Batch [199]	Speed: 1284.460067 samples/sec	accuracy=0.955156
# Epoch[0] Batch [249]	Speed: 1283.637014 samples/sec	accuracy=0.955969
# Epoch[0] Batch [299]	Speed: 1266.013885 samples/sec	accuracy=0.956536
# Epoch[0] Batch [349]	Speed: 1211.157310 samples/sec	accuracy=0.957790
# [Epoch 0] training: accuracy=0.958894
# [Epoch 0] time cost: 52.003801
# [Epoch 0] validation: accuracy=0.907953
# Epoch[1] Batch [49]	Speed: 1138.062861 samples/sec	accuracy=0.957344
# Epoch[1] Batch [99]	Speed: 1211.865394 samples/sec	accuracy=0.956172
# Epoch[1] Batch [149]	Speed: 1195.919335 samples/sec	accuracy=0.956146
# Epoch[1] Batch [199]	Speed: 1226.970852 samples/sec	accuracy=0.956211
# Epoch[1] Batch [249]	Speed: 1302.910806 samples/sec	accuracy=0.956781
# Epoch[1] Batch [299]	Speed: 1214.184067 samples/sec	accuracy=0.957708
# Epoch[1] Batch [349]	Speed: 1133.162605 samples/sec	accuracy=0.958594
# [Epoch 1] training: accuracy=0.958879
# [Epoch 1] time cost: 43.622476
# [Epoch 1] validation: accuracy=0.909155
# Epoch[2] Batch [49]	Speed: 1196.537702 samples/sec	accuracy=0.959688
# Epoch[2] Batch [99]	Speed: 1041.705222 samples/sec	accuracy=0.957109
# Epoch[2] Batch [149]	Speed: 969.742734 samples/sec	accuracy=0.957448
# Epoch[2] Batch [199]	Speed: 1148.949779 samples/sec	accuracy=0.957930
# Epoch[2] Batch [249]	Speed: 1042.400996 samples/sec	accuracy=0.958469
# Epoch[2] Batch [299]	Speed: 1202.716310 samples/sec	accuracy=0.958411
# Epoch[2] Batch [349]	Speed: 1226.665277 samples/sec	accuracy=0.959308
# [Epoch 2] training: accuracy=0.959759
# [Epoch 2] time cost: 44.116256
# [Epoch 2] validation: accuracy=0.909155
# Epoch[3] Batch [49]	Speed: 1212.336085 samples/sec	accuracy=0.958906
# Epoch[3] Batch [99]	Speed: 1239.176896 samples/sec	accuracy=0.958516
# Epoch[3] Batch [149]	Speed: 1320.507748 samples/sec	accuracy=0.958750
# Epoch[3] Batch [199]	Speed: 1173.416517 samples/sec	accuracy=0.958711
# Epoch[3] Batch [249]	Speed: 1354.267503 samples/sec	accuracy=0.959469
# Epoch[3] Batch [299]	Speed: 1030.256747 samples/sec	accuracy=0.959818
# Epoch[3] Batch [349]	Speed: 1085.258588 samples/sec	accuracy=0.961272
# [Epoch 3] training: accuracy=0.961679
# [Epoch 3] time cost: 43.494492
# [Epoch 3] validation: accuracy=0.910056
# Epoch[4] Batch [49]	Speed: 941.376725 samples/sec	accuracy=0.960000
# Epoch[4] Batch [99]	Speed: 1075.684510 samples/sec	accuracy=0.958359
# Epoch[4] Batch [149]	Speed: 1152.617763 samples/sec	accuracy=0.960417
# Epoch[4] Batch [199]	Speed: 1097.942676 samples/sec	accuracy=0.959922
# Epoch[4] Batch [249]	Speed: 1017.749327 samples/sec	accuracy=0.960719
# Epoch[4] Batch [299]	Speed: 1223.537013 samples/sec	accuracy=0.960182
# Epoch[4] Batch [349]	Speed: 1217.237028 samples/sec	accuracy=0.960804
# [Epoch 4] training: accuracy=0.961037
# [Epoch 4] time cost: 44.864956
# [Epoch 4] validation: accuracy=0.910056
# Epoch[5] Batch [49]	Speed: 1240.055601 samples/sec	accuracy=0.958281
# Epoch[5] Batch [99]	Speed: 1079.363147 samples/sec	accuracy=0.957187
# Epoch[5] Batch [149]	Speed: 1258.074968 samples/sec	accuracy=0.958281
# Epoch[5] Batch [199]	Speed: 1190.855297 samples/sec	accuracy=0.957812
# Epoch[5] Batch [249]	Speed: 912.173929 samples/sec	accuracy=0.958937
# Epoch[5] Batch [299]	Speed: 1185.014705 samples/sec	accuracy=0.959453
# Epoch[5] Batch [349]	Speed: 1267.074601 samples/sec	accuracy=0.959911
# [Epoch 5] training: accuracy=0.960517
# [Epoch 5] time cost: 44.035769
# [Epoch 5] validation: accuracy=0.909355
# Epoch[6] Batch [49]	Speed: 1200.626426 samples/sec	accuracy=0.964063
# Epoch[6] Batch [99]	Speed: 793.321658 samples/sec	accuracy=0.958438
# Epoch[6] Batch [149]	Speed: 900.483413 samples/sec	accuracy=0.959115
# Epoch[6] Batch [199]	Speed: 1214.219766 samples/sec	accuracy=0.958945
# Epoch[6] Batch [249]	Speed: 1160.947561 samples/sec	accuracy=0.959344
# Epoch[6] Batch [299]	Speed: 1232.907749 samples/sec	accuracy=0.959609
# Epoch[6] Batch [349]	Speed: 1287.429347 samples/sec	accuracy=0.960580
# [Epoch 6] training: accuracy=0.960977
# [Epoch 6] time cost: 44.125039
# [Epoch 6] validation: accuracy=0.908722
# Epoch[7] Batch [49]	Speed: 1198.634773 samples/sec	accuracy=0.955937
# Epoch[7] Batch [99]	Speed: 1235.276456 samples/sec	accuracy=0.956094
# Epoch[7] Batch [149]	Speed: 994.734075 samples/sec	accuracy=0.957812
# Epoch[7] Batch [199]	Speed: 1158.767552 samples/sec	accuracy=0.958320
# Epoch[7] Batch [249]	Speed: 1291.533041 samples/sec	accuracy=0.959063
# Epoch[7] Batch [299]	Speed: 1021.546906 samples/sec	accuracy=0.960000
# Epoch[7] Batch [349]	Speed: 1333.420044 samples/sec	accuracy=0.961339
# [Epoch 7] training: accuracy=0.961897
# [Epoch 7] time cost: 43.317396
# [Epoch 7] validation: accuracy=0.908654
# Epoch[8] Batch [49]	Speed: 1183.353491 samples/sec	accuracy=0.959688
# Epoch[8] Batch [99]	Speed: 1145.551890 samples/sec	accuracy=0.958828
# Epoch[8] Batch [149]	Speed: 1225.920202 samples/sec	accuracy=0.960000
# Epoch[8] Batch [199]	Speed: 1246.950767 samples/sec	accuracy=0.959961
# Epoch[8] Batch [249]	Speed: 1140.596763 samples/sec	accuracy=0.960250
# Epoch[8] Batch [299]	Speed: 1280.468311 samples/sec	accuracy=0.960833
# Epoch[8] Batch [349]	Speed: 1035.219245 samples/sec	accuracy=0.961808
# [Epoch 8] training: accuracy=0.961999
# [Epoch 8] time cost: 43.733970
# [Epoch 8] validation: accuracy=0.907752
# Epoch[9] Batch [49]	Speed: 1146.559839 samples/sec	accuracy=0.959844
# Epoch[9] Batch [99]	Speed: 1243.945976 samples/sec	accuracy=0.958359
# Epoch[9] Batch [149]	Speed: 1005.703941 samples/sec	accuracy=0.959167
# Epoch[9] Batch [199]	Speed: 1193.967152 samples/sec	accuracy=0.959844
# Epoch[9] Batch [249]	Speed: 1199.700812 samples/sec	accuracy=0.960781
# Epoch[9] Batch [299]	Speed: 1252.641591 samples/sec	accuracy=0.960443
# Epoch[9] Batch [349]	Speed: 1258.641260 samples/sec	accuracy=0.961496
# [Epoch 9] training: accuracy=0.962096
# [Epoch 9] time cost: 43.498626
# [Epoch 9] validation: accuracy=0.907853

# %% [markdown]
# The accuracy of the model with quantized $W_A$, $W_B$ should have a validation accuracy slighlty below that of the unquantized model.
#
# We finally save the paramters of the quantized model.

# %%
sp_resnet.collect_params().save('sp_resnet.params')

# %% [markdown]
# Done!

# %% [markdown]
# ### References
#
# [1] https://github.com/apache/incubator-mxnet/blob/master/docs/tutorials/gluon/customop.md
#
# [2] F. Li, B. Zhang, B. Liu, Ternary Weight Networks, 2016, https://arxiv.org/abs/1605.04711v2
#
# [3] K. He, X. Zhang, S. Ren, J. Sun, Deep Residual Learning for Image Recognition, 2016, http://arxiv.org/abs/1512.03385
#
# [4] https://github.com/apache/incubator-mxnet/blob/master/python/mxnet/gluon/model_zoo/vision/resnet.py
#
# [5] https://github.com/apache/incubator-mxnet/blob/master/example/gluon/image_classification.py
