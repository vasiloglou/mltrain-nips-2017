# %% [markdown]
# # Fast Linear Algebra in Stacked Strassen Networks
#
# This notebook provides a step-by-step implementation to reproduce the experiment in *Fast Linear Algebra in Stacked Strassen Networks* by Michael Tschannen, Aran Khanna, and Anima Anandkumar, submitted to the Machine Learning on the Phone and other Consumer Devices (MLPCD) NIPS 2018 workshop.
#
# #### Abstract
#
# Matrix multiplications can be cast as $2$-layer sum-product (SP) networks with ternary weight matrices, disentangling multiplications and additions. We leverage this observation for end-to-end learning of low cost (in terms of multiplications) approximations for linear operations in neural network layers. Specifically, we propose to replace matrix multiplication operations by SP networks, with widths corresponding to the budget of multiplications we want to allocate to each layer, and to learn them end-to-end. We showcase this approach by compressing the convolution layers of ResNet and evaluating it on CIFAR-10. We obtain a $98.96\%$ reduction in the number of multiplications with an accuracy loss of only $0.82\%$.
#
#
# #### Learning fast matrix multiplications via sum-product networks
# $\renewcommand{\vec}{\mathrm{vec}}$Given square matrices $A, B \in \mathbb{R}^{n \times n}$, the product $C = A B$ can be represented as a $2$-layer sum-product (SP) network (or ``Strassen network'')
#
# $$
#     \label{eq:strnet}
#     \vec(C) = W_C [ (W_B \vec(B)) \odot (W_A \vec(A))] \qquad \qquad (1)
# $$
#
# where $W_A, W_B \in \mathbb{K}^{r \times n^2}$ and $W_C \in \mathbb{K}^{n^2 \times r}$, $\mathbb{K}:= \{-1,0,1\}$, and $\odot$ denotes the element-wise product.
#
# <img src="files/spnetwork.png" alt="spnetwork" style="width: 400px;"/>
#
# 1. $A, B\in \mathbb{R}^{2 \times 2}$: Strassen's algorithm tells us ternary weights that satisfy (1) for $r=7$ (instead of $r = 8$).
# 2. General case $A \in \mathbb{R}^{k \times m}$, $B \in \mathbb{R}^{m \times n}$: $C = A B$ can be written in the form (1) if $r \geq nmk$.
# 3. If $A \in \mathbb{R}^{k \times m}$ is fixed and $B \in \mathbb{R}^{m \times n}$ concentrates on low-dimensional subspace of $\mathbb{R}^{k \times m}$: Can find $W_A, W_B$ s.t. (1) holds approximately even when $r \ll nmk$
#
# *Idea:* Leverage item 3 to learn low-cost (in terms of multiplications) approximate linear operations in neural network layers by associating $A$ with (pretrained) weights/filters and $B$ with corresponding activations/feature maps, and by learning $W_A$, $W_B$, $W_C$ end-to-end.
#
# In this notebook, we demonstrate this idea by compressing the 2D convolution layers of ResNet.
#
# #### Outline of the notebook:
# 1. Implement the ternary quantization operator to learn ternary weights $W_B$ and $W_C$
# 2. Implement the SP 2D convolution layer (i.e. a Strassen network for 2D convolutions)
# 3. Implement residual blocks with SP layers and use these to construct a SP ResNet
# 4. Define iterators and the training loop
# 5. Train the network
#
# The code is base on Apache MXNet 0.12 and the gluon package.

# %% [markdown]
# ## 1. Implement the ternary quantization operator
#
# Following the tutorial from [1] to define custom gluon operators, we define an operator implementing the ternarization method proposed in [2]. Using the notation from [2], this method quantizes the entries of a given input tensor to values $\{-\alpha, 0, \alpha\}$ ($\alpha$ corresponds to `scale` below) based on a threshold $\Delta$ (corresponding to `thresh` below) on the full precision entries. $\alpha$ and $\Delta$ are determinined by approximately solving an optimization problem, see [2]. The operator will be used to quanzie $W_B$ and $W_C$ (the factor $\alpha$ can be absorbed into $\tilde a = W_A \vec(A)$ after training to ensure that the entries of $W_B$ and $W_C$ are in $\{-1,0,1\}$).
#
# [1] https://github.com/apache/incubator-mxnet/blob/master/docs/tutorials/gluon/customop.md
#
# [2] F. Li, B. Zhang, B. Liu, Ternary Weight Networks, 2016, https://arxiv.org/abs/1605.04711v2

# %%
# !pip install mxnet

# %%
import mxnet as mx
import numpy as np

# define the quantization operator
class TerQuant(mx.operator.CustomOp):
    # define forward pass as described in [1]
    def forward(self, is_train, req, in_data, out_data, aux):
        full_data = in_data[0]

        # compute $\Delta$ as in [1], Eq. (6)
        thresh = mx.nd.mean(mx.nd.abs(full_data), axis=()).asnumpy()[0] * 0.7

        # ternarize weights
        quant_data = mx.nd.greater(full_data, thresh*mx.nd.ones(full_data.shape, full_data.context))\
            - mx.nd.lesser(full_data, (-1.0)*thresh*mx.nd.ones(full_data.shape, full_data.context))

        # compute $\alpha$ as in [1], Eq. (5)
        scale = mx.nd.sum(mx.nd.multiply(full_data, quant_data), axis=()).asnumpy()[0]\
            / mx.nd.sum(mx.nd.abs(quant_data), axis=()).asnumpy()[0]

        # rescale ternary weights
        quant_data = scale * quant_data
        self.assign(out_data[0], req[0], quant_data)

    # define backward pass: simply pass on gradient from previous operation (derivative of the identity function)
    def backward(self, req, out_grad, in_data, out_data, in_grad, aux):
        self.assign(in_grad[0], req[0], out_grad[0])

# wrap the operator and provide functions to get information about input, output etc.
@mx.operator.register('ter_quant')
class TerQuantProp(mx.operator.CustomOpProp):
    def __init__(self):
        super(TerQuantProp, self).__init__(True)

    def list_arguments(self):
        return ['data']

    def list_outputs(self):
        return ['output']

    def infer_shape(self, in_shapes):
        data_shape = in_shapes[0]
        output_shape = data_shape
        return (data_shape,), (output_shape,), ()

    def create_operator(self, ctx, in_shapes, in_dtypes):
        return TerQuant()

# %% [markdown]
# ## 2. Implement the SP 2DConvLayer
# $\newcommand{\cin}{c_\mathrm{in}}\newcommand{\cout}{c_\mathrm{out}}$We are now ready to implement the SP 2D convolution layer (as a gluon `HybridBlock` object). Specifically, we compress the computation of $\cout \times p \times p$ output elements of the convolution from $\cin \times (p + 2\lfloor k/2\rfloor) \times (p + 2\lfloor k/2\rfloor)$ input elements by applying (see figure below)
#
# 1. a $p$-strided 2D convolution with a *ternary* filter of size $r \times \cin \times (p + 2\lfloor k/2\rfloor) \times (p + 2\lfloor k/2\rfloor)$ (corresponding to multiplication with $W_B$),
# 2. a channel-wise multiplication with an $r \times 1 \times 1$ *full-precision* filter $\tilde a = W_A \vec(A)$ (corresponding to the filters of the original convolution),
# 3. a $1/p$-strided transposed 2D convolution with a *ternary* filter of size $\cout \times r \times p \times p$ (corresponding to multiplication with $W_C$).
#
# <img src="files/sp2dconv.png" alt="spnetwork" style="width: 600px;"/>
#
# As we will pretrain the convolutions described in items 1 and 3 above with full-precision weights, we include a variable `mode` that determines whether quantization is active or not. Furthermore, we include the original convolution to selectively replace the SP convolutions with ordinary ones (not used in this notebook).

# %%
from mxnet import gluon, autograd
from mxnet.gluon.block import HybridBlock
from mxnet.base import numeric_types
from math import ceil

class SumProd2DConv(mx.gluon.HybridBlock):
    r"""
    nbr_mul : int
        Width of the sum-product network, corresponding to the number of multiplications r used to compute an
        $p_x$ x $p_y$ x channels activation element
    target_layer_shape:
        Shape of the filter to be replaced by the sum-product network
    target_layer_key:
        Name of the target layer in the original ResNet (to enable loading from a pretrained network)
    out_patch : int
        size ($p_x$, $p_y$) of the output patch for spatial compression
    kernel, stride, pad : specifics of the 2D convolution
    """
    
    def __init__(self, nbr_mul, target_layer_shape, target_layer_key, out_patch=(1,1), kernel=(3,3), stride=(1,1), pad=(1,1), prefix=None, **kwargs):
        # Use same prefix as parent layer for loading the shared paramters to be compressed
        super(SumProd2DConv, self).__init__(prefix=prefix, **kwargs)

        if isinstance(stride, numeric_types):
            stride = (stride,)*len(kernel)
        if isinstance(pad, numeric_types):
            pad = (pad,)*len(kernel)

        self._nbr_mul = nbr_mul
        # corresponds to $p$ in the description above
        self._out_patch = out_patch
        self._kernel = kernel
        self._stride = stride
        self._pad = pad

        # compute kernel shapes and stride for $W_B$
        self._sp_data_weight_kernel = ((self._out_patch[0]-1)*self._stride[0]+self._kernel[0], (self._out_patch[1]-1)*self._stride[1]+self._kernel[1])
        self._sp_data_weight_stride = (self._out_patch[0]*self._stride[0], self._out_patch[1]*self._stride[1])

        # filters for the original convolution
        self.filter_weights = self.params.get(target_layer_key, shape=target_layer_shape)

        # Assuming the default NCHW layout, determine shapes of $W_B$ and $W_C$
        filter_weights_shape = list(target_layer_shape)
        sp_data_weights_shape = filter_weights_shape.copy()
        sp_data_weights_shape[0] = nbr_mul
        sp_data_weights_shape[2] = self._sp_data_weight_kernel[0]
        sp_data_weights_shape[3] = self._sp_data_weight_kernel[1]
        sp_out_weights_shape = filter_weights_shape.copy()
        sp_out_weights_shape[0] = nbr_mul
        sp_out_weights_shape[1] = filter_weights_shape[0]
        sp_out_weights_shape[2] = self._out_patch[0]
        sp_out_weights_shape[3] = self._out_patch[1]

        ## SP network weights
        # $\tilde a = W_A \vec(A)$
        self.sp_in_weights = self.params.get('sp_in_weights', shape=(1,self._nbr_mul,1,1))
        # $W_B$
        self.sp_data_weights = self.params.get('sp_data_weights', shape=sp_data_weights_shape)
        # $W_C$
        self.sp_out_weights =  self.params.get('sp_out_weights', shape=sp_out_weights_shape)

        # SP network batchnorm parameters
        self.sp_batchnorm_gamma = self.params.get('sp_batchnorm_gamma', shape=(1,self._nbr_mul,1,1))
        self.sp_batchnorm_beta = self.params.get('sp_batchnorm_beta', shape=(1,self._nbr_mul,1,1))
        self.sp_batchnorm_running_mean = self.params.get('sp_batchnorm_running_mean', shape=(1,self._nbr_mul,1,1))
        self.sp_batchnorm_running_var = self.params.get('sp_batchnorm_running_var', shape=(1,self._nbr_mul,1,1))

        # mode: 1: original convolution; 2: SP network without ternary quantization; 3: SP network with ternary quantization
        self.sp_mode = self.params.get('sp_mode', shape=(1,), dtype=np.uint8)


    def forward(self, data):
        with data.context:
            mode = self.sp_mode.data().asnumpy()[0]
            filter_weights = self.filter_weights.data()

            if mode == 0:
                # perform original convolution
                conv_out = mx.nd.Convolution(data=data,
                                  weight=filter_weights,
                                  bias=None,
                                  no_bias=True,
                                  kernel=self._kernel,
                                  stride=self._stride,
                                  pad=self._pad,
                                  num_filter=filter_weights.shape[0])

                return conv_out
            else:
                sp_data_weights = self.sp_data_weights.data()
                sp_out_weights = self.sp_out_weights.data()

                # quantzie $W_B$ and $W_C$ if desired
                if mode == 2:
                    sp_data_weights = mx.nd.Custom(sp_data_weights, op_type='ter_quant')
                    sp_out_weights = mx.nd.Custom(sp_out_weights, op_type='ter_quant')

                pad_x = self._pad[0] + ceil((data.shape[2]%self._sp_data_weight_stride[0])/2)
                pad_y = self._pad[1] + ceil((data.shape[3]%self._sp_data_weight_stride[1])/2)

                # compute $W_B \vec(B)$
                sp_data_mul = mx.nd.Convolution(data=data,
                                  weight=sp_data_weights,
                                  bias=None,
                                  no_bias=True,
                                  kernel=self._sp_data_weight_kernel,
                                  stride=self._sp_data_weight_stride,
                                  pad=(pad_x, pad_y),
                                  num_filter = self._nbr_mul)

                # apply batchnorm to $W_B \vec(B)$
                sp_data_mul_norm = mx.nd.BatchNorm(data=sp_data_mul,
                                              gamma=self.sp_batchnorm_gamma.data(),
                                              beta=self.sp_batchnorm_beta.data(),
                                              moving_mean=self.sp_batchnorm_running_mean.data(),
                                              moving_var=self.sp_batchnorm_running_var.data(),
                                              fix_gamma=True)

                # apply non-negativity constraint to $\tilde a = W_A \vec(A)$
                with mx.autograd.pause():
                    self.sp_in_weights.set_data(mx.nd.clip(data=self.sp_in_weights.data(), a_min=0.0, a_max=100.0))
                
                # compute $(W_A \vec(A)) \odot (W_B \vec(B))$
                sp_mul = mx.nd.multiply(self.sp_in_weights.data(), sp_data_mul_norm)
                
                # compute $W_C[(W_A \vec(A)) \odot (W_B \vec(B))]$
                sp_out = mx.nd.Deconvolution(data = sp_mul,
                                  weight = sp_out_weights,
                                  bias = None,
                                  no_bias = True,
                                  kernel = self._out_patch,
                                  stride = self._out_patch,
                                  target_shape = (data.shape[2]//self._stride[0], data.shape[3]//self._stride[1]),
                                  num_filter = filter_weights.shape[0])

                return sp_out

# %% [markdown]
# ## 3. Implement the sum-product residual unit
#
# We continue by defining the residual unit as proposed in [3] using sum-product 2D convolutions. The code block below is adapted from [4] and looks lengthy, but there are only small modifications compared to [4]. Specifically, we replace ordinary 2D convolutions by sum-product 2D convolutions and add parameters for the sum-product convolutions.
#
# [3] K. He, X. Zhang, S. Ren, J. Sun, Deep Residual Learning for Image Recognition, 2016, http://arxiv.org/abs/1512.03385
#
# [4] https://github.com/apache/incubator-mxnet/blob/master/python/mxnet/gluon/model_zoo/vision/resnet.py

# %%
from mxnet.gluon import nn

class BasicBlockV1SumProd(HybridBlock):
    r"""
    Parameters
    ----------
    channels : int
        Number of output channels.
    stride : int
        Stride size.
    nbr_mul : int
        Width of the sum-product network, corresponding to the number of multiplications r used to compute an
        $p_x$ x $p_y$ x channels activation element
    out_patch : int
        size ($p_x$, $p_y$) of the output patch for spatial compression
    conv_idx : int
        index of the convolution, used for parameter names
    downsample : bool, default False
        Whether to downsample the input.
    in_channels : int, default 0
        Number of input channels. Default is 0, to infer from the graph.
    quant_down : bool
        Whether to quantize ResNet 1x1 convolution projection layers
    """
    def __init__(self, channels, stride, nbr_mul, out_patch=(1,1), conv_idx=0, downsample=False, in_channels=0, quant_down=True, **kwargs):
        super(BasicBlockV1SumProd, self).__init__(**kwargs)
        self.body = nn.HybridSequential(prefix='')

        prefix1 = 'conv%i_'%conv_idx
        # shape of the original convolution
        orig_shape1 = (channels, in_channels, 3, 3)
        # kernel of the original convolution
        kernel = (3,3)

        self.body.add(SumProd2DConv(nbr_mul=nbr_mul,
                                      target_layer_shape=orig_shape1,
                                      target_layer_key='weight',
                                      out_patch=out_patch,
                                      kernel=kernel,
                                      stride=stride,
                                      prefix=prefix1))

        self.body.add(nn.BatchNorm())
        self.body.add(nn.Activation('relu'))
        
        prefix2 = 'conv%i_'%(conv_idx+1)
        orig_shape2 = (channels, channels, 3, 3)

        self.body.add(SumProd2DConv(nbr_mul=nbr_mul,
                                      target_layer_shape=orig_shape2,
                                      target_layer_key='weight',
                                      out_patch=out_patch,
                                      kernel=kernel,
                                      stride=1,
                                      prefix=prefix2))

        self.body.add(nn.BatchNorm())
        
        if downsample:
            self.downsample = nn.HybridSequential(prefix='')

            # Quantize projection layer if required
            if quant_down:
                prefix_ds = 'conv%i_'%(conv_idx+2)
                orig_shape_ds = (channels, in_channels, 1, 1)

                self.downsample.add(SumProd2DConv(nbr_mul=nbr_mul,
                                              target_layer_shape=orig_shape_ds,
                                              target_layer_key='weight',
                                              out_patch=(1,1),
                                              kernel=(1,1),
                                              stride=stride,
                                              pad=(0,0),
                                              prefix=prefix_ds))
            else:
                self.downsample.add(nn.Conv2D(channels, kernel_size=1, strides=stride,
                                              use_bias=False, in_channels=in_channels))

            self.downsample.add(nn.BatchNorm())
        else:
            self.downsample = None

    def hybrid_forward(self, F, x):
        residual = x

        x = self.body(x)

        if self.downsample:
            residual = self.downsample(residual)

        x = F.Activation(residual+x, act_type='relu')

        return x

# %% [markdown]
# ## 4. Implement the sum-product ResNet
#
# Again, we modify the code to construct ResNet (as a gluon `HybridBlock` object) for various dephts from [4], replacing ordinary 2D convolutions by sum-product 2D convolutions, and the fully connected output layer by a sum-product network if desired. As before, we add in some parameters for the sum-product networks.

# %%
from mxnet.gluon.model_zoo.vision.resnet import _conv3x3

class ResNetV1SumProd(HybridBlock):
    r"""ResNet V1 model from
    `"Deep Residual Learning for Image Recognition"
    <http://arxiv.org/abs/1512.03385>`_ paper.

    Parameters
    ----------
    block : HybridBlock
        Class for the residual block. Options are BasicBlockV1, BottleneckV1.
    layers : list of int
        Numbers of layers in each block
    channels : list of int
        Numbers of channels in each block. Length should be one larger than layers list.
    nbr_mul : int
        Width of the sum-product network, corresponding to the number of multiplications r used to compute an
        $p_x$ x $p_y$ x channels activation element
    out_patch : int
        size ($p_x$, $p_y$) of the output patch for spatial compression
    classes : int, default 1000
        Number of classification classes.
    thumbnail : bool, default False
        Enable thumbnail.
    quant_down : bool
        Whether to quantize ResNet 1x1 convolution projection layers
    """
    def __init__(self, layers, channels, nbr_mul, out_patch, classes=1000, thumbnail=False, quant_down=True, prefix='resnetv10_', **kwargs):
        super(ResNetV1SumProd, self).__init__(prefix, **kwargs)
        
        with self.name_scope():
            self.features = nn.HybridSequential(prefix='')
            # Thumbnail determines the characteristics of the first layer. If thumbnail==True, 3x3 convolutions are used
            # and no pooling is performed (this setting is used for CIFAR). Otherwise, 7x7 filters with max-pooling are used.
            if thumbnail:
                # replace first layer with a sum-product layer if desired
                if nbr_mul[0] > 0:
                    orig_shape = (channels[0], 3, 3, 3)

                    self.features.add(SumProd2DConv(nbr_mul = nbr_mul[0],
                                                  target_layer_shape = orig_shape,
                                                  target_layer_key = 'weight',
                                                  kernel = (3, 3),
                                                  stride = (1, 1),
                                                  out_patch = out_patch[0],
                                                  prefix = 'conv0_'))
                else:
                    self.features.add(_conv3x3(channels[0], 1, 3))

            else:
                # replace first layer with a sum-product layer if desired
                if nbr_mul[0] > 0:
                    orig_shape = (channels[0], 3, 7, 7)

                    self.features.add(SumProd2DConv(nbr_mul = nbr_mul[0],
                                                  target_layer_shape = orig_shape,
                                                  target_layer_key = 'weight',
                                                  kernel = (7, 7),
                                                  stride = (2, 2),
                                                  pad = (3,3),
                                                  out_patch = out_patch[0],
                                                  prefix = 'conv0_'))
                else:
                    self.features.add(nn.Conv2D(channels[0], 7, 2, 3, use_bias=False,
                                                in_channels=3))
                self.features.add(nn.BatchNorm())
                self.features.add(nn.Activation('relu'))
                self.features.add(nn.MaxPool2D(3, 2, 1))

            for i, num_layer in enumerate(layers):
                stride = 1 if i == 0 else 2
                self.features.add(self._make_sumprod_layer(num_layer, channels[i+1], stride,
                                                   nbr_mul[i+1], out_patch[i+1], i+1, in_channels=channels[i], quant_down=quant_down))

            self.classifier = nn.HybridSequential(prefix='')
            self.classifier.add(nn.GlobalAvgPool2D())
            self.classifier.add(nn.Flatten())
            self.classifier.add(nn.Dense(classes, in_units=channels[-1]))

    # stack residual blocks as described in [2]
    def _make_sumprod_layer(self, layers, channels, stride, nbr_mul, out_patch, stage_index, in_channels=0, quant_down=True):
        layer = nn.HybridSequential(prefix='stage%d_'%stage_index)
        with layer.name_scope():
            layer.add(BasicBlockV1SumProd(channels, stride, nbr_mul, out_patch, 0, channels != in_channels, in_channels=in_channels, quant_down=quant_down, prefix=''))
            nbr_conv = 2 if channels == in_channels else 3
            for i in range(layers-1):
                layer.add(BasicBlockV1SumProd(channels, 1, nbr_mul, out_patch, nbr_conv, False, in_channels=channels, quant_down=quant_down, prefix=''))
                nbr_conv += 2
        return layer

    def hybrid_forward(self, F, x):
        x = self.features(x)
        x = self.classifier(x)

        return x

# %% [markdown]
# # 5. Training the network
#
# We are now ready to train and evaluate the SP-ResNet-20 on CIFAR-10 as described in the paper.
#
# We start by defining the SP-Resnet-20. The parameters below realize the configuration for $p=1$ and $r=c_\mathrm{out}$ in Table 1 (first row, first column) in the paper, and can be modified for other configurations. Furthermore, the context can be modified below (use `ctx = [mx.cpu(0)]` if you don't have a GPU available, or extend to a list of devices for parallel training).

# %%
# CIFAR-10 has 10 classes
classes = 10
# structure of ResNet-20
res_units = [3, 3, 3]
res_channels = [16, 16, 32, 64]
# choose the width of the sum-product convolution networks (i.e., $r$) to be equal to the number of output channels
# don't compress the last layer (encoded by nbr_mul=0)
nbr_mul = [16, 16, 32, 64, 0]
# don't do spatial compression (out. patch=1x1)
out_patch = [(1,1)]*4
# quantize ResNet 1x1 convolution projection layers
quant_down = True
# use 3x3 kernels for the first convolution layer, don't do pooling after the first convolution layer
thumbnail = True

# construct ResNet HybridBlock object
sp_resnet = ResNetV1SumProd(res_units, res_channels, nbr_mul, out_patch, classes, thumbnail, quant_down)

# define context
ctx = [mx.gpu(0)]

# %% [markdown]
# Next, we initialize the network parameters. As we first train all weights at full precision first, `sp_mode` is set to  1. `sp_in_weights` (corresponding to $\tilde a = W_A \mathrm{vec}(A)$) is initialized to 1s and Xavier initialization is used for `sp_data_weights` and `sp_out_weights` (corresponding to $W_B$ and $W_C$, respectively), and for the fully connected output layer. Furthermore, optimization is deactivated for the auxiliary batchnorm variables.

# %%
# helper function to filter and intialize paramters whose name contains a given substring
def initialize_by_key(net, key, init, context, force_reinit=False):
    for k, p in net.collect_params().items():
        if key in k:
            p.initialize(init=init, ctx=context, force_reinit=force_reinit)

# initialize SP networks
initialize_by_key(sp_resnet, 'sp_mode', mx.init.One(), ctx)
initialize_by_key(sp_resnet, 'sp_in_weights', mx.init.One(), ctx)
initialize_by_key(sp_resnet, 'sp_data_weights', mx.init.Xavier(magnitude=2), ctx)
initialize_by_key(sp_resnet, 'sp_out_weights', mx.init.Xavier(magnitude=2), ctx)

# intialize batchnorm parameters
initialize_by_key(sp_resnet, 'gamma', mx.init.One(), ctx)
initialize_by_key(sp_resnet, 'beta', mx.init.Zero(), ctx)
initialize_by_key(sp_resnet, 'running_mean', mx.init.Zero(), ctx)
initialize_by_key(sp_resnet, 'running_var', mx.init.Zero(), ctx)

# initialize fully connected layer
initialize_by_key(sp_resnet, 'dense0_weight', mx.init.Xavier(magnitude=2), ctx) #mx.init.Normal(1)
initialize_by_key(sp_resnet, 'dense0_bias', mx.init.Zero(), ctx)

# deactivate optimization for original convolutions as they are not used here
for k, p in sp_resnet.collect_params().items():
    if 'conv' in k and 'sp' not in k:
        p.initialize(init=mx.init.Xavier(magnitude=2), ctx=ctx)
        p.grad_req = 'null'

# deactivate optimization for batchnorm auxiliary variables
for k, p in sp_resnet.collect_params().items():
    if 'running_mean' in k or 'running_var' in k or 'sp_mode' in k:
        p.grad_req = 'null'

# %% [markdown]
# We continue by defining a testing routine and a training loop. This again looks lengthy but is standard and adapted from [5] with slight modifications.
#
# [5] https://github.com/apache/incubator-mxnet/blob/master/example/gluon/image_classification.py

# %%
import time

def test(net, val_data, context):
    metric = mx.metric.Accuracy()
    val_data.reset()
    for batch in val_data:
        data = gluon.utils.split_and_load(batch.data[0], ctx_list=context, batch_axis=0)
        label = gluon.utils.split_and_load(batch.label[0], ctx_list=context, batch_axis=0)
        outputs = []
        for x in data:
            outputs.append(net(x))
        metric.update(label, outputs)
    return metric.get()


def train(net, lr, mom, wd, epochs, scheduler, context, train_data, val_data, log_interval):
    trainer = gluon.Trainer(net.collect_params(), 'sgd',
                            {'learning_rate': lr, 'wd': wd, 'momentum': mom, 'lr_scheduler': scheduler},
                            kvstore = 'device')
    metric = mx.metric.Accuracy()
    loss = gluon.loss.SoftmaxCrossEntropyLoss()

    for epoch in range(epochs):
        tic = time.time()
        train_data.reset()
        metric.reset()
        btic = time.time()
        for i, batch in enumerate(train_data):
            data = gluon.utils.split_and_load(batch.data[0], ctx_list=ctx, batch_axis=0)
            label = gluon.utils.split_and_load(batch.label[0], ctx_list=ctx, batch_axis=0)
            outputs = []
            Ls = []
            with autograd.record():
                for x, y in zip(data, label):
                    z = net(x)
                    L = loss(z, y)
                    Ls.append(L)
                    outputs.append(z)
                for L in Ls:
                    L.backward()
            trainer.step(batch.data[0].shape[0])
            metric.update(label, outputs)
            if log_interval and not (i+1)%log_interval:
                name, acc = metric.get()
                print('Epoch[%d] Batch [%d]\tSpeed: %f samples/sec\t%s=%f'%(
                               epoch, i, batch_size/(time.time()-btic), name, acc))
            btic = time.time()

        name, acc = metric.get()
        print('[Epoch %d] training: %s=%f'%(epoch, name, acc))
        print('[Epoch %d] time cost: %f'%(epoch, time.time()-tic))
        name, val_acc = test(net, val_data, context)
        print('[Epoch %d] validation: %s=%f'%(epoch, name, val_acc))

# %% [markdown]
# Now, we define the iterators, employing the same data augmentation procedures as described in [3], Sec. 4.2. The CIFAR-10 data set should be downloaded automatically if not available locally (otherwise, you can donwload it manually from http://data.mxnet.io/mxnet/data/cifar10.zip, create a subfolder 'data' in the folder containing this notebook, and extract it there).

# %%
mx.random.seed(321)

data_shape = (3, 32, 32)
batch_size = 128

# download CIFAR-10 if necessary
zip_file_path = mx.test_utils.download('http://data.mxnet.io/mxnet/data/cifar10.zip', dirname='data')
import zipfile
with zipfile.ZipFile(zip_file_path) as zf:
    zf.extractall('data')

# training set iterator
train_data = mx.io.ImageRecordIter(
    path_imgrec   = "data/cifar/train.rec",
    data_shape    = data_shape,
    batch_size    = batch_size,
    mean_r        = 125.3,
    mean_g        = 123.0,
    mean_b        = 113.9,
    std_r         = 63.0,
    std_g         = 62.1,
    std_b         = 66.7,
    dtype         = 'float32',
    rand_crop     = True,
    max_crop_size = 32,
    min_crop_size = 32,
    pad           = 4,
    fill_value    = 0,
    shuffle       = True,
    rand_mirror   = True,
    shuffle_chunk_seed  = 123)

# validation set iterator
val_data = mx.io.ImageRecordIter(
    mean_r      = 125.3,
    mean_g      = 123.0,
    mean_b      = 113.9,
    std_r       = 63.0,
    std_g       = 62.1,
    std_b       = 66.7,
    dtype       = 'float32',
    path_imgrec = "data/cifar/test.rec",
    rand_crop   = False,
    rand_mirror = False,
    data_shape  = data_shape,
    batch_size  = batch_size)

# %% [markdown]
# Specify optimizer paramters, regularization, and learning rate schedule (150-50-50 epochs x0.1)...

# %%
epochs = 250
learning_rate = 0.1
momentum = 0.9
weight_decay = 0.0001

train_set_size = 50000
# introduce auxiliary variable to translate steps into epochs
schedule_factor = ceil(train_set_size/batch_size)
scheduler = mx.lr_scheduler.MultiFactorScheduler([150*schedule_factor, 200*schedule_factor, 250*schedule_factor], factor=0.1)

log_interval = 50

# %% [markdown]
# ... and train the SP-ResNet-20 from scratch with full precision entries for $W_B$, $W_C$.

# %%
train(sp_resnet, learning_rate, momentum, weight_decay, epochs, scheduler, ctx, train_data, val_data, log_interval)
# Out:
# Epoch[0] Batch [49]	Speed: 3439.187414 samples/sec	accuracy=0.207344
# Epoch[0] Batch [99]	Speed: 2777.957850 samples/sec	accuracy=0.246641
# Epoch[0] Batch [149]	Speed: 3822.723345 samples/sec	accuracy=0.276719
# Epoch[0] Batch [199]	Speed: 3925.585411 samples/sec	accuracy=0.295195
# Epoch[0] Batch [249]	Speed: 3826.946987 samples/sec	accuracy=0.312875
# Epoch[0] Batch [299]	Speed: 3414.449149 samples/sec	accuracy=0.328333
# Epoch[0] Batch [349]	Speed: 3957.182222 samples/sec	accuracy=0.344062
# [Epoch 0] training: accuracy=0.357197
# [Epoch 0] time cost: 16.649981
# [Epoch 0] validation: accuracy=0.449862
# Epoch[1] Batch [49]	Speed: 3053.334804 samples/sec	accuracy=0.496250
# Epoch[1] Batch [99]	Speed: 3770.902368 samples/sec	accuracy=0.506641
# Epoch[1] Batch [149]	Speed: 3821.009302 samples/sec	accuracy=0.516354
# Epoch[1] Batch [199]	Speed: 3916.021707 samples/sec	accuracy=0.525742
# Epoch[1] Batch [249]	Speed: 3827.929298 samples/sec	accuracy=0.535312
# Epoch[1] Batch [299]	Speed: 3848.454241 samples/sec	accuracy=0.540990
# Epoch[1] Batch [349]	Speed: 3894.828224 samples/sec	accuracy=0.550022
# [Epoch 1] training: accuracy=0.554228
# [Epoch 1] time cost: 15.845188
# [Epoch 1] validation: accuracy=0.621895
# Epoch[2] Batch [49]	Speed: 3754.657118 samples/sec	accuracy=0.618906
# Epoch[2] Batch [99]	Speed: 3760.495580 samples/sec	accuracy=0.620391
# Epoch[2] Batch [149]	Speed: 3806.326345 samples/sec	accuracy=0.621875
# Epoch[2] Batch [199]	Speed: 3447.203447 samples/sec	accuracy=0.625898
# Epoch[2] Batch [249]	Speed: 2845.691012 samples/sec	accuracy=0.630000
# Epoch[2] Batch [299]	Speed: 3969.793565 samples/sec	accuracy=0.632344
# Epoch[2] Batch [349]	Speed: 3786.807962 samples/sec	accuracy=0.636696
# [Epoch 2] training: accuracy=0.639443
# [Epoch 2] time cost: 15.310952
# [Epoch 2] validation: accuracy=0.590645
# Epoch[3] Batch [49]	Speed: 3763.606304 samples/sec	accuracy=0.665156
# Epoch[3] Batch [99]	Speed: 2125.606902 samples/sec	accuracy=0.672266
# Epoch[3] Batch [149]	Speed: 2326.080076 samples/sec	accuracy=0.670104
# Epoch[3] Batch [199]	Speed: 3026.363950 samples/sec	accuracy=0.675117
# Epoch[3] Batch [249]	Speed: 3784.245521 samples/sec	accuracy=0.677781
# Epoch[3] Batch [299]	Speed: 3625.987168 samples/sec	accuracy=0.679193
# Epoch[3] Batch [349]	Speed: 1804.213910 samples/sec	accuracy=0.682299
# [Epoch 3] training: accuracy=0.683704
# [Epoch 3] time cost: 15.834161
# [Epoch 3] validation: accuracy=0.696715
# Epoch[4] Batch [49]	Speed: 3955.986707 samples/sec	accuracy=0.707031
# Epoch[4] Batch [99]	Speed: 3014.265970 samples/sec	accuracy=0.706250
# Epoch[4] Batch [149]	Speed: 3865.996342 samples/sec	accuracy=0.708073
# Epoch[4] Batch [199]	Speed: 3288.904550 samples/sec	accuracy=0.708984
# Epoch[4] Batch [249]	Speed: 3507.974308 samples/sec	accuracy=0.712531
# Epoch[4] Batch [299]	Speed: 3740.270256 samples/sec	accuracy=0.713698
# Epoch[4] Batch [349]	Speed: 3081.073596 samples/sec	accuracy=0.716920
# [Epoch 4] training: accuracy=0.718550
# [Epoch 4] time cost: 15.234896
# [Epoch 4] validation: accuracy=0.677684
# Epoch[5] Batch [49]	Speed: 4077.861927 samples/sec	accuracy=0.731094
# Epoch[5] Batch [99]	Speed: 3217.358207 samples/sec	accuracy=0.740313
# Epoch[5] Batch [149]	Speed: 3779.689752 samples/sec	accuracy=0.738333
# Epoch[5] Batch [199]	Speed: 3133.109889 samples/sec	accuracy=0.739961
# Epoch[5] Batch [249]	Speed: 3770.240328 samples/sec	accuracy=0.740844
# Epoch[5] Batch [299]	Speed: 2959.368693 samples/sec	accuracy=0.741276
# Epoch[5] Batch [349]	Speed: 3788.170671 samples/sec	accuracy=0.742165
# [Epoch 5] training: accuracy=0.743409
# [Epoch 5] time cost: 15.655585
# [Epoch 5] validation: accuracy=0.669671
# Epoch[6] Batch [49]	Speed: 3718.560647 samples/sec	accuracy=0.754687
# Epoch[6] Batch [99]	Speed: 2939.390803 samples/sec	accuracy=0.756484
# Epoch[6] Batch [149]	Speed: 3835.504537 samples/sec	accuracy=0.758490
# Epoch[6] Batch [199]	Speed: 3439.650135 samples/sec	accuracy=0.759414
# Epoch[6] Batch [249]	Speed: 3871.683845 samples/sec	accuracy=0.761156
# Epoch[6] Batch [299]	Speed: 3044.573243 samples/sec	accuracy=0.761328
# Epoch[6] Batch [349]	Speed: 3825.965180 samples/sec	accuracy=0.763058
# [Epoch 6] training: accuracy=0.763827
# [Epoch 6] time cost: 15.941863
# [Epoch 6] validation: accuracy=0.752404
# Epoch[7] Batch [49]	Speed: 3772.174138 samples/sec	accuracy=0.765469
# Epoch[7] Batch [99]	Speed: 3701.332745 samples/sec	accuracy=0.772578
# Epoch[7] Batch [149]	Speed: 2836.969325 samples/sec	accuracy=0.771771
# Epoch[7] Batch [199]	Speed: 3480.344047 samples/sec	accuracy=0.773633
# Epoch[7] Batch [249]	Speed: 2562.140460 samples/sec	accuracy=0.774656
# Epoch[7] Batch [299]	Speed: 3456.792021 samples/sec	accuracy=0.774245
# Epoch[7] Batch [349]	Speed: 2782.060526 samples/sec	accuracy=0.775871
# [Epoch 7] training: accuracy=0.776082
# [Epoch 7] time cost: 15.315651
# [Epoch 7] validation: accuracy=0.774239
# Epoch[8] Batch [49]	Speed: 3843.109816 samples/sec	accuracy=0.786563
# Epoch[8] Batch [99]	Speed: 3830.933931 samples/sec	accuracy=0.784844
# Epoch[8] Batch [149]	Speed: 2158.049458 samples/sec	accuracy=0.786198
# Epoch[8] Batch [199]	Speed: 3488.077341 samples/sec	accuracy=0.785859
# Epoch[8] Batch [249]	Speed: 2644.554022 samples/sec	accuracy=0.786594
# Epoch[8] Batch [299]	Speed: 3471.477330 samples/sec	accuracy=0.786667
# Epoch[8] Batch [349]	Speed: 3995.377881 samples/sec	accuracy=0.787388
# [Epoch 8] training: accuracy=0.788163
# [Epoch 8] time cost: 15.436168
# [Epoch 8] validation: accuracy=0.775514
# Epoch[9] Batch [49]	Speed: 2772.377547 samples/sec	accuracy=0.798438
# Epoch[9] Batch [99]	Speed: 3921.742871 samples/sec	accuracy=0.795391
# Epoch[9] Batch [149]	Speed: 3967.505280 samples/sec	accuracy=0.793229
# Epoch[9] Batch [199]	Speed: 3934.590301 samples/sec	accuracy=0.793008
# Epoch[9] Batch [249]	Speed: 2706.152619 samples/sec	accuracy=0.794375
# Epoch[9] Batch [299]	Speed: 4009.431614 samples/sec	accuracy=0.794687
# Epoch[9] Batch [349]	Speed: 3697.407143 samples/sec	accuracy=0.795670
# [Epoch 9] training: accuracy=0.796296
# [Epoch 9] time cost: 14.584720
# [Epoch 9] validation: accuracy=0.743089
# Epoch[10] Batch [49]	Speed: 2982.566468 samples/sec	accuracy=0.807500
# Epoch[10] Batch [99]	Speed: 3481.269328 samples/sec	accuracy=0.803438
# Epoch[10] Batch [149]	Speed: 3064.314199 samples/sec	accuracy=0.800573
# Epoch[10] Batch [199]	Speed: 2836.879380 samples/sec	accuracy=0.800312
# Epoch[10] Batch [249]	Speed: 3823.594559 samples/sec	accuracy=0.800813
# Epoch[10] Batch [299]	Speed: 3466.971334 samples/sec	accuracy=0.801641
# Epoch[10] Batch [349]	Speed: 3047.217182 samples/sec	accuracy=0.803772
# [Epoch 10] training: accuracy=0.803145
# [Epoch 10] time cost: 15.727621
# [Epoch 10] validation: accuracy=0.789163
# Epoch[11] Batch [49]	Speed: 1579.292213 samples/sec	accuracy=0.807969
# Epoch[11] Batch [99]	Speed: 3784.512280 samples/sec	accuracy=0.806953
# Epoch[11] Batch [149]	Speed: 2096.464098 samples/sec	accuracy=0.810104
# Epoch[11] Batch [199]	Speed: 3815.713660 samples/sec	accuracy=0.807852
# Epoch[11] Batch [249]	Speed: 3851.546456 samples/sec	accuracy=0.809562
# Epoch[11] Batch [299]	Speed: 2608.195258 samples/sec	accuracy=0.809297
# Epoch[11] Batch [349]	Speed: 3313.118116 samples/sec	accuracy=0.810201
# [Epoch 11] training: accuracy=0.809143
# [Epoch 11] time cost: 15.637626
# [Epoch 11] validation: accuracy=0.773137
# Epoch[12] Batch [49]	Speed: 3881.537024 samples/sec	accuracy=0.818125
# Epoch[12] Batch [99]	Speed: 4007.426434 samples/sec	accuracy=0.815391
# Epoch[12] Batch [149]	Speed: 3906.021317 samples/sec	accuracy=0.813073
# Epoch[12] Batch [199]	Speed: 2672.981026 samples/sec	accuracy=0.813086
# Epoch[12] Batch [249]	Speed: 955.252326 samples/sec	accuracy=0.814125
# Epoch[12] Batch [299]	Speed: 3800.048924 samples/sec	accuracy=0.813984
# Epoch[12] Batch [349]	Speed: 3878.312435 samples/sec	accuracy=0.815424
# [Epoch 12] training: accuracy=0.815317
# [Epoch 12] time cost: 15.397054
# [Epoch 12] validation: accuracy=0.792067
# Epoch[13] Batch [49]	Speed: 3236.794453 samples/sec	accuracy=0.818125
# Epoch[13] Batch [99]	Speed: 2992.424681 samples/sec	accuracy=0.813516
# Epoch[13] Batch [149]	Speed: 3925.068811 samples/sec	accuracy=0.816406
# Epoch[13] Batch [199]	Speed: 2874.056671 samples/sec	accuracy=0.817695
# Epoch[13] Batch [249]	Speed: 3602.072609 samples/sec	accuracy=0.816187
# Epoch[13] Batch [299]	Speed: 3312.811458 samples/sec	accuracy=0.817969
# Epoch[13] Batch [349]	Speed: 3958.757905 samples/sec	accuracy=0.819844
# [Epoch 13] training: accuracy=0.819551
# [Epoch 13] time cost: 16.079724
# [Epoch 13] validation: accuracy=0.799880
# Epoch[14] Batch [49]	Speed: 3944.737704 samples/sec	accuracy=0.827812
# Epoch[14] Batch [99]	Speed: 2369.631899 samples/sec	accuracy=0.824688
# Epoch[14] Batch [149]	Speed: 3659.227710 samples/sec	accuracy=0.821406
# Epoch[14] Batch [199]	Speed: 4050.663669 samples/sec	accuracy=0.822969
# Epoch[14] Batch [249]	Speed: 2680.026317 samples/sec	accuracy=0.821969
# Epoch[14] Batch [299]	Speed: 3889.777005 samples/sec	accuracy=0.822396
# Epoch[14] Batch [349]	Speed: 3876.688151 samples/sec	accuracy=0.822098
# [Epoch 14] training: accuracy=0.822011
# [Epoch 14] time cost: 15.770859
# [Epoch 14] validation: accuracy=0.794271
# Epoch[15] Batch [49]	Speed: 2150.408203 samples/sec	accuracy=0.819688
# Epoch[15] Batch [99]	Speed: 2827.839117 samples/sec	accuracy=0.826875
# Epoch[15] Batch [149]	Speed: 3534.347450 samples/sec	accuracy=0.826979
# Epoch[15] Batch [199]	Speed: 2429.005370 samples/sec	accuracy=0.827070
# Epoch[15] Batch [249]	Speed: 3558.358599 samples/sec	accuracy=0.826656
# Epoch[15] Batch [299]	Speed: 2045.658929 samples/sec	accuracy=0.826510
# Epoch[15] Batch [349]	Speed: 3994.694128 samples/sec	accuracy=0.826629
# [Epoch 15] training: accuracy=0.827244
# [Epoch 15] time cost: 15.877112
# [Epoch 15] validation: accuracy=0.818409
# Epoch[16] Batch [49]	Speed: 2376.576075 samples/sec	accuracy=0.832656
# Epoch[16] Batch [99]	Speed: 3597.534808 samples/sec	accuracy=0.827734
# Epoch[16] Batch [149]	Speed: 3777.402689 samples/sec	accuracy=0.829219
# Epoch[16] Batch [199]	Speed: 3755.865400 samples/sec	accuracy=0.829609
# Epoch[16] Batch [249]	Speed: 3641.753292 samples/sec	accuracy=0.829906
# Epoch[16] Batch [299]	Speed: 3423.746952 samples/sec	accuracy=0.831667
# Epoch[16] Batch [349]	Speed: 4042.641767 samples/sec	accuracy=0.832433
# [Epoch 16] training: accuracy=0.832201
# [Epoch 16] time cost: 15.755648
# [Epoch 16] validation: accuracy=0.795194
# Epoch[17] Batch [49]	Speed: 4005.154329 samples/sec	accuracy=0.827031
# Epoch[17] Batch [99]	Speed: 3953.161169 samples/sec	accuracy=0.831484
# Epoch[17] Batch [149]	Speed: 2996.249111 samples/sec	accuracy=0.830208
# Epoch[17] Batch [199]	Speed: 3536.629131 samples/sec	accuracy=0.830469
# Epoch[17] Batch [249]	Speed: 2596.602382 samples/sec	accuracy=0.830812
# Epoch[17] Batch [299]	Speed: 1938.890096 samples/sec	accuracy=0.831354
# Epoch[17] Batch [349]	Speed: 3664.422745 samples/sec	accuracy=0.831719
# [Epoch 17] training: accuracy=0.831801
# [Epoch 17] time cost: 15.178120
# [Epoch 17] validation: accuracy=0.793570
# Epoch[18] Batch [49]	Speed: 3973.936787 samples/sec	accuracy=0.828125
# Epoch[18] Batch [99]	Speed: 1642.907366 samples/sec	accuracy=0.831953
# Epoch[18] Batch [149]	Speed: 1589.466474 samples/sec	accuracy=0.833125
# Epoch[18] Batch [199]	Speed: 3888.706365 samples/sec	accuracy=0.833125
# Epoch[18] Batch [249]	Speed: 2424.803584 samples/sec	accuracy=0.832187
# Epoch[18] Batch [299]	Speed: 3936.292338 samples/sec	accuracy=0.832318
# Epoch[18] Batch [349]	Speed: 3819.405481 samples/sec	accuracy=0.833460
# [Epoch 18] training: accuracy=0.833894
# [Epoch 18] time cost: 15.512382
# [Epoch 18] validation: accuracy=0.822416
# Epoch[19] Batch [49]	Speed: 2332.983861 samples/sec	accuracy=0.841406
# Epoch[19] Batch [99]	Speed: 3019.606356 samples/sec	accuracy=0.841719
# Epoch[19] Batch [149]	Speed: 2023.324371 samples/sec	accuracy=0.838437
# Epoch[19] Batch [199]	Speed: 3951.240944 samples/sec	accuracy=0.838516
# Epoch[19] Batch [249]	Speed: 3792.478999 samples/sec	accuracy=0.836969
# Epoch[19] Batch [299]	Speed: 3948.218918 samples/sec	accuracy=0.837786
# Epoch[19] Batch [349]	Speed: 2984.987585 samples/sec	accuracy=0.839085
# [Epoch 19] training: accuracy=0.839035
# [Epoch 19] time cost: 15.978943
# [Epoch 19] validation: accuracy=0.814603
# Epoch[20] Batch [49]	Speed: 3935.715211 samples/sec	accuracy=0.844531
# Epoch[20] Batch [99]	Speed: 3657.383028 samples/sec	accuracy=0.840000
# Epoch[20] Batch [149]	Speed: 2937.091263 samples/sec	accuracy=0.841667
# Epoch[20] Batch [199]	Speed: 3381.288927 samples/sec	accuracy=0.839570
# Epoch[20] Batch [249]	Speed: 2662.918070 samples/sec	accuracy=0.840125
# Epoch[20] Batch [299]	Speed: 2267.478616 samples/sec	accuracy=0.840339
# Epoch[20] Batch [349]	Speed: 2283.633901 samples/sec	accuracy=0.840491
# [Epoch 20] training: accuracy=0.841053
# [Epoch 20] time cost: 15.465853
# [Epoch 20] validation: accuracy=0.823017
# Epoch[21] Batch [49]	Speed: 3843.990348 samples/sec	accuracy=0.846094
# Epoch[21] Batch [99]	Speed: 1949.825897 samples/sec	accuracy=0.842109
# Epoch[21] Batch [149]	Speed: 3884.429691 samples/sec	accuracy=0.841042
# Epoch[21] Batch [199]	Speed: 3966.157015 samples/sec	accuracy=0.843828
# Epoch[21] Batch [249]	Speed: 3040.607316 samples/sec	accuracy=0.844688
# Epoch[21] Batch [299]	Speed: 4022.258191 samples/sec	accuracy=0.843828
# Epoch[21] Batch [349]	Speed: 3919.109061 samples/sec	accuracy=0.845134
# [Epoch 21] training: accuracy=0.843870
# [Epoch 21] time cost: 15.308098
# [Epoch 21] validation: accuracy=0.801583
# Epoch[22] Batch [49]	Speed: 3041.434135 samples/sec	accuracy=0.840938
# Epoch[22] Batch [99]	Speed: 3734.130733 samples/sec	accuracy=0.843047
# Epoch[22] Batch [149]	Speed: 3825.011129 samples/sec	accuracy=0.845625
# Epoch[22] Batch [199]	Speed: 3724.132297 samples/sec	accuracy=0.844961
# Epoch[22] Batch [249]	Speed: 2323.553217 samples/sec	accuracy=0.844031
# Epoch[22] Batch [299]	Speed: 3633.447340 samples/sec	accuracy=0.844740
# Epoch[22] Batch [349]	Speed: 3815.171347 samples/sec	accuracy=0.845759
# [Epoch 22] training: accuracy=0.845548
# [Epoch 22] time cost: 15.676855
# [Epoch 22] validation: accuracy=0.817107
# Epoch[23] Batch [49]	Speed: 3850.469139 samples/sec	accuracy=0.845938
# Epoch[23] Batch [99]	Speed: 3827.519941 samples/sec	accuracy=0.847734
# Epoch[23] Batch [149]	Speed: 2737.922004 samples/sec	accuracy=0.845469
# Epoch[23] Batch [199]	Speed: 3057.804185 samples/sec	accuracy=0.845039
# Epoch[23] Batch [249]	Speed: 3007.595933 samples/sec	accuracy=0.844719
# Epoch[23] Batch [299]	Speed: 2893.933203 samples/sec	accuracy=0.845625
# Epoch[23] Batch [349]	Speed: 2877.769444 samples/sec	accuracy=0.846116
# [Epoch 23] training: accuracy=0.845473
# [Epoch 23] time cost: 15.886645
# [Epoch 23] validation: accuracy=0.805889
# Epoch[24] Batch [49]	Speed: 2154.611102 samples/sec	accuracy=0.846406
# Epoch[24] Batch [99]	Speed: 3924.494971 samples/sec	accuracy=0.850156
# Epoch[24] Batch [149]	Speed: 3900.572599 samples/sec	accuracy=0.847396
# Epoch[24] Batch [199]	Speed: 3739.931537 samples/sec	accuracy=0.847578
# Epoch[24] Batch [249]	Speed: 3531.743417 samples/sec	accuracy=0.846938
# Epoch[24] Batch [299]	Speed: 3685.224750 samples/sec	accuracy=0.847656
# Epoch[24] Batch [349]	Speed: 3779.317250 samples/sec	accuracy=0.848080
# [Epoch 24] training: accuracy=0.847946
# [Epoch 24] time cost: 15.874727
# [Epoch 24] validation: accuracy=0.808940
# Epoch[25] Batch [49]	Speed: 4015.729528 samples/sec	accuracy=0.850000
# Epoch[25] Batch [99]	Speed: 3927.566971 samples/sec	accuracy=0.847109
# Epoch[25] Batch [149]	Speed: 3662.472880 samples/sec	accuracy=0.848594
# Epoch[25] Batch [199]	Speed: 1814.476420 samples/sec	accuracy=0.850156
# Epoch[25] Batch [249]	Speed: 2769.088673 samples/sec	accuracy=0.850250
# Epoch[25] Batch [299]	Speed: 3795.830737 samples/sec	accuracy=0.850833
# Epoch[25] Batch [349]	Speed: 2229.891519 samples/sec	accuracy=0.851317
# [Epoch 25] training: accuracy=0.850783
# [Epoch 25] time cost: 15.646214
# [Epoch 25] validation: accuracy=0.778245
# Epoch[26] Batch [49]	Speed: 2964.581639 samples/sec	accuracy=0.846562
# Epoch[26] Batch [99]	Speed: 3825.610763 samples/sec	accuracy=0.850938
# Epoch[26] Batch [149]	Speed: 3929.780641 samples/sec	accuracy=0.851667
# Epoch[26] Batch [199]	Speed: 3459.576451 samples/sec	accuracy=0.850391
# Epoch[26] Batch [249]	Speed: 3467.083282 samples/sec	accuracy=0.850219
# Epoch[26] Batch [299]	Speed: 3803.333229 samples/sec	accuracy=0.850391
# Epoch[26] Batch [349]	Speed: 3839.921266 samples/sec	accuracy=0.851451
# [Epoch 26] training: accuracy=0.850861
# [Epoch 26] time cost: 15.163875
# [Epoch 26] validation: accuracy=0.799679
# Epoch[27] Batch [49]	Speed: 3821.390068 samples/sec	accuracy=0.848906
# Epoch[27] Batch [99]	Speed: 3896.496026 samples/sec	accuracy=0.851562
# Epoch[27] Batch [149]	Speed: 3745.854930 samples/sec	accuracy=0.850938
# Epoch[27] Batch [199]	Speed: 4016.360407 samples/sec	accuracy=0.851523
# Epoch[27] Batch [249]	Speed: 2621.388801 samples/sec	accuracy=0.852625
# Epoch[27] Batch [299]	Speed: 2888.794550 samples/sec	accuracy=0.854089
# Epoch[27] Batch [349]	Speed: 3618.825870 samples/sec	accuracy=0.853996
# [Epoch 27] training: accuracy=0.854020
# [Epoch 27] time cost: 15.110211
# [Epoch 27] validation: accuracy=0.817208
# Epoch[28] Batch [49]	Speed: 2968.253131 samples/sec	accuracy=0.857969
# Epoch[28] Batch [99]	Speed: 3787.048369 samples/sec	accuracy=0.854453
# Epoch[28] Batch [149]	Speed: 3643.458603 samples/sec	accuracy=0.855469
# Epoch[28] Batch [199]	Speed: 3906.021317 samples/sec	accuracy=0.855391
# Epoch[28] Batch [249]	Speed: 3425.276015 samples/sec	accuracy=0.854375
# Epoch[28] Batch [299]	Speed: 3003.104021 samples/sec	accuracy=0.855208
# Epoch[28] Batch [349]	Speed: 2994.711485 samples/sec	accuracy=0.855335
# [Epoch 28] training: accuracy=0.854640
# [Epoch 28] time cost: 15.823660
# [Epoch 28] validation: accuracy=0.812300
# Epoch[29] Batch [49]	Speed: 1618.382591 samples/sec	accuracy=0.856719
# Epoch[29] Batch [99]	Speed: 2548.566915 samples/sec	accuracy=0.856797
# Epoch[29] Batch [149]	Speed: 3882.154514 samples/sec	accuracy=0.854323
# Epoch[29] Batch [199]	Speed: 2407.924794 samples/sec	accuracy=0.855117
# Epoch[29] Batch [249]	Speed: 2028.768245 samples/sec	accuracy=0.854375
# Epoch[29] Batch [299]	Speed: 2639.029233 samples/sec	accuracy=0.855130
# Epoch[29] Batch [349]	Speed: 3583.272121 samples/sec	accuracy=0.856228
# [Epoch 29] training: accuracy=0.855629
# [Epoch 29] time cost: 15.747955
# [Epoch 29] validation: accuracy=0.812901
# Epoch[30] Batch [49]	Speed: 2492.575780 samples/sec	accuracy=0.856094
# Epoch[30] Batch [99]	Speed: 2799.249767 samples/sec	accuracy=0.852344
# Epoch[30] Batch [149]	Speed: 2117.391283 samples/sec	accuracy=0.854115
# Epoch[30] Batch [199]	Speed: 3716.912988 samples/sec	accuracy=0.853828
# Epoch[30] Batch [249]	Speed: 3827.410793 samples/sec	accuracy=0.853688
# Epoch[30] Batch [299]	Speed: 3643.458603 samples/sec	accuracy=0.854661
# Epoch[30] Batch [349]	Speed: 3370.272399 samples/sec	accuracy=0.854397
# [Epoch 30] training: accuracy=0.854020
# [Epoch 30] time cost: 15.348173
# [Epoch 30] validation: accuracy=0.835337
# Epoch[31] Batch [49]	Speed: 3920.998174 samples/sec	accuracy=0.855469
# Epoch[31] Batch [99]	Speed: 3956.657273 samples/sec	accuracy=0.855156
# Epoch[31] Batch [149]	Speed: 3396.133120 samples/sec	accuracy=0.854635
# Epoch[31] Batch [199]	Speed: 4062.833255 samples/sec	accuracy=0.857500
# Epoch[31] Batch [249]	Speed: 2879.729830 samples/sec	accuracy=0.857781
# Epoch[31] Batch [299]	Speed: 3822.505603 samples/sec	accuracy=0.858307
# Epoch[31] Batch [349]	Speed: 3919.137670 samples/sec	accuracy=0.858996
# [Epoch 31] training: accuracy=0.858353
# [Epoch 31] time cost: 15.088480
# [Epoch 31] validation: accuracy=0.838341
# Epoch[32] Batch [49]	Speed: 4074.612265 samples/sec	accuracy=0.862344
# Epoch[32] Batch [99]	Speed: 3725.062529 samples/sec	accuracy=0.860625
# Epoch[32] Batch [149]	Speed: 2913.343347 samples/sec	accuracy=0.856667
# Epoch[32] Batch [199]	Speed: 2982.268246 samples/sec	accuracy=0.856289
# Epoch[32] Batch [249]	Speed: 2310.324565 samples/sec	accuracy=0.857781
# Epoch[32] Batch [299]	Speed: 3683.783421 samples/sec	accuracy=0.858672
# Epoch[32] Batch [349]	Speed: 3956.773916 samples/sec	accuracy=0.858549
# [Epoch 32] training: accuracy=0.859055
# [Epoch 32] time cost: 15.360775
# [Epoch 32] validation: accuracy=0.798358
# Epoch[33] Batch [49]	Speed: 4079.411208 samples/sec	accuracy=0.859844
# Epoch[33] Batch [99]	Speed: 3745.959475 samples/sec	accuracy=0.861328
# Epoch[33] Batch [149]	Speed: 4027.266816 samples/sec	accuracy=0.859167
# Epoch[33] Batch [199]	Speed: 3837.697914 samples/sec	accuracy=0.858984
# Epoch[33] Batch [249]	Speed: 4009.611280 samples/sec	accuracy=0.859437
# Epoch[33] Batch [299]	Speed: 3771.935616 samples/sec	accuracy=0.859792
# Epoch[33] Batch [349]	Speed: 2488.001483 samples/sec	accuracy=0.860290
# [Epoch 33] training: accuracy=0.858975
# [Epoch 33] time cost: 14.580614
# [Epoch 33] validation: accuracy=0.828425
# Epoch[34] Batch [49]	Speed: 2063.745126 samples/sec	accuracy=0.858281
# Epoch[34] Batch [99]	Speed: 2348.157159 samples/sec	accuracy=0.858516
# Epoch[34] Batch [149]	Speed: 3877.836211 samples/sec	accuracy=0.860938
# Epoch[34] Batch [199]	Speed: 2590.213259 samples/sec	accuracy=0.860469
# Epoch[34] Batch [249]	Speed: 3900.062561 samples/sec	accuracy=0.861219
# Epoch[34] Batch [299]	Speed: 3740.947879 samples/sec	accuracy=0.862448
# Epoch[34] Batch [349]	Speed: 2627.418403 samples/sec	accuracy=0.862165
# [Epoch 34] training: accuracy=0.862079
# [Epoch 34] time cost: 16.130198
# [Epoch 34] validation: accuracy=0.825421
# Epoch[35] Batch [49]	Speed: 3730.083457 samples/sec	accuracy=0.867188
# Epoch[35] Batch [99]	Speed: 3700.745924 samples/sec	accuracy=0.863359
# Epoch[35] Batch [149]	Speed: 1675.574770 samples/sec	accuracy=0.863750
# Epoch[35] Batch [199]	Speed: 3884.373482 samples/sec	accuracy=0.863242
# Epoch[35] Batch [249]	Speed: 3655.739338 samples/sec	accuracy=0.863344
# Epoch[35] Batch [299]	Speed: 3602.967035 samples/sec	accuracy=0.862552
# Epoch[35] Batch [349]	Speed: 3620.290043 samples/sec	accuracy=0.862299
# [Epoch 35] training: accuracy=0.862532
# [Epoch 35] time cost: 15.454390
# [Epoch 35] validation: accuracy=0.839443
# Epoch[36] Batch [49]	Speed: 3647.220870 samples/sec	accuracy=0.859844
# Epoch[36] Batch [99]	Speed: 3645.512036 samples/sec	accuracy=0.860547
# Epoch[36] Batch [149]	Speed: 3594.042710 samples/sec	accuracy=0.863281
# Epoch[36] Batch [199]	Speed: 3758.179064 samples/sec	accuracy=0.862539
# Epoch[36] Batch [249]	Speed: 3814.060088 samples/sec	accuracy=0.862656
# Epoch[36] Batch [299]	Speed: 3877.920242 samples/sec	accuracy=0.863932
# Epoch[36] Batch [349]	Speed: 3722.453888 samples/sec	accuracy=0.864196
# [Epoch 36] training: accuracy=0.864190
# [Epoch 36] time cost: 15.496023
# [Epoch 36] validation: accuracy=0.823417
# Epoch[37] Batch [49]	Speed: 2681.324663 samples/sec	accuracy=0.858906
# Epoch[37] Batch [99]	Speed: 3933.379578 samples/sec	accuracy=0.859375
# Epoch[37] Batch [149]	Speed: 3890.622664 samples/sec	accuracy=0.861510
# Epoch[37] Batch [199]	Speed: 3245.835396 samples/sec	accuracy=0.862578
# Epoch[37] Batch [249]	Speed: 3621.682106 samples/sec	accuracy=0.863219
# Epoch[37] Batch [299]	Speed: 3696.465219 samples/sec	accuracy=0.864688
# Epoch[37] Batch [349]	Speed: 3786.273834 samples/sec	accuracy=0.864420
# [Epoch 37] training: accuracy=0.864223
# [Epoch 37] time cost: 15.999871
# [Epoch 37] validation: accuracy=0.843550
# Epoch[38] Batch [49]	Speed: 3862.102813 samples/sec	accuracy=0.867188
# Epoch[38] Batch [99]	Speed: 2615.068325 samples/sec	accuracy=0.866016
# Epoch[38] Batch [149]	Speed: 3815.252684 samples/sec	accuracy=0.863490
# Epoch[38] Batch [199]	Speed: 3898.986252 samples/sec	accuracy=0.864844
# Epoch[38] Batch [249]	Speed: 2973.612739 samples/sec	accuracy=0.865344
# Epoch[38] Batch [299]	Speed: 1818.452799 samples/sec	accuracy=0.864635
# Epoch[38] Batch [349]	Speed: 3982.633265 samples/sec	accuracy=0.865960
# [Epoch 38] training: accuracy=0.866728
# [Epoch 38] time cost: 15.780664
# [Epoch 38] validation: accuracy=0.834335
# Epoch[39] Batch [49]	Speed: 3851.270163 samples/sec	accuracy=0.858594
# Epoch[39] Batch [99]	Speed: 3819.106612 samples/sec	accuracy=0.862344
# Epoch[39] Batch [149]	Speed: 2477.130231 samples/sec	accuracy=0.862604
# Epoch[39] Batch [199]	Speed: 2219.483699 samples/sec	accuracy=0.863437
# Epoch[39] Batch [249]	Speed: 3787.449115 samples/sec	accuracy=0.863938
# Epoch[39] Batch [299]	Speed: 4022.499284 samples/sec	accuracy=0.864896
# Epoch[39] Batch [349]	Speed: 3484.206403 samples/sec	accuracy=0.866674
# [Epoch 39] training: accuracy=0.865925
# [Epoch 39] time cost: 15.705457
# [Epoch 39] validation: accuracy=0.830629
# Epoch[40] Batch [49]	Speed: 3009.129956 samples/sec	accuracy=0.860156
# Epoch[40] Batch [99]	Speed: 2853.222536 samples/sec	accuracy=0.860781
# Epoch[40] Batch [149]	Speed: 3818.346067 samples/sec	accuracy=0.862083
# Epoch[40] Batch [199]	Speed: 3826.510566 samples/sec	accuracy=0.862812
# Epoch[40] Batch [249]	Speed: 3343.115462 samples/sec	accuracy=0.864187
# Epoch[40] Batch [299]	Speed: 3967.036214 samples/sec	accuracy=0.864896
# Epoch[40] Batch [349]	Speed: 3620.827204 samples/sec	accuracy=0.865446
# [Epoch 40] training: accuracy=0.864690
# [Epoch 40] time cost: 15.804601
# [Epoch 40] validation: accuracy=0.833366
# Epoch[41] Batch [49]	Speed: 3892.681970 samples/sec	accuracy=0.862812
# Epoch[41] Batch [99]	Speed: 4064.463445 samples/sec	accuracy=0.867109
# Epoch[41] Batch [149]	Speed: 3015.501901 samples/sec	accuracy=0.864219
# Epoch[41] Batch [199]	Speed: 4033.196698 samples/sec	accuracy=0.864883
# Epoch[41] Batch [249]	Speed: 3652.207920 samples/sec	accuracy=0.864313
# Epoch[41] Batch [299]	Speed: 1879.194769 samples/sec	accuracy=0.864193
# Epoch[41] Batch [349]	Speed: 3297.813902 samples/sec	accuracy=0.865714
# [Epoch 41] training: accuracy=0.866248
# [Epoch 41] time cost: 15.495762
# [Epoch 41] validation: accuracy=0.827324
# Epoch[42] Batch [49]	Speed: 3778.067247 samples/sec	accuracy=0.868594
# Epoch[42] Batch [99]	Speed: 2803.078970 samples/sec	accuracy=0.870391
# Epoch[42] Batch [149]	Speed: 3837.752781 samples/sec	accuracy=0.870625
# Epoch[42] Batch [199]	Speed: 2250.615870 samples/sec	accuracy=0.869531
# Epoch[42] Batch [249]	Speed: 3846.331222 samples/sec	accuracy=0.868188
# Epoch[42] Batch [299]	Speed: 3218.901425 samples/sec	accuracy=0.869740
# Epoch[42] Batch [349]	Speed: 3293.423911 samples/sec	accuracy=0.870379
# [Epoch 42] training: accuracy=0.869732
# [Epoch 42] time cost: 15.895624
# [Epoch 42] validation: accuracy=0.817007
# Epoch[43] Batch [49]	Speed: 3779.423672 samples/sec	accuracy=0.859531
# Epoch[43] Batch [99]	Speed: 3628.633981 samples/sec	accuracy=0.862344
# Epoch[43] Batch [149]	Speed: 3918.822990 samples/sec	accuracy=0.862552
# Epoch[43] Batch [199]	Speed: 3861.325048 samples/sec	accuracy=0.863633
# Epoch[43] Batch [249]	Speed: 3370.018530 samples/sec	accuracy=0.864531
# Epoch[43] Batch [299]	Speed: 3015.637407 samples/sec	accuracy=0.865339
# Epoch[43] Batch [349]	Speed: 3494.479816 samples/sec	accuracy=0.866942
# [Epoch 43] training: accuracy=0.867267
# [Epoch 43] time cost: 16.171615
# [Epoch 43] validation: accuracy=0.834135
# Epoch[44] Batch [49]	Speed: 1485.748912 samples/sec	accuracy=0.869375
# Epoch[44] Batch [99]	Speed: 3949.961830 samples/sec	accuracy=0.867109
# Epoch[44] Batch [149]	Speed: 3918.136591 samples/sec	accuracy=0.867969
# Epoch[44] Batch [199]	Speed: 3943.375901 samples/sec	accuracy=0.866836
# Epoch[44] Batch [249]	Speed: 3498.533208 samples/sec	accuracy=0.867875
# Epoch[44] Batch [299]	Speed: 3665.373432 samples/sec	accuracy=0.868047
# Epoch[44] Batch [349]	Speed: 3731.976282 samples/sec	accuracy=0.868549
# [Epoch 44] training: accuracy=0.868506
# [Epoch 44] time cost: 15.522820
# [Epoch 44] validation: accuracy=0.835437
# Epoch[45] Batch [49]	Speed: 3852.347928 samples/sec	accuracy=0.867188
# Epoch[45] Batch [99]	Speed: 2682.651077 samples/sec	accuracy=0.866094
# Epoch[45] Batch [149]	Speed: 3825.528983 samples/sec	accuracy=0.863750
# Epoch[45] Batch [199]	Speed: 3973.407383 samples/sec	accuracy=0.868164
# Epoch[45] Batch [249]	Speed: 1675.982768 samples/sec	accuracy=0.868250
# Epoch[45] Batch [299]	Speed: 3007.663330 samples/sec	accuracy=0.867500
# Epoch[45] Batch [349]	Speed: 3630.007924 samples/sec	accuracy=0.869442
# [Epoch 45] training: accuracy=0.869291
# [Epoch 45] time cost: 15.576280
# [Epoch 45] validation: accuracy=0.827123
# Epoch[46] Batch [49]	Speed: 3719.488098 samples/sec	accuracy=0.875000
# Epoch[46] Batch [99]	Speed: 3910.260251 samples/sec	accuracy=0.871875
# Epoch[46] Batch [149]	Speed: 3682.242195 samples/sec	accuracy=0.871615
# Epoch[46] Batch [199]	Speed: 2704.434990 samples/sec	accuracy=0.871836
# Epoch[46] Batch [249]	Speed: 3763.975714 samples/sec	accuracy=0.870406
# Epoch[46] Batch [299]	Speed: 3753.554583 samples/sec	accuracy=0.870703
# Epoch[46] Batch [349]	Speed: 3981.156608 samples/sec	accuracy=0.871429
# [Epoch 46] training: accuracy=0.871603
# [Epoch 46] time cost: 15.653429
# [Epoch 46] validation: accuracy=0.790966
# Epoch[47] Batch [49]	Speed: 1828.286725 samples/sec	accuracy=0.869531
# Epoch[47] Batch [99]	Speed: 3998.710810 samples/sec	accuracy=0.867812
# Epoch[47] Batch [149]	Speed: 3806.407306 samples/sec	accuracy=0.869635
# Epoch[47] Batch [199]	Speed: 3923.491154 samples/sec	accuracy=0.869297
# Epoch[47] Batch [249]	Speed: 3745.985613 samples/sec	accuracy=0.869344
# Epoch[47] Batch [299]	Speed: 3952.026265 samples/sec	accuracy=0.869583
# Epoch[47] Batch [349]	Speed: 3071.150626 samples/sec	accuracy=0.871116
# [Epoch 47] training: accuracy=0.870913
# [Epoch 47] time cost: 15.137374
# [Epoch 47] validation: accuracy=0.829127
# Epoch[48] Batch [49]	Speed: 3935.224787 samples/sec	accuracy=0.872500
# Epoch[48] Batch [99]	Speed: 3766.272963 samples/sec	accuracy=0.873281
# Epoch[48] Batch [149]	Speed: 3868.364103 samples/sec	accuracy=0.872344
# Epoch[48] Batch [199]	Speed: 2303.247682 samples/sec	accuracy=0.871328
# Epoch[48] Batch [249]	Speed: 3848.481828 samples/sec	accuracy=0.871594
# Epoch[48] Batch [299]	Speed: 4011.348884 samples/sec	accuracy=0.871432
# Epoch[48] Batch [349]	Speed: 2977.967240 samples/sec	accuracy=0.870826
# [Epoch 48] training: accuracy=0.870524
# [Epoch 48] time cost: 14.947777
# [Epoch 48] validation: accuracy=0.833861
# Epoch[49] Batch [49]	Speed: 4012.548110 samples/sec	accuracy=0.870000
# Epoch[49] Batch [99]	Speed: 3444.483088 samples/sec	accuracy=0.871328
# Epoch[49] Batch [149]	Speed: 1689.575025 samples/sec	accuracy=0.869219
# Epoch[49] Batch [199]	Speed: 3555.624881 samples/sec	accuracy=0.870703
# Epoch[49] Batch [249]	Speed: 2256.442756 samples/sec	accuracy=0.869812
# Epoch[49] Batch [299]	Speed: 2801.396923 samples/sec	accuracy=0.869870
# Epoch[49] Batch [349]	Speed: 4003.422086 samples/sec	accuracy=0.870826
# [Epoch 49] training: accuracy=0.870205
# [Epoch 49] time cost: 15.691192
# [Epoch 49] validation: accuracy=0.839143
# Epoch[50] Batch [49]	Speed: 2928.008813 samples/sec	accuracy=0.877031
# Epoch[50] Batch [99]	Speed: 2283.381374 samples/sec	accuracy=0.871406
# Epoch[50] Batch [149]	Speed: 3819.758749 samples/sec	accuracy=0.873073
# Epoch[50] Batch [199]	Speed: 3831.836241 samples/sec	accuracy=0.872422
# Epoch[50] Batch [249]	Speed: 3044.089882 samples/sec	accuracy=0.872781
# Epoch[50] Batch [299]	Speed: 2014.358710 samples/sec	accuracy=0.871849
# Epoch[50] Batch [349]	Speed: 3903.947877 samples/sec	accuracy=0.872701
# [Epoch 50] training: accuracy=0.873498
# [Epoch 50] time cost: 15.988715
# [Epoch 50] validation: accuracy=0.825621
# Epoch[51] Batch [49]	Speed: 2465.006001 samples/sec	accuracy=0.875156
# Epoch[51] Batch [99]	Speed: 3817.477243 samples/sec	accuracy=0.869687
# Epoch[51] Batch [149]	Speed: 4016.811157 samples/sec	accuracy=0.869427
# Epoch[51] Batch [199]	Speed: 2853.586508 samples/sec	accuracy=0.870313
# Epoch[51] Batch [249]	Speed: 3552.331154 samples/sec	accuracy=0.871500
# Epoch[51] Batch [299]	Speed: 1773.408048 samples/sec	accuracy=0.872526
# Epoch[51] Batch [349]	Speed: 3928.687869 samples/sec	accuracy=0.873259
# [Epoch 51] training: accuracy=0.873521
# [Epoch 51] time cost: 15.847744
# [Epoch 51] validation: accuracy=0.832532
# Epoch[52] Batch [49]	Speed: 3953.423162 samples/sec	accuracy=0.867344
# Epoch[52] Batch [99]	Speed: 4110.299749 samples/sec	accuracy=0.873125
# Epoch[52] Batch [149]	Speed: 1716.580695 samples/sec	accuracy=0.873437
# Epoch[52] Batch [199]	Speed: 3527.914101 samples/sec	accuracy=0.872422
# Epoch[52] Batch [249]	Speed: 3512.288849 samples/sec	accuracy=0.873563
# Epoch[52] Batch [299]	Speed: 2995.546955 samples/sec	accuracy=0.872604
# Epoch[52] Batch [349]	Speed: 2762.932356 samples/sec	accuracy=0.873884
# [Epoch 52] training: accuracy=0.873501
# [Epoch 52] time cost: 14.902017
# [Epoch 52] validation: accuracy=0.817308
# Epoch[53] Batch [49]	Speed: 3079.182771 samples/sec	accuracy=0.873125
# Epoch[53] Batch [99]	Speed: 3318.873364 samples/sec	accuracy=0.871016
# Epoch[53] Batch [149]	Speed: 3960.451703 samples/sec	accuracy=0.871667
# Epoch[53] Batch [199]	Speed: 3753.475855 samples/sec	accuracy=0.872070
# Epoch[53] Batch [249]	Speed: 3541.107914 samples/sec	accuracy=0.872625
# Epoch[53] Batch [299]	Speed: 3908.267661 samples/sec	accuracy=0.872760
# Epoch[53] Batch [349]	Speed: 3451.369707 samples/sec	accuracy=0.874129
# [Epoch 53] training: accuracy=0.874439
# [Epoch 53] time cost: 15.698350
# [Epoch 53] validation: accuracy=0.835637
# Epoch[54] Batch [49]	Speed: 1800.553080 samples/sec	accuracy=0.875781
# Epoch[54] Batch [99]	Speed: 3961.649918 samples/sec	accuracy=0.875000
# Epoch[54] Batch [149]	Speed: 3875.764597 samples/sec	accuracy=0.874792
# Epoch[54] Batch [199]	Speed: 3929.061643 samples/sec	accuracy=0.874336
# Epoch[54] Batch [249]	Speed: 2181.701454 samples/sec	accuracy=0.876500
# Epoch[54] Batch [299]	Speed: 3653.525186 samples/sec	accuracy=0.875807
# Epoch[54] Batch [349]	Speed: 3694.531962 samples/sec	accuracy=0.876451
# [Epoch 54] training: accuracy=0.875779
# [Epoch 54] time cost: 15.972163
# [Epoch 54] validation: accuracy=0.795172
# Epoch[55] Batch [49]	Speed: 3724.158131 samples/sec	accuracy=0.872500
# Epoch[55] Batch [99]	Speed: 3782.272671 samples/sec	accuracy=0.871953
# Epoch[55] Batch [149]	Speed: 3574.825790 samples/sec	accuracy=0.871302
# Epoch[55] Batch [199]	Speed: 3762.814954 samples/sec	accuracy=0.873789
# Epoch[55] Batch [249]	Speed: 3416.143805 samples/sec	accuracy=0.874437
# Epoch[55] Batch [299]	Speed: 3916.850241 samples/sec	accuracy=0.874089
# Epoch[55] Batch [349]	Speed: 3851.767518 samples/sec	accuracy=0.875379
# [Epoch 55] training: accuracy=0.875341
# [Epoch 55] time cost: 15.355228
# [Epoch 55] validation: accuracy=0.840345
# Epoch[56] Batch [49]	Speed: 3429.520850 samples/sec	accuracy=0.872969
# Epoch[56] Batch [99]	Speed: 3671.012623 samples/sec	accuracy=0.876563
# Epoch[56] Batch [149]	Speed: 3988.195313 samples/sec	accuracy=0.877292
# Epoch[56] Batch [199]	Speed: 3370.716760 samples/sec	accuracy=0.876563
# Epoch[56] Batch [249]	Speed: 3804.303454 samples/sec	accuracy=0.876844
# Epoch[56] Batch [299]	Speed: 3439.473845 samples/sec	accuracy=0.877630
# Epoch[56] Batch [349]	Speed: 1577.491720 samples/sec	accuracy=0.877455
# [Epoch 56] training: accuracy=0.877338
# [Epoch 56] time cost: 16.046084
# [Epoch 56] validation: accuracy=0.842069
# Epoch[57] Batch [49]	Speed: 2459.168500 samples/sec	accuracy=0.876875
# Epoch[57] Batch [99]	Speed: 3468.987497 samples/sec	accuracy=0.874375
# Epoch[57] Batch [149]	Speed: 2644.241418 samples/sec	accuracy=0.876198
# Epoch[57] Batch [199]	Speed: 2848.529561 samples/sec	accuracy=0.878008
# Epoch[57] Batch [249]	Speed: 3376.822709 samples/sec	accuracy=0.878313
# Epoch[57] Batch [299]	Speed: 3809.486355 samples/sec	accuracy=0.877969
# Epoch[57] Batch [349]	Speed: 3793.550911 samples/sec	accuracy=0.878504
# [Epoch 57] training: accuracy=0.878117
# [Epoch 57] time cost: 16.138668
# [Epoch 57] validation: accuracy=0.819611
# Epoch[58] Batch [49]	Speed: 2760.971520 samples/sec	accuracy=0.878906
# Epoch[58] Batch [99]	Speed: 3869.981417 samples/sec	accuracy=0.879609
# Epoch[58] Batch [149]	Speed: 3396.971173 samples/sec	accuracy=0.877500
# Epoch[58] Batch [199]	Speed: 1741.781041 samples/sec	accuracy=0.876758
# Epoch[58] Batch [249]	Speed: 3769.604988 samples/sec	accuracy=0.877188
# Epoch[58] Batch [299]	Speed: 3206.194831 samples/sec	accuracy=0.877083
# Epoch[58] Batch [349]	Speed: 3903.436956 samples/sec	accuracy=0.879085
# [Epoch 58] training: accuracy=0.878385
# [Epoch 58] time cost: 15.651486
# [Epoch 58] validation: accuracy=0.822516
# Epoch[59] Batch [49]	Speed: 3550.545685 samples/sec	accuracy=0.875938
# Epoch[59] Batch [99]	Speed: 3958.320089 samples/sec	accuracy=0.875547
# Epoch[59] Batch [149]	Speed: 2289.281760 samples/sec	accuracy=0.874896
# Epoch[59] Batch [199]	Speed: 3921.456415 samples/sec	accuracy=0.873789
# Epoch[59] Batch [249]	Speed: 3914.679656 samples/sec	accuracy=0.874531
# Epoch[59] Batch [299]	Speed: 3792.184329 samples/sec	accuracy=0.875026
# Epoch[59] Batch [349]	Speed: 3737.718344 samples/sec	accuracy=0.876473
# [Epoch 59] training: accuracy=0.876479
# [Epoch 59] time cost: 15.266822
# [Epoch 59] validation: accuracy=0.820713
# Epoch[60] Batch [49]	Speed: 1745.762701 samples/sec	accuracy=0.885000
# Epoch[60] Batch [99]	Speed: 2456.490501 samples/sec	accuracy=0.880000
# Epoch[60] Batch [149]	Speed: 2722.565771 samples/sec	accuracy=0.877135
# Epoch[60] Batch [199]	Speed: 3935.570956 samples/sec	accuracy=0.877461
# Epoch[60] Batch [249]	Speed: 3781.340283 samples/sec	accuracy=0.876875
# Epoch[60] Batch [299]	Speed: 3838.466189 samples/sec	accuracy=0.876745
# Epoch[60] Batch [349]	Speed: 3992.466123 samples/sec	accuracy=0.878125
# [Epoch 60] training: accuracy=0.878337
# [Epoch 60] time cost: 15.361937
# [Epoch 60] validation: accuracy=0.833834
# Epoch[61] Batch [49]	Speed: 3639.408010 samples/sec	accuracy=0.881719
# Epoch[61] Batch [99]	Speed: 3911.684775 samples/sec	accuracy=0.881328
# Epoch[61] Batch [149]	Speed: 3532.045474 samples/sec	accuracy=0.883281
# Epoch[61] Batch [199]	Speed: 3620.021523 samples/sec	accuracy=0.881016
# Epoch[61] Batch [249]	Speed: 2243.083883 samples/sec	accuracy=0.880281
# Epoch[61] Batch [299]	Speed: 3232.506921 samples/sec	accuracy=0.879818
# Epoch[61] Batch [349]	Speed: 3970.703745 samples/sec	accuracy=0.880112
# [Epoch 61] training: accuracy=0.880068
# [Epoch 61] time cost: 15.705746
# [Epoch 61] validation: accuracy=0.803786
# Epoch[62] Batch [49]	Speed: 3550.146550 samples/sec	accuracy=0.882031
# Epoch[62] Batch [99]	Speed: 3952.404494 samples/sec	accuracy=0.881172
# Epoch[62] Batch [149]	Speed: 2424.628369 samples/sec	accuracy=0.881042
# Epoch[62] Batch [199]	Speed: 3632.242803 samples/sec	accuracy=0.881172
# Epoch[62] Batch [249]	Speed: 2949.694312 samples/sec	accuracy=0.879906
# Epoch[62] Batch [299]	Speed: 2153.029853 samples/sec	accuracy=0.879375
# Epoch[62] Batch [349]	Speed: 3745.044903 samples/sec	accuracy=0.880067
# [Epoch 62] training: accuracy=0.880715
# [Epoch 62] time cost: 16.032933
# [Epoch 62] validation: accuracy=0.849659
# Epoch[63] Batch [49]	Speed: 3999.753490 samples/sec	accuracy=0.881875
# Epoch[63] Batch [99]	Speed: 3018.944139 samples/sec	accuracy=0.881641
# Epoch[63] Batch [149]	Speed: 3644.596364 samples/sec	accuracy=0.883542
# Epoch[63] Batch [199]	Speed: 3900.997733 samples/sec	accuracy=0.882305
# Epoch[63] Batch [249]	Speed: 3765.982351 samples/sec	accuracy=0.881344
# Epoch[63] Batch [299]	Speed: 3822.777784 samples/sec	accuracy=0.882578
# Epoch[63] Batch [349]	Speed: 3871.432573 samples/sec	accuracy=0.883772
# [Epoch 63] training: accuracy=0.883213
# [Epoch 63] time cost: 15.587617
# [Epoch 63] validation: accuracy=0.827925
# Epoch[64] Batch [49]	Speed: 2785.842814 samples/sec	accuracy=0.884375
# Epoch[64] Batch [99]	Speed: 3760.917072 samples/sec	accuracy=0.879922
# Epoch[64] Batch [149]	Speed: 2227.171857 samples/sec	accuracy=0.877448
# Epoch[64] Batch [199]	Speed: 3850.966287 samples/sec	accuracy=0.879219
# Epoch[64] Batch [249]	Speed: 3345.156843 samples/sec	accuracy=0.879188
# Epoch[64] Batch [299]	Speed: 3742.956126 samples/sec	accuracy=0.879375
# Epoch[64] Batch [349]	Speed: 2299.065644 samples/sec	accuracy=0.880112
# [Epoch 64] training: accuracy=0.880255
# [Epoch 64] time cost: 15.671157
# [Epoch 64] validation: accuracy=0.843651
# Epoch[65] Batch [49]	Speed: 2439.335505 samples/sec	accuracy=0.874531
# Epoch[65] Batch [99]	Speed: 2821.730510 samples/sec	accuracy=0.876484
# Epoch[65] Batch [149]	Speed: 4055.283802 samples/sec	accuracy=0.877656
# Epoch[65] Batch [199]	Speed: 3773.261120 samples/sec	accuracy=0.876250
# Epoch[65] Batch [249]	Speed: 2839.880622 samples/sec	accuracy=0.877375
# Epoch[65] Batch [299]	Speed: 3950.049016 samples/sec	accuracy=0.878099
# Epoch[65] Batch [349]	Speed: 3922.545168 samples/sec	accuracy=0.879732
# [Epoch 65] training: accuracy=0.880355
# [Epoch 65] time cost: 16.165025
# [Epoch 65] validation: accuracy=0.854267
# Epoch[66] Batch [49]	Speed: 2744.472224 samples/sec	accuracy=0.882656
# Epoch[66] Batch [99]	Speed: 3677.449908 samples/sec	accuracy=0.882422
# Epoch[66] Batch [149]	Speed: 3901.451311 samples/sec	accuracy=0.884948
# Epoch[66] Batch [199]	Speed: 3524.255015 samples/sec	accuracy=0.882539
# Epoch[66] Batch [249]	Speed: 3558.547286 samples/sec	accuracy=0.881938
# Epoch[66] Batch [299]	Speed: 3952.026265 samples/sec	accuracy=0.882552
# Epoch[66] Batch [349]	Speed: 3932.832115 samples/sec	accuracy=0.884330
# [Epoch 66] training: accuracy=0.883854
# [Epoch 66] time cost: 15.643987
# [Epoch 66] validation: accuracy=0.816406
# Epoch[67] Batch [49]	Speed: 3689.783728 samples/sec	accuracy=0.879219
# Epoch[67] Batch [99]	Speed: 3898.306784 samples/sec	accuracy=0.881875
# Epoch[67] Batch [149]	Speed: 3917.850663 samples/sec	accuracy=0.880781
# Epoch[67] Batch [199]	Speed: 3956.978058 samples/sec	accuracy=0.879297
# Epoch[67] Batch [249]	Speed: 2514.405867 samples/sec	accuracy=0.879625
# Epoch[67] Batch [299]	Speed: 2476.501767 samples/sec	accuracy=0.880026
# Epoch[67] Batch [349]	Speed: 3814.249769 samples/sec	accuracy=0.880781
# [Epoch 67] training: accuracy=0.880395
# [Epoch 67] time cost: 16.250060
# [Epoch 67] validation: accuracy=0.820813
# Epoch[68] Batch [49]	Speed: 3979.799050 samples/sec	accuracy=0.875469
# Epoch[68] Batch [99]	Speed: 2269.510699 samples/sec	accuracy=0.880625
# Epoch[68] Batch [149]	Speed: 3957.007223 samples/sec	accuracy=0.879896
# Epoch[68] Batch [199]	Speed: 2735.146225 samples/sec	accuracy=0.881445
# Epoch[68] Batch [249]	Speed: 2967.777291 samples/sec	accuracy=0.882219
# Epoch[68] Batch [299]	Speed: 2979.752305 samples/sec	accuracy=0.881484
# Epoch[68] Batch [349]	Speed: 3924.265482 samples/sec	accuracy=0.881763
# [Epoch 68] training: accuracy=0.881754
# [Epoch 68] time cost: 15.908869
# [Epoch 68] validation: accuracy=0.837540
# Epoch[69] Batch [49]	Speed: 4039.052904 samples/sec	accuracy=0.884375
# Epoch[69] Batch [99]	Speed: 1931.106974 samples/sec	accuracy=0.879844
# Epoch[69] Batch [149]	Speed: 4010.330106 samples/sec	accuracy=0.879427
# Epoch[69] Batch [199]	Speed: 4006.618944 samples/sec	accuracy=0.878633
# Epoch[69] Batch [249]	Speed: 3522.636327 samples/sec	accuracy=0.879719
# Epoch[69] Batch [299]	Speed: 3766.642897 samples/sec	accuracy=0.881198
# Epoch[69] Batch [349]	Speed: 3878.872848 samples/sec	accuracy=0.881362
# [Epoch 69] training: accuracy=0.881851
# [Epoch 69] time cost: 15.410942
# [Epoch 69] validation: accuracy=0.844852
# Epoch[70] Batch [49]	Speed: 2224.670827 samples/sec	accuracy=0.880313
# Epoch[70] Batch [99]	Speed: 3304.492063 samples/sec	accuracy=0.883359
# Epoch[70] Batch [149]	Speed: 3820.737373 samples/sec	accuracy=0.882760
# Epoch[70] Batch [199]	Speed: 3812.001903 samples/sec	accuracy=0.884648
# Epoch[70] Batch [249]	Speed: 2471.417250 samples/sec	accuracy=0.885062
# Epoch[70] Batch [299]	Speed: 3915.393398 samples/sec	accuracy=0.885182
# Epoch[70] Batch [349]	Speed: 3958.991446 samples/sec	accuracy=0.884107
# [Epoch 70] training: accuracy=0.883552
# [Epoch 70] time cost: 15.839699
# [Epoch 70] validation: accuracy=0.815304
# Epoch[71] Batch [49]	Speed: 3985.412348 samples/sec	accuracy=0.886094
# Epoch[71] Batch [99]	Speed: 3969.441350 samples/sec	accuracy=0.886016
# Epoch[71] Batch [149]	Speed: 3728.322004 samples/sec	accuracy=0.883646
# Epoch[71] Batch [199]	Speed: 1913.500773 samples/sec	accuracy=0.883672
# Epoch[71] Batch [249]	Speed: 3720.055101 samples/sec	accuracy=0.884906
# Epoch[71] Batch [299]	Speed: 3309.237965 samples/sec	accuracy=0.885286
# Epoch[71] Batch [349]	Speed: 4034.742541 samples/sec	accuracy=0.885335
# [Epoch 71] training: accuracy=0.885557
# [Epoch 71] time cost: 15.137295
# [Epoch 71] validation: accuracy=0.850861
# Epoch[72] Batch [49]	Speed: 3102.654430 samples/sec	accuracy=0.880938
# Epoch[72] Batch [99]	Speed: 3768.837571 samples/sec	accuracy=0.882969
# Epoch[72] Batch [149]	Speed: 3952.870106 samples/sec	accuracy=0.883125
# Epoch[72] Batch [199]	Speed: 3840.800338 samples/sec	accuracy=0.882812
# Epoch[72] Batch [249]	Speed: 3717.530689 samples/sec	accuracy=0.880281
# Epoch[72] Batch [299]	Speed: 2447.096335 samples/sec	accuracy=0.882240
# Epoch[72] Batch [349]	Speed: 2596.765654 samples/sec	accuracy=0.883103
# [Epoch 72] training: accuracy=0.882972
# [Epoch 72] time cost: 15.975569
# [Epoch 72] validation: accuracy=0.855222
# Epoch[73] Batch [49]	Speed: 2524.894827 samples/sec	accuracy=0.882031
# Epoch[73] Batch [99]	Speed: 3759.889851 samples/sec	accuracy=0.882422
# Epoch[73] Batch [149]	Speed: 2756.817508 samples/sec	accuracy=0.883281
# Epoch[73] Batch [199]	Speed: 3766.167280 samples/sec	accuracy=0.882656
# Epoch[73] Batch [249]	Speed: 3795.562380 samples/sec	accuracy=0.882812
# Epoch[73] Batch [299]	Speed: 2960.380431 samples/sec	accuracy=0.883672
# Epoch[73] Batch [349]	Speed: 3852.182079 samples/sec	accuracy=0.883884
# [Epoch 73] training: accuracy=0.883612
# [Epoch 73] time cost: 15.941403
# [Epoch 73] validation: accuracy=0.853766
# Epoch[74] Batch [49]	Speed: 3879.237203 samples/sec	accuracy=0.889531
# Epoch[74] Batch [99]	Speed: 2315.875594 samples/sec	accuracy=0.884062
# Epoch[74] Batch [149]	Speed: 3656.635713 samples/sec	accuracy=0.882552
# Epoch[74] Batch [199]	Speed: 4046.541990 samples/sec	accuracy=0.881484
# Epoch[74] Batch [249]	Speed: 2143.530977 samples/sec	accuracy=0.882625
# Epoch[74] Batch [299]	Speed: 2962.013727 samples/sec	accuracy=0.882708
# Epoch[74] Batch [349]	Speed: 3979.356568 samples/sec	accuracy=0.883214
# [Epoch 74] training: accuracy=0.882652
# [Epoch 74] time cost: 15.609570
# [Epoch 74] validation: accuracy=0.848658
# Epoch[75] Batch [49]	Speed: 3926.877506 samples/sec	accuracy=0.883281
# Epoch[75] Batch [99]	Speed: 4033.833078 samples/sec	accuracy=0.885234
# Epoch[75] Batch [149]	Speed: 3591.758458 samples/sec	accuracy=0.886615
# Epoch[75] Batch [199]	Speed: 3747.345250 samples/sec	accuracy=0.886797
# Epoch[75] Batch [249]	Speed: 3523.630488 samples/sec	accuracy=0.885906
# Epoch[75] Batch [299]	Speed: 3225.147251 samples/sec	accuracy=0.884948
# Epoch[75] Batch [349]	Speed: 3991.486588 samples/sec	accuracy=0.886205
# [Epoch 75] training: accuracy=0.885949
# [Epoch 75] time cost: 15.580562
# [Epoch 75] validation: accuracy=0.838542
# Epoch[76] Batch [49]	Speed: 3549.606686 samples/sec	accuracy=0.885625
# Epoch[76] Batch [99]	Speed: 3896.354632 samples/sec	accuracy=0.882969
# Epoch[76] Batch [149]	Speed: 3734.026847 samples/sec	accuracy=0.885625
# Epoch[76] Batch [199]	Speed: 3844.072919 samples/sec	accuracy=0.882695
# Epoch[76] Batch [249]	Speed: 3472.959466 samples/sec	accuracy=0.883844
# Epoch[76] Batch [299]	Speed: 3809.026882 samples/sec	accuracy=0.884505
# Epoch[76] Batch [349]	Speed: 2244.087110 samples/sec	accuracy=0.885067
# [Epoch 76] training: accuracy=0.884671
# [Epoch 76] time cost: 16.146632
# [Epoch 76] validation: accuracy=0.846755
# Epoch[77] Batch [49]	Speed: 4059.085707 samples/sec	accuracy=0.887500
# Epoch[77] Batch [99]	Speed: 3402.633473 samples/sec	accuracy=0.878984
# Epoch[77] Batch [149]	Speed: 3846.303666 samples/sec	accuracy=0.877917
# Epoch[77] Batch [199]	Speed: 2593.178407 samples/sec	accuracy=0.879844
# Epoch[77] Batch [249]	Speed: 3722.015169 samples/sec	accuracy=0.879250
# Epoch[77] Batch [299]	Speed: 3658.828702 samples/sec	accuracy=0.879714
# Epoch[77] Batch [349]	Speed: 3691.991280 samples/sec	accuracy=0.881741
# [Epoch 77] training: accuracy=0.882632
# [Epoch 77] time cost: 15.711364
# [Epoch 77] validation: accuracy=0.851162
# Epoch[78] Batch [49]	Speed: 2686.678537 samples/sec	accuracy=0.881719
# Epoch[78] Batch [99]	Speed: 3902.812678 samples/sec	accuracy=0.881328
# Epoch[78] Batch [149]	Speed: 3862.686342 samples/sec	accuracy=0.882917
# Epoch[78] Batch [199]	Speed: 2284.858479 samples/sec	accuracy=0.882891
# Epoch[78] Batch [249]	Speed: 2637.991853 samples/sec	accuracy=0.883125
# Epoch[78] Batch [299]	Speed: 2862.258220 samples/sec	accuracy=0.883464
# Epoch[78] Batch [349]	Speed: 3936.754161 samples/sec	accuracy=0.884129
# [Epoch 78] training: accuracy=0.884311
# [Epoch 78] time cost: 15.410105
# [Epoch 78] validation: accuracy=0.835136
# Epoch[79] Batch [49]	Speed: 3924.036019 samples/sec	accuracy=0.883906
# Epoch[79] Batch [99]	Speed: 3884.514008 samples/sec	accuracy=0.886406
# ...
# Epoch[224] Batch [99]	Speed: 2599.317876 samples/sec	accuracy=0.986484
# Epoch[224] Batch [149]	Speed: 2294.722203 samples/sec	accuracy=0.986927
# Epoch[224] Batch [199]	Speed: 3353.766317 samples/sec	accuracy=0.986992
# Epoch[224] Batch [249]	Speed: 3632.488562 samples/sec	accuracy=0.987594
# Epoch[224] Batch [299]	Speed: 3849.502829 samples/sec	accuracy=0.987760
# Epoch[224] Batch [349]	Speed: 2287.438271 samples/sec	accuracy=0.988125
# [Epoch 224] training: accuracy=0.987732
# [Epoch 224] time cost: 16.159385
# [Epoch 224] validation: accuracy=0.913964
# Epoch[225] Batch [49]	Speed: 3842.449682 samples/sec	accuracy=0.991563
# Epoch[225] Batch [99]	Speed: 3831.781543 samples/sec	accuracy=0.989141
# Epoch[225] Batch [149]	Speed: 3194.215188 samples/sec	accuracy=0.989479
# Epoch[225] Batch [199]	Speed: 3164.075933 samples/sec	accuracy=0.988711
# Epoch[225] Batch [249]	Speed: 3679.466191 samples/sec	accuracy=0.988563
# Epoch[225] Batch [299]	Speed: 3840.690432 samples/sec	accuracy=0.988333
# Epoch[225] Batch [349]	Speed: 3861.269505 samples/sec	accuracy=0.988304
# [Epoch 225] training: accuracy=0.988371
# [Epoch 225] time cost: 15.905958
# [Epoch 225] validation: accuracy=0.915064
# Epoch[226] Batch [49]	Speed: 2682.878977 samples/sec	accuracy=0.988906
# Epoch[226] Batch [99]	Speed: 2393.390123 samples/sec	accuracy=0.988281
# Epoch[226] Batch [149]	Speed: 3828.584452 samples/sec	accuracy=0.988229
# Epoch[226] Batch [199]	Speed: 2828.435041 samples/sec	accuracy=0.988242
# Epoch[226] Batch [249]	Speed: 2770.746434 samples/sec	accuracy=0.988313
# Epoch[226] Batch [299]	Speed: 2715.556302 samples/sec	accuracy=0.988203
# Epoch[226] Batch [349]	Speed: 3751.770898 samples/sec	accuracy=0.988393
# [Epoch 226] training: accuracy=0.988421
# [Epoch 226] time cost: 16.415807
# [Epoch 226] validation: accuracy=0.914363
# Epoch[227] Batch [49]	Speed: 2949.467441 samples/sec	accuracy=0.988750
# Epoch[227] Batch [99]	Speed: 3803.441008 samples/sec	accuracy=0.987734
# Epoch[227] Batch [149]	Speed: 2929.606574 samples/sec	accuracy=0.987917
# Epoch[227] Batch [199]	Speed: 3646.353870 samples/sec	accuracy=0.988125
# Epoch[227] Batch [249]	Speed: 2829.538163 samples/sec	accuracy=0.988062
# Epoch[227] Batch [299]	Speed: 3924.523659 samples/sec	accuracy=0.988177
# Epoch[227] Batch [349]	Speed: 3680.399471 samples/sec	accuracy=0.988125
# [Epoch 227] training: accuracy=0.988271
# [Epoch 227] time cost: 15.974571
# [Epoch 227] validation: accuracy=0.914263
# Epoch[228] Batch [49]	Speed: 2720.413643 samples/sec	accuracy=0.989375
# Epoch[228] Batch [99]	Speed: 2695.960671 samples/sec	accuracy=0.988672
# Epoch[228] Batch [149]	Speed: 3873.806999 samples/sec	accuracy=0.988333
# Epoch[228] Batch [199]	Speed: 3384.849076 samples/sec	accuracy=0.988398
# Epoch[228] Batch [249]	Speed: 2238.323780 samples/sec	accuracy=0.988344
# Epoch[228] Batch [299]	Speed: 3705.343410 samples/sec	accuracy=0.988542
# Epoch[228] Batch [349]	Speed: 3642.321551 samples/sec	accuracy=0.988415
# [Epoch 228] training: accuracy=0.988251
# [Epoch 228] time cost: 15.038986
# [Epoch 228] validation: accuracy=0.913862
# Epoch[229] Batch [49]	Speed: 3840.058595 samples/sec	accuracy=0.989062
# Epoch[229] Batch [99]	Speed: 3739.280325 samples/sec	accuracy=0.990078
# Epoch[229] Batch [149]	Speed: 3801.017473 samples/sec	accuracy=0.989635
# Epoch[229] Batch [199]	Speed: 3901.196160 samples/sec	accuracy=0.989570
# Epoch[229] Batch [249]	Speed: 2319.748145 samples/sec	accuracy=0.989344
# Epoch[229] Batch [299]	Speed: 3106.047036 samples/sec	accuracy=0.989115
# Epoch[229] Batch [349]	Speed: 2647.618848 samples/sec	accuracy=0.989330
# [Epoch 229] training: accuracy=0.989263
# [Epoch 229] time cost: 15.434252
# [Epoch 229] validation: accuracy=0.915765
# Epoch[230] Batch [49]	Speed: 3790.925801 samples/sec	accuracy=0.989219
# Epoch[230] Batch [99]	Speed: 2738.047675 samples/sec	accuracy=0.989453
# Epoch[230] Batch [149]	Speed: 3768.202704 samples/sec	accuracy=0.988750
# Epoch[230] Batch [199]	Speed: 3788.277592 samples/sec	accuracy=0.988789
# Epoch[230] Batch [249]	Speed: 3716.321217 samples/sec	accuracy=0.988781
# Epoch[230] Batch [299]	Speed: 3341.846064 samples/sec	accuracy=0.988984
# Epoch[230] Batch [349]	Speed: 3661.898315 samples/sec	accuracy=0.989129
# [Epoch 230] training: accuracy=0.988711
# [Epoch 230] time cost: 14.885568
# [Epoch 230] validation: accuracy=0.914163
# Epoch[231] Batch [49]	Speed: 3240.330460 samples/sec	accuracy=0.990313
# Epoch[231] Batch [99]	Speed: 3813.111963 samples/sec	accuracy=0.990078
# Epoch[231] Batch [149]	Speed: 3870.678952 samples/sec	accuracy=0.989948
# Epoch[231] Batch [199]	Speed: 3188.675473 samples/sec	accuracy=0.988984
# Epoch[231] Batch [249]	Speed: 2799.862904 samples/sec	accuracy=0.989344
# Epoch[231] Batch [299]	Speed: 3823.866895 samples/sec	accuracy=0.989167
# Epoch[231] Batch [349]	Speed: 3676.492947 samples/sec	accuracy=0.989397
# [Epoch 231] training: accuracy=0.989243
# [Epoch 231] time cost: 15.160674
# [Epoch 231] validation: accuracy=0.914764
# Epoch[232] Batch [49]	Speed: 2269.395578 samples/sec	accuracy=0.989688
# Epoch[232] Batch [99]	Speed: 3856.221804 samples/sec	accuracy=0.989688
# Epoch[232] Batch [149]	Speed: 3281.787580 samples/sec	accuracy=0.989531
# Epoch[232] Batch [199]	Speed: 3853.702899 samples/sec	accuracy=0.989414
# Epoch[232] Batch [249]	Speed: 2689.397180 samples/sec	accuracy=0.989375
# Epoch[232] Batch [299]	Speed: 3686.186262 samples/sec	accuracy=0.989010
# Epoch[232] Batch [349]	Speed: 3865.217008 samples/sec	accuracy=0.988929
# [Epoch 232] training: accuracy=0.988891
# [Epoch 232] time cost: 14.759057
# [Epoch 232] validation: accuracy=0.914755
# Epoch[233] Batch [49]	Speed: 2243.121371 samples/sec	accuracy=0.991406
# Epoch[233] Batch [99]	Speed: 3933.264310 samples/sec	accuracy=0.989844
# Epoch[233] Batch [149]	Speed: 2612.370686 samples/sec	accuracy=0.989323
# Epoch[233] Batch [199]	Speed: 3387.668396 samples/sec	accuracy=0.989492
# Epoch[233] Batch [249]	Speed: 3107.773107 samples/sec	accuracy=0.989500
# Epoch[233] Batch [299]	Speed: 3791.380917 samples/sec	accuracy=0.989427
# Epoch[233] Batch [349]	Speed: 3726.200111 samples/sec	accuracy=0.989464
# [Epoch 233] training: accuracy=0.989810
# [Epoch 233] time cost: 15.370283
# [Epoch 233] validation: accuracy=0.914764
# Epoch[234] Batch [49]	Speed: 3782.432555 samples/sec	accuracy=0.987812
# Epoch[234] Batch [99]	Speed: 3761.892133 samples/sec	accuracy=0.986641
# Epoch[234] Batch [149]	Speed: 3909.776150 samples/sec	accuracy=0.987344
# Epoch[234] Batch [199]	Speed: 3900.827668 samples/sec	accuracy=0.987695
# Epoch[234] Batch [249]	Speed: 3658.803767 samples/sec	accuracy=0.987938
# Epoch[234] Batch [299]	Speed: 3801.528851 samples/sec	accuracy=0.988464
# Epoch[234] Batch [349]	Speed: 3800.317916 samples/sec	accuracy=0.988460
# [Epoch 234] training: accuracy=0.988381
# [Epoch 234] time cost: 15.218546
# [Epoch 234] validation: accuracy=0.914563
# Epoch[235] Batch [49]	Speed: 3736.677747 samples/sec	accuracy=0.991563
# Epoch[235] Batch [99]	Speed: 3825.801595 samples/sec	accuracy=0.990859
# Epoch[235] Batch [149]	Speed: 3262.562134 samples/sec	accuracy=0.989583
# Epoch[235] Batch [199]	Speed: 3780.195406 samples/sec	accuracy=0.989453
# Epoch[235] Batch [249]	Speed: 2109.122920 samples/sec	accuracy=0.989688
# Epoch[235] Batch [299]	Speed: 3638.076249 samples/sec	accuracy=0.989375
# Epoch[235] Batch [349]	Speed: 3702.251621 samples/sec	accuracy=0.989621
# [Epoch 235] training: accuracy=0.989650
# [Epoch 235] time cost: 15.158588
# [Epoch 235] validation: accuracy=0.914263
# Epoch[236] Batch [49]	Speed: 3870.985947 samples/sec	accuracy=0.990625
# Epoch[236] Batch [99]	Speed: 3369.066864 samples/sec	accuracy=0.989922
# Epoch[236] Batch [149]	Speed: 2813.744606 samples/sec	accuracy=0.988802
# Epoch[236] Batch [199]	Speed: 3782.139444 samples/sec	accuracy=0.989492
# Epoch[236] Batch [249]	Speed: 3597.920559 samples/sec	accuracy=0.989812
# Epoch[236] Batch [299]	Speed: 2734.282560 samples/sec	accuracy=0.989870
# Epoch[236] Batch [349]	Speed: 3928.026749 samples/sec	accuracy=0.990022
# [Epoch 236] training: accuracy=0.989870
# [Epoch 236] time cost: 14.726980
# [Epoch 236] validation: accuracy=0.914864
# Epoch[237] Batch [49]	Speed: 3675.838471 samples/sec	accuracy=0.989531
# Epoch[237] Batch [99]	Speed: 3822.423957 samples/sec	accuracy=0.990547
# Epoch[237] Batch [149]	Speed: 3418.710715 samples/sec	accuracy=0.989635
# Epoch[237] Batch [199]	Speed: 3855.197237 samples/sec	accuracy=0.989648
# Epoch[237] Batch [249]	Speed: 3548.855843 samples/sec	accuracy=0.989375
# Epoch[237] Batch [299]	Speed: 2949.321614 samples/sec	accuracy=0.989323
# Epoch[237] Batch [349]	Speed: 3824.466170 samples/sec	accuracy=0.989241
# [Epoch 237] training: accuracy=0.989303
# [Epoch 237] time cost: 15.843949
# [Epoch 237] validation: accuracy=0.914964
# Epoch[238] Batch [49]	Speed: 3877.556133 samples/sec	accuracy=0.988906
# Epoch[238] Batch [99]	Speed: 2192.885142 samples/sec	accuracy=0.989688
# Epoch[238] Batch [149]	Speed: 3512.219917 samples/sec	accuracy=0.989948
# Epoch[238] Batch [199]	Speed: 3739.280325 samples/sec	accuracy=0.989609
# Epoch[238] Batch [249]	Speed: 3626.354550 samples/sec	accuracy=0.989688
# Epoch[238] Batch [299]	Speed: 3825.174647 samples/sec	accuracy=0.989401
# Epoch[238] Batch [349]	Speed: 3716.990189 samples/sec	accuracy=0.989688
# [Epoch 238] training: accuracy=0.989670
# [Epoch 238] time cost: 15.551488
# [Epoch 238] validation: accuracy=0.914764
# Epoch[239] Batch [49]	Speed: 3773.924222 samples/sec	accuracy=0.992188
# Epoch[239] Batch [99]	Speed: 3811.217128 samples/sec	accuracy=0.990000
# Epoch[239] Batch [149]	Speed: 2188.924364 samples/sec	accuracy=0.989375
# Epoch[239] Batch [199]	Speed: 2696.109598 samples/sec	accuracy=0.988633
# Epoch[239] Batch [249]	Speed: 2119.313730 samples/sec	accuracy=0.988437
# Epoch[239] Batch [299]	Speed: 3756.128173 samples/sec	accuracy=0.988281
# Epoch[239] Batch [349]	Speed: 3062.758355 samples/sec	accuracy=0.988549
# [Epoch 239] training: accuracy=0.988662
# [Epoch 239] time cost: 15.767437
# [Epoch 239] validation: accuracy=0.914764
# Epoch[240] Batch [49]	Speed: 2491.095380 samples/sec	accuracy=0.990313
# Epoch[240] Batch [99]	Speed: 2880.456005 samples/sec	accuracy=0.989766
# Epoch[240] Batch [149]	Speed: 3726.510481 samples/sec	accuracy=0.989844
# Epoch[240] Batch [199]	Speed: 3854.837383 samples/sec	accuracy=0.989961
# Epoch[240] Batch [249]	Speed: 2677.793965 samples/sec	accuracy=0.989812
# Epoch[240] Batch [299]	Speed: 2553.937730 samples/sec	accuracy=0.989740
# Epoch[240] Batch [349]	Speed: 2883.426313 samples/sec	accuracy=0.989821
# [Epoch 240] training: accuracy=0.989770
# [Epoch 240] time cost: 15.457757
# [Epoch 240] validation: accuracy=0.914854
# Epoch[241] Batch [49]	Speed: 2645.427100 samples/sec	accuracy=0.988437
# Epoch[241] Batch [99]	Speed: 3836.957369 samples/sec	accuracy=0.988672
# Epoch[241] Batch [149]	Speed: 3471.297763 samples/sec	accuracy=0.988281
# Epoch[241] Batch [199]	Speed: 2779.410396 samples/sec	accuracy=0.988437
# Epoch[241] Batch [249]	Speed: 2257.980165 samples/sec	accuracy=0.988437
# Epoch[241] Batch [299]	Speed: 3284.277022 samples/sec	accuracy=0.988724
# Epoch[241] Batch [349]	Speed: 2239.201335 samples/sec	accuracy=0.988906
# [Epoch 241] training: accuracy=0.989090
# [Epoch 241] time cost: 16.108474
# [Epoch 241] validation: accuracy=0.914263
# Epoch[242] Batch [49]	Speed: 2528.652766 samples/sec	accuracy=0.989844
# Epoch[242] Batch [99]	Speed: 3756.101894 samples/sec	accuracy=0.989688
# Epoch[242] Batch [149]	Speed: 3864.716174 samples/sec	accuracy=0.989531
# Epoch[242] Batch [199]	Speed: 3100.468428 samples/sec	accuracy=0.988750
# Epoch[242] Batch [249]	Speed: 1953.728487 samples/sec	accuracy=0.988844
# Epoch[242] Batch [299]	Speed: 3654.097126 samples/sec	accuracy=0.989010
# Epoch[242] Batch [349]	Speed: 3701.613464 samples/sec	accuracy=0.989219
# [Epoch 242] training: accuracy=0.989303
# [Epoch 242] time cost: 16.133862
# [Epoch 242] validation: accuracy=0.915765
# Epoch[243] Batch [49]	Speed: 3867.862453 samples/sec	accuracy=0.989844
# Epoch[243] Batch [99]	Speed: 3753.292170 samples/sec	accuracy=0.989219
# Epoch[243] Batch [149]	Speed: 3806.758174 samples/sec	accuracy=0.989271
# Epoch[243] Batch [199]	Speed: 3913.766444 samples/sec	accuracy=0.989102
# Epoch[243] Batch [249]	Speed: 3615.730607 samples/sec	accuracy=0.989219
# Epoch[243] Batch [299]	Speed: 3726.613949 samples/sec	accuracy=0.989271
# Epoch[243] Batch [349]	Speed: 3843.687620 samples/sec	accuracy=0.989554
# [Epoch 243] training: accuracy=0.989750
# [Epoch 243] time cost: 15.620821
# [Epoch 243] validation: accuracy=0.914363
# Epoch[244] Batch [49]	Speed: 3894.460934 samples/sec	accuracy=0.993125
# Epoch[244] Batch [99]	Speed: 3809.891864 samples/sec	accuracy=0.991563
# Epoch[244] Batch [149]	Speed: 3913.880572 samples/sec	accuracy=0.990781
# Epoch[244] Batch [199]	Speed: 3630.621628 samples/sec	accuracy=0.990977
# Epoch[244] Batch [249]	Speed: 2932.102566 samples/sec	accuracy=0.990906
# Epoch[244] Batch [299]	Speed: 3703.349764 samples/sec	accuracy=0.990781
# Epoch[244] Batch [349]	Speed: 2406.500063 samples/sec	accuracy=0.990826
# [Epoch 244] training: accuracy=0.990769
# [Epoch 244] time cost: 15.513408
# [Epoch 244] validation: accuracy=0.916066
# Epoch[245] Batch [49]	Speed: 3791.327368 samples/sec	accuracy=0.990156
# Epoch[245] Batch [99]	Speed: 3893.161848 samples/sec	accuracy=0.989141
# Epoch[245] Batch [149]	Speed: 3152.797162 samples/sec	accuracy=0.988385
# Epoch[245] Batch [199]	Speed: 3779.796194 samples/sec	accuracy=0.988477
# Epoch[245] Batch [249]	Speed: 3662.497865 samples/sec	accuracy=0.988688
# Epoch[245] Batch [299]	Speed: 2534.609812 samples/sec	accuracy=0.988776
# Epoch[245] Batch [349]	Speed: 2918.918881 samples/sec	accuracy=0.989263
# [Epoch 245] training: accuracy=0.989223
# [Epoch 245] time cost: 16.180924
# [Epoch 245] validation: accuracy=0.915665
# Epoch[246] Batch [49]	Speed: 3063.702162 samples/sec	accuracy=0.991875
# Epoch[246] Batch [99]	Speed: 2346.412500 samples/sec	accuracy=0.989922
# Epoch[246] Batch [149]	Speed: 3826.756041 samples/sec	accuracy=0.989844
# Epoch[246] Batch [199]	Speed: 2774.168257 samples/sec	accuracy=0.989453
# Epoch[246] Batch [249]	Speed: 2604.336326 samples/sec	accuracy=0.989344
# Epoch[246] Batch [299]	Speed: 2234.234505 samples/sec	accuracy=0.989323
# Epoch[246] Batch [349]	Speed: 3825.065633 samples/sec	accuracy=0.989442
# [Epoch 246] training: accuracy=0.989570
# [Epoch 246] time cost: 15.789343
# [Epoch 246] validation: accuracy=0.915565
# Epoch[247] Batch [49]	Speed: 3849.944510 samples/sec	accuracy=0.989844
# Epoch[247] Batch [99]	Speed: 3886.566851 samples/sec	accuracy=0.989453
# Epoch[247] Batch [149]	Speed: 3874.477953 samples/sec	accuracy=0.989062
# Epoch[247] Batch [199]	Speed: 2991.307588 samples/sec	accuracy=0.989414
# Epoch[247] Batch [249]	Speed: 3483.415165 samples/sec	accuracy=0.989500
# Epoch[247] Batch [299]	Speed: 2229.363719 samples/sec	accuracy=0.989583
# Epoch[247] Batch [349]	Speed: 2977.059001 samples/sec	accuracy=0.989777
# [Epoch 247] training: accuracy=0.989744
# [Epoch 247] time cost: 14.624324
# [Epoch 247] validation: accuracy=0.914663
# Epoch[248] Batch [49]	Speed: 3103.210381 samples/sec	accuracy=0.990625
# Epoch[248] Batch [99]	Speed: 2553.172554 samples/sec	accuracy=0.989844
# Epoch[248] Batch [149]	Speed: 2426.941057 samples/sec	accuracy=0.989583
# Epoch[248] Batch [199]	Speed: 2087.895121 samples/sec	accuracy=0.990000
# Epoch[248] Batch [249]	Speed: 3533.789120 samples/sec	accuracy=0.989688
# Epoch[248] Batch [299]	Speed: 3798.193917 samples/sec	accuracy=0.989948
# Epoch[248] Batch [349]	Speed: 2796.290051 samples/sec	accuracy=0.990067
# [Epoch 248] training: accuracy=0.990109
# [Epoch 248] time cost: 14.895168
# [Epoch 248] validation: accuracy=0.916337
# Epoch[249] Batch [49]	Speed: 3267.904216 samples/sec	accuracy=0.990625
# Epoch[249] Batch [99]	Speed: 3286.649517 samples/sec	accuracy=0.990313
# Epoch[249] Batch [149]	Speed: 3891.920055 samples/sec	accuracy=0.989635
# Epoch[249] Batch [199]	Speed: 2172.431855 samples/sec	accuracy=0.989688
# Epoch[249] Batch [249]	Speed: 3168.688615 samples/sec	accuracy=0.989781
# Epoch[249] Batch [299]	Speed: 2693.647644 samples/sec	accuracy=0.989844
# Epoch[249] Batch [349]	Speed: 3825.856122 samples/sec	accuracy=0.989821
# [Epoch 249] training: accuracy=0.989590
# [Epoch 249] time cost: 15.216167
# [Epoch 249] validation: accuracy=0.913862

# %% [markdown]
# The training should have led to a similar validation accuracy as reported in [3], Sec. 4.2. We next activate quantization for $W_B$, $W_C$ (by setting `sp_mode` to 2) and continue training for 40 epochs.

# %%
initialize_by_key(sp_resnet, 'sp_mode', mx.init.Constant(2), ctx, True)

epochs = 40
learning_rate = 0.01
scheduler = mx.lr_scheduler.MultiFactorScheduler([10*schedule_factor, 20*schedule_factor, 30*schedule_factor, 40*schedule_factor], factor=0.1)

train(sp_resnet, learning_rate, momentum, weight_decay, epochs, scheduler, ctx, train_data, val_data, log_interval)
# Out:
# Epoch[0] Batch [49]	Speed: 1069.645083 samples/sec	accuracy=0.729375
# Epoch[0] Batch [99]	Speed: 1072.894238 samples/sec	accuracy=0.781250
# Epoch[0] Batch [149]	Speed: 1066.555374 samples/sec	accuracy=0.808385
# Epoch[0] Batch [199]	Speed: 1063.055985 samples/sec	accuracy=0.824844
# Epoch[0] Batch [249]	Speed: 1017.921068 samples/sec	accuracy=0.834281
# Epoch[0] Batch [299]	Speed: 1146.652895 samples/sec	accuracy=0.842630
# Epoch[0] Batch [349]	Speed: 973.466941 samples/sec	accuracy=0.850022
# [Epoch 0] training: accuracy=0.854667
# [Epoch 0] time cost: 51.520275
# [Epoch 0] validation: accuracy=0.853165
# Epoch[1] Batch [49]	Speed: 782.601532 samples/sec	accuracy=0.905937
# Epoch[1] Batch [99]	Speed: 1060.586311 samples/sec	accuracy=0.903750
# Epoch[1] Batch [149]	Speed: 1118.213161 samples/sec	accuracy=0.901771
# Epoch[1] Batch [199]	Speed: 1114.038837 samples/sec	accuracy=0.899258
# Epoch[1] Batch [249]	Speed: 1104.597655 samples/sec	accuracy=0.900094
# Epoch[1] Batch [299]	Speed: 1102.599046 samples/sec	accuracy=0.900599
# Epoch[1] Batch [349]	Speed: 842.373762 samples/sec	accuracy=0.901339
# [Epoch 1] training: accuracy=0.901714
# [Epoch 1] time cost: 52.405267
# [Epoch 1] validation: accuracy=0.864784
# Epoch[2] Batch [49]	Speed: 883.893808 samples/sec	accuracy=0.903438
# Epoch[2] Batch [99]	Speed: 816.543642 samples/sec	accuracy=0.902500
# Epoch[2] Batch [149]	Speed: 1089.109154 samples/sec	accuracy=0.904219
# Epoch[2] Batch [199]	Speed: 813.790952 samples/sec	accuracy=0.905195
# Epoch[2] Batch [249]	Speed: 1002.006196 samples/sec	accuracy=0.905406
# Epoch[2] Batch [299]	Speed: 837.549512 samples/sec	accuracy=0.906354
# Epoch[2] Batch [349]	Speed: 941.502192 samples/sec	accuracy=0.907344
# [Epoch 2] training: accuracy=0.906929
# [Epoch 2] time cost: 52.426196
# [Epoch 2] validation: accuracy=0.852464
# Epoch[3] Batch [49]	Speed: 1045.757357 samples/sec	accuracy=0.913281
# Epoch[3] Batch [99]	Speed: 1077.299066 samples/sec	accuracy=0.908047
# Epoch[3] Batch [149]	Speed: 1039.693927 samples/sec	accuracy=0.905833
# Epoch[3] Batch [199]	Speed: 781.955230 samples/sec	accuracy=0.906133
# Epoch[3] Batch [249]	Speed: 1016.417888 samples/sec	accuracy=0.907281
# Epoch[3] Batch [299]	Speed: 1041.569816 samples/sec	accuracy=0.908021
# Epoch[3] Batch [349]	Speed: 1021.119454 samples/sec	accuracy=0.908170
# [Epoch 3] training: accuracy=0.908494
# [Epoch 3] time cost: 52.081697
# [Epoch 3] validation: accuracy=0.872596
# Epoch[4] Batch [49]	Speed: 1080.436207 samples/sec	accuracy=0.915781
# Epoch[4] Batch [99]	Speed: 1010.319997 samples/sec	accuracy=0.911172
# Epoch[4] Batch [149]	Speed: 1097.173052 samples/sec	accuracy=0.908333
# Epoch[4] Batch [199]	Speed: 806.541183 samples/sec	accuracy=0.908672
# Epoch[4] Batch [249]	Speed: 868.863751 samples/sec	accuracy=0.909188
# Epoch[4] Batch [299]	Speed: 840.389258 samples/sec	accuracy=0.908646
# Epoch[4] Batch [349]	Speed: 820.240069 samples/sec	accuracy=0.909554
# [Epoch 4] training: accuracy=0.910526
# [Epoch 4] time cost: 52.677725
# [Epoch 4] validation: accuracy=0.867788
# Epoch[5] Batch [49]	Speed: 1085.381455 samples/sec	accuracy=0.914844
# Epoch[5] Batch [99]	Speed: 831.852443 samples/sec	accuracy=0.910000
# Epoch[5] Batch [149]	Speed: 1042.437428 samples/sec	accuracy=0.912292
# Epoch[5] Batch [199]	Speed: 1056.474800 samples/sec	accuracy=0.911875
# Epoch[5] Batch [249]	Speed: 1087.463438 samples/sec	accuracy=0.911250
# Epoch[5] Batch [299]	Speed: 1036.024323 samples/sec	accuracy=0.910521
# Epoch[5] Batch [349]	Speed: 1003.697771 samples/sec	accuracy=0.910246
# [Epoch 5] training: accuracy=0.911098
# [Epoch 5] time cost: 52.919751
# [Epoch 5] validation: accuracy=0.854167
# Epoch[6] Batch [49]	Speed: 892.078881 samples/sec	accuracy=0.914062
# Epoch[6] Batch [99]	Speed: 1055.712368 samples/sec	accuracy=0.910391
# Epoch[6] Batch [149]	Speed: 1121.317064 samples/sec	accuracy=0.910781
# Epoch[6] Batch [199]	Speed: 895.711915 samples/sec	accuracy=0.910078
# Epoch[6] Batch [249]	Speed: 1077.446084 samples/sec	accuracy=0.910250
# Epoch[6] Batch [299]	Speed: 1169.561673 samples/sec	accuracy=0.910156
# Epoch[6] Batch [349]	Speed: 1009.389223 samples/sec	accuracy=0.910357
# [Epoch 6] training: accuracy=0.910666
# [Epoch 6] time cost: 52.715838
# [Epoch 6] validation: accuracy=0.865407
# Epoch[7] Batch [49]	Speed: 1118.739775 samples/sec	accuracy=0.911719
# Epoch[7] Batch [99]	Speed: 1068.168123 samples/sec	accuracy=0.912266
# Epoch[7] Batch [149]	Speed: 1166.611064 samples/sec	accuracy=0.911354
# Epoch[7] Batch [199]	Speed: 1050.529328 samples/sec	accuracy=0.911055
# Epoch[7] Batch [249]	Speed: 1042.882918 samples/sec	accuracy=0.910375
# Epoch[7] Batch [299]	Speed: 911.374915 samples/sec	accuracy=0.911276
# Epoch[7] Batch [349]	Speed: 1079.408720 samples/sec	accuracy=0.911920
# [Epoch 7] training: accuracy=0.911925
# [Epoch 7] time cost: 52.197213
# [Epoch 7] validation: accuracy=0.869892
# Epoch[8] Batch [49]	Speed: 1058.559957 samples/sec	accuracy=0.910937
# Epoch[8] Batch [99]	Speed: 748.219815 samples/sec	accuracy=0.910859
# Epoch[8] Batch [149]	Speed: 1072.204283 samples/sec	accuracy=0.911510
# Epoch[8] Batch [199]	Speed: 781.571602 samples/sec	accuracy=0.910000
# Epoch[8] Batch [249]	Speed: 992.729168 samples/sec	accuracy=0.910656
# Epoch[8] Batch [299]	Speed: 806.549664 samples/sec	accuracy=0.910651
# Epoch[8] Batch [349]	Speed: 1073.741824 samples/sec	accuracy=0.911763
# [Epoch 8] training: accuracy=0.912540
# [Epoch 8] time cost: 52.171016
# [Epoch 8] validation: accuracy=0.848357
# Epoch[9] Batch [49]	Speed: 1154.417109 samples/sec	accuracy=0.911563
# Epoch[9] Batch [99]	Speed: 1112.296236 samples/sec	accuracy=0.908281
# Epoch[9] Batch [149]	Speed: 1119.859894 samples/sec	accuracy=0.907760
# Epoch[9] Batch [199]	Speed: 850.693414 samples/sec	accuracy=0.908516
# Epoch[9] Batch [249]	Speed: 1070.485407 samples/sec	accuracy=0.908094
# Epoch[9] Batch [299]	Speed: 883.139191 samples/sec	accuracy=0.907578
# Epoch[9] Batch [349]	Speed: 1059.566938 samples/sec	accuracy=0.908393
# [Epoch 9] training: accuracy=0.908248
# [Epoch 9] time cost: 52.533242
# [Epoch 9] validation: accuracy=0.861478
# Epoch[10] Batch [49]	Speed: 1023.613427 samples/sec	accuracy=0.906719
# Epoch[10] Batch [99]	Speed: 983.065801 samples/sec	accuracy=0.909766
# Epoch[10] Batch [149]	Speed: 742.676120 samples/sec	accuracy=0.914531
# Epoch[10] Batch [199]	Speed: 1105.990289 samples/sec	accuracy=0.918672
# Epoch[10] Batch [249]	Speed: 1084.296365 samples/sec	accuracy=0.921719
# Epoch[10] Batch [299]	Speed: 1091.935656 samples/sec	accuracy=0.924323
# Epoch[10] Batch [349]	Speed: 1021.768545 samples/sec	accuracy=0.927612
# [Epoch 10] training: accuracy=0.929588
# [Epoch 10] time cost: 52.545611
# [Epoch 10] validation: accuracy=0.897837
# Epoch[11] Batch [49]	Speed: 1060.906971 samples/sec	accuracy=0.938906
# Epoch[11] Batch [99]	Speed: 1031.604891 samples/sec	accuracy=0.937266
# Epoch[11] Batch [149]	Speed: 1032.885024 samples/sec	accuracy=0.938698
# Epoch[11] Batch [199]	Speed: 848.976890 samples/sec	accuracy=0.939883
# Epoch[11] Batch [249]	Speed: 974.985539 samples/sec	accuracy=0.940406
# Epoch[11] Batch [299]	Speed: 1045.012345 samples/sec	accuracy=0.940000
# Epoch[11] Batch [349]	Speed: 870.712554 samples/sec	accuracy=0.941652
# [Epoch 11] training: accuracy=0.942288
# [Epoch 11] time cost: 52.506495
# [Epoch 11] validation: accuracy=0.897937
# Epoch[12] Batch [49]	Speed: 1019.862489 samples/sec	accuracy=0.945469
# Epoch[12] Batch [99]	Speed: 1036.832655 samples/sec	accuracy=0.943047
# Epoch[12] Batch [149]	Speed: 1025.649136 samples/sec	accuracy=0.943542
# Epoch[12] Batch [199]	Speed: 1059.774003 samples/sec	accuracy=0.944102
# Epoch[12] Batch [249]	Speed: 1039.871141 samples/sec	accuracy=0.943875
# Epoch[12] Batch [299]	Speed: 1067.409948 samples/sec	accuracy=0.944661
# Epoch[12] Batch [349]	Speed: 854.094374 samples/sec	accuracy=0.945937
# [Epoch 12] training: accuracy=0.946371
# [Epoch 12] time cost: 52.382597
# [Epoch 12] validation: accuracy=0.900841
# Epoch[13] Batch [49]	Speed: 1016.970465 samples/sec	accuracy=0.947344
# Epoch[13] Batch [99]	Speed: 1148.578612 samples/sec	accuracy=0.943906
# Epoch[13] Batch [149]	Speed: 825.382561 samples/sec	accuracy=0.943177
# Epoch[13] Batch [199]	Speed: 1066.133893 samples/sec	accuracy=0.944609
# Epoch[13] Batch [249]	Speed: 1058.967115 samples/sec	accuracy=0.945344
# Epoch[13] Batch [299]	Speed: 1081.971298 samples/sec	accuracy=0.945599
# Epoch[13] Batch [349]	Speed: 891.404943 samples/sec	accuracy=0.946607
# [Epoch 13] training: accuracy=0.946575
# [Epoch 13] time cost: 51.943875
# [Epoch 13] validation: accuracy=0.899239
# Epoch[14] Batch [49]	Speed: 816.667851 samples/sec	accuracy=0.944688
# Epoch[14] Batch [99]	Speed: 1097.206686 samples/sec	accuracy=0.943047
# Epoch[14] Batch [149]	Speed: 879.774435 samples/sec	accuracy=0.942708
# Epoch[14] Batch [199]	Speed: 1111.959885 samples/sec	accuracy=0.944063
# Epoch[14] Batch [249]	Speed: 1034.172323 samples/sec	accuracy=0.944344
# Epoch[14] Batch [299]	Speed: 981.496826 samples/sec	accuracy=0.945182
# Epoch[14] Batch [349]	Speed: 1094.549204 samples/sec	accuracy=0.946362
# [Epoch 14] training: accuracy=0.946851
# [Epoch 14] time cost: 51.659012
# [Epoch 14] validation: accuracy=0.897350
# Epoch[15] Batch [49]	Speed: 1064.305690 samples/sec	accuracy=0.943594
# Epoch[15] Batch [99]	Speed: 1068.187250 samples/sec	accuracy=0.944688
# Epoch[15] Batch [149]	Speed: 1025.028375 samples/sec	accuracy=0.944219
# Epoch[15] Batch [199]	Speed: 933.677176 samples/sec	accuracy=0.944492
# Epoch[15] Batch [249]	Speed: 1010.708008 samples/sec	accuracy=0.945344
# Epoch[15] Batch [299]	Speed: 1071.833960 samples/sec	accuracy=0.945964
# Epoch[15] Batch [349]	Speed: 1112.542869 samples/sec	accuracy=0.946228
# [Epoch 15] training: accuracy=0.946591
# [Epoch 15] time cost: 51.975877
# [Epoch 15] validation: accuracy=0.896134
# Epoch[16] Batch [49]	Speed: 984.896299 samples/sec	accuracy=0.943750
# Epoch[16] Batch [99]	Speed: 1121.157831 samples/sec	accuracy=0.942578
# Epoch[16] Batch [149]	Speed: 849.193092 samples/sec	accuracy=0.942917
# Epoch[16] Batch [199]	Speed: 1052.805729 samples/sec	accuracy=0.943672
# Epoch[16] Batch [249]	Speed: 1050.922101 samples/sec	accuracy=0.944187
# Epoch[16] Batch [299]	Speed: 964.764011 samples/sec	accuracy=0.944922
# Epoch[16] Batch [349]	Speed: 1065.025654 samples/sec	accuracy=0.945915
# [Epoch 16] training: accuracy=0.946094
# [Epoch 16] time cost: 52.907636
# [Epoch 16] validation: accuracy=0.897236
# Epoch[17] Batch [49]	Speed: 995.180301 samples/sec	accuracy=0.946406
# Epoch[17] Batch [99]	Speed: 1104.686297 samples/sec	accuracy=0.944766
# Epoch[17] Batch [149]	Speed: 841.274205 samples/sec	accuracy=0.945833
# Epoch[17] Batch [199]	Speed: 845.981586 samples/sec	accuracy=0.946758
# Epoch[17] Batch [249]	Speed: 783.362047 samples/sec	accuracy=0.947219
# Epoch[17] Batch [299]	Speed: 1042.816071 samples/sec	accuracy=0.946094
# Epoch[17] Batch [349]	Speed: 797.345274 samples/sec	accuracy=0.946473
# [Epoch 17] training: accuracy=0.946411
# [Epoch 17] time cost: 53.519266
# [Epoch 17] validation: accuracy=0.898538
# Epoch[18] Batch [49]	Speed: 881.222834 samples/sec	accuracy=0.944844
# Epoch[18] Batch [99]	Speed: 770.512711 samples/sec	accuracy=0.944844
# Epoch[18] Batch [149]	Speed: 929.411633 samples/sec	accuracy=0.943906
# Epoch[18] Batch [199]	Speed: 789.737870 samples/sec	accuracy=0.944766
# Epoch[18] Batch [249]	Speed: 1002.327961 samples/sec	accuracy=0.944438
# Epoch[18] Batch [299]	Speed: 811.360742 samples/sec	accuracy=0.945495
# Epoch[18] Batch [349]	Speed: 832.447056 samples/sec	accuracy=0.946205
# [Epoch 18] training: accuracy=0.946551
# [Epoch 18] time cost: 53.221958
# [Epoch 18] validation: accuracy=0.900040
# Epoch[19] Batch [49]	Speed: 1080.234031 samples/sec	accuracy=0.945937
# Epoch[19] Batch [99]	Speed: 949.227815 samples/sec	accuracy=0.945469
# Epoch[19] Batch [149]	Speed: 1084.285415 samples/sec	accuracy=0.944740
# Epoch[19] Batch [199]	Speed: 827.088997 samples/sec	accuracy=0.945156
# Epoch[19] Batch [249]	Speed: 727.199341 samples/sec	accuracy=0.946406
# Epoch[19] Batch [299]	Speed: 1146.743516 samples/sec	accuracy=0.947370
# Epoch[19] Batch [349]	Speed: 1108.951019 samples/sec	accuracy=0.947321
# [Epoch 19] training: accuracy=0.947596
# [Epoch 19] time cost: 53.275615
# [Epoch 19] validation: accuracy=0.896034
# Epoch[20] Batch [49]	Speed: 713.053629 samples/sec	accuracy=0.946875
# Epoch[20] Batch [99]	Speed: 855.363979 samples/sec	accuracy=0.944922
# Epoch[20] Batch [149]	Speed: 1072.489157 samples/sec	accuracy=0.945937
# Epoch[20] Batch [199]	Speed: 1114.883246 samples/sec	accuracy=0.948477
# Epoch[20] Batch [249]	Speed: 685.531941 samples/sec	accuracy=0.949906
# Epoch[20] Batch [299]	Speed: 1077.355274 samples/sec	accuracy=0.950026
# Epoch[20] Batch [349]	Speed: 1052.005291 samples/sec	accuracy=0.951496
# [Epoch 20] training: accuracy=0.952625
# [Epoch 20] time cost: 53.601881
# [Epoch 20] validation: accuracy=0.908153
# Epoch[21] Batch [49]	Speed: 850.578853 samples/sec	accuracy=0.957187
# Epoch[21] Batch [99]	Speed: 1063.428693 samples/sec	accuracy=0.956094
# Epoch[21] Batch [149]	Speed: 833.605180 samples/sec	accuracy=0.955469
# Epoch[21] Batch [199]	Speed: 1063.249676 samples/sec	accuracy=0.955937
# Epoch[21] Batch [249]	Speed: 1052.314594 samples/sec	accuracy=0.956719
# Epoch[21] Batch [299]	Speed: 995.974169 samples/sec	accuracy=0.957135
# Epoch[21] Batch [349]	Speed: 804.638518 samples/sec	accuracy=0.957879
# [Epoch 21] training: accuracy=0.958353
# [Epoch 21] time cost: 51.892442
# [Epoch 21] validation: accuracy=0.906250
# Epoch[22] Batch [49]	Speed: 865.396005 samples/sec	accuracy=0.956250
# Epoch[22] Batch [99]	Speed: 1091.411781 samples/sec	accuracy=0.953906
# Epoch[22] Batch [149]	Speed: 778.616560 samples/sec	accuracy=0.954688
# Epoch[22] Batch [199]	Speed: 809.091297 samples/sec	accuracy=0.954375
# Epoch[22] Batch [249]	Speed: 1036.678494 samples/sec	accuracy=0.955688
# Epoch[22] Batch [299]	Speed: 1067.507580 samples/sec	accuracy=0.955234
# Epoch[22] Batch [349]	Speed: 1098.019025 samples/sec	accuracy=0.956317
# [Epoch 22] training: accuracy=0.956821
# [Epoch 22] time cost: 53.251355
# [Epoch 22] validation: accuracy=0.909019
# Epoch[23] Batch [49]	Speed: 1108.415270 samples/sec	accuracy=0.959531
# Epoch[23] Batch [99]	Speed: 936.486602 samples/sec	accuracy=0.958594
# Epoch[23] Batch [149]	Speed: 775.766723 samples/sec	accuracy=0.957604
# Epoch[23] Batch [199]	Speed: 1060.743473 samples/sec	accuracy=0.957187
# Epoch[23] Batch [249]	Speed: 780.508066 samples/sec	accuracy=0.957125
# Epoch[23] Batch [299]	Speed: 800.856409 samples/sec	accuracy=0.956979
# Epoch[23] Batch [349]	Speed: 1089.310246 samples/sec	accuracy=0.956853
# [Epoch 23] training: accuracy=0.957341
# [Epoch 23] time cost: 53.705992
# [Epoch 23] validation: accuracy=0.903946
# Epoch[24] Batch [49]	Speed: 847.347515 samples/sec	accuracy=0.950781
# Epoch[24] Batch [99]	Speed: 991.940462 samples/sec	accuracy=0.953281
# Epoch[24] Batch [149]	Speed: 802.892472 samples/sec	accuracy=0.952760
# Epoch[24] Batch [199]	Speed: 810.984476 samples/sec	accuracy=0.953711
# Epoch[24] Batch [249]	Speed: 1033.093719 samples/sec	accuracy=0.953625
# Epoch[24] Batch [299]	Speed: 1061.998247 samples/sec	accuracy=0.954010
# Epoch[24] Batch [349]	Speed: 1071.617877 samples/sec	accuracy=0.954866
# [Epoch 24] training: accuracy=0.955589
# [Epoch 24] time cost: 52.396592
# [Epoch 24] validation: accuracy=0.909155
# Epoch[25] Batch [49]	Speed: 1056.277335 samples/sec	accuracy=0.955156
# Epoch[25] Batch [99]	Speed: 1099.318570 samples/sec	accuracy=0.953750
# Epoch[25] Batch [149]	Speed: 1052.896578 samples/sec	accuracy=0.953906
# Epoch[25] Batch [199]	Speed: 872.827425 samples/sec	accuracy=0.954102
# Epoch[25] Batch [249]	Speed: 1060.665934 samples/sec	accuracy=0.954812
# Epoch[25] Batch [299]	Speed: 1111.598420 samples/sec	accuracy=0.955286
# Epoch[25] Batch [349]	Speed: 1012.499763 samples/sec	accuracy=0.956183
# [Epoch 25] training: accuracy=0.956582
# [Epoch 25] time cost: 50.996152
# [Epoch 25] validation: accuracy=0.906350
# Epoch[26] Batch [49]	Speed: 906.421799 samples/sec	accuracy=0.955625
# Epoch[26] Batch [99]	Speed: 1034.054801 samples/sec	accuracy=0.954219
# Epoch[26] Batch [149]	Speed: 766.554362 samples/sec	accuracy=0.953854
# Epoch[26] Batch [199]	Speed: 838.649827 samples/sec	accuracy=0.953906
# Epoch[26] Batch [249]	Speed: 869.601203 samples/sec	accuracy=0.954719
# Epoch[26] Batch [299]	Speed: 786.596386 samples/sec	accuracy=0.954661
# Epoch[26] Batch [349]	Speed: 1075.458255 samples/sec	accuracy=0.955580
# [Epoch 26] training: accuracy=0.955463
# [Epoch 26] time cost: 52.011467
# [Epoch 26] validation: accuracy=0.905349
# Epoch[27] Batch [49]	Speed: 783.885902 samples/sec	accuracy=0.953125
# Epoch[27] Batch [99]	Speed: 1050.586889 samples/sec	accuracy=0.952500
# Epoch[27] Batch [149]	Speed: 1102.331904 samples/sec	accuracy=0.953542
# Epoch[27] Batch [199]	Speed: 981.304868 samples/sec	accuracy=0.953164
# Epoch[27] Batch [249]	Speed: 1014.545144 samples/sec	accuracy=0.954281
# Epoch[27] Batch [299]	Speed: 1076.551624 samples/sec	accuracy=0.953958
# Epoch[27] Batch [349]	Speed: 1075.917329 samples/sec	accuracy=0.954643
# [Epoch 27] training: accuracy=0.955268
# [Epoch 27] time cost: 52.128010
# [Epoch 27] validation: accuracy=0.904147
# Epoch[28] Batch [49]	Speed: 827.281445 samples/sec	accuracy=0.952656
# Epoch[28] Batch [99]	Speed: 1053.621861 samples/sec	accuracy=0.953750
# Epoch[28] Batch [149]	Speed: 1127.932199 samples/sec	accuracy=0.953281
# Epoch[28] Batch [199]	Speed: 730.279630 samples/sec	accuracy=0.954023
# Epoch[28] Batch [249]	Speed: 1032.918807 samples/sec	accuracy=0.954750
# Epoch[28] Batch [299]	Speed: 800.811015 samples/sec	accuracy=0.955052
# Epoch[28] Batch [349]	Speed: 1056.869952 samples/sec	accuracy=0.955647
# [Epoch 28] training: accuracy=0.956082
# [Epoch 28] time cost: 52.903626
# [Epoch 28] validation: accuracy=0.903546
# Epoch[29] Batch [49]	Speed: 701.449111 samples/sec	accuracy=0.958438
# Epoch[29] Batch [99]	Speed: 1029.561290 samples/sec	accuracy=0.956016
# Epoch[29] Batch [149]	Speed: 829.116095 samples/sec	accuracy=0.955260
# Epoch[29] Batch [199]	Speed: 1014.387956 samples/sec	accuracy=0.954844
# Epoch[29] Batch [249]	Speed: 1032.696278 samples/sec	accuracy=0.955125
# Epoch[29] Batch [299]	Speed: 993.204831 samples/sec	accuracy=0.954505
# Epoch[29] Batch [349]	Speed: 1010.413168 samples/sec	accuracy=0.954978
# [Epoch 29] training: accuracy=0.955709
# [Epoch 29] time cost: 52.739029
# [Epoch 29] validation: accuracy=0.904748
# Epoch[30] Batch [49]	Speed: 926.433361 samples/sec	accuracy=0.957500
# Epoch[30] Batch [99]	Speed: 1080.699367 samples/sec	accuracy=0.954219
# Epoch[30] Batch [149]	Speed: 1060.156973 samples/sec	accuracy=0.955729
# Epoch[30] Batch [199]	Speed: 823.138848 samples/sec	accuracy=0.955859
# Epoch[30] Batch [249]	Speed: 1045.297197 samples/sec	accuracy=0.956812
# Epoch[30] Batch [299]	Speed: 1059.968592 samples/sec	accuracy=0.956953
# Epoch[30] Batch [349]	Speed: 1096.978012 samples/sec	accuracy=0.957768
# [Epoch 30] training: accuracy=0.958660
# [Epoch 30] time cost: 50.813494
# [Epoch 30] validation: accuracy=0.909118
# Epoch[31] Batch [49]	Speed: 851.230239 samples/sec	accuracy=0.956406
# Epoch[31] Batch [99]	Speed: 1105.389114 samples/sec	accuracy=0.957109
# Epoch[31] Batch [149]	Speed: 861.943374 samples/sec	accuracy=0.956719
# Epoch[31] Batch [199]	Speed: 1101.382109 samples/sec	accuracy=0.957773
# Epoch[31] Batch [249]	Speed: 818.338407 samples/sec	accuracy=0.958656
# Epoch[31] Batch [299]	Speed: 1067.286873 samples/sec	accuracy=0.958958
# Epoch[31] Batch [349]	Speed: 1064.406975 samples/sec	accuracy=0.959821
# [Epoch 31] training: accuracy=0.960418
# [Epoch 31] time cost: 51.894296
# [Epoch 31] validation: accuracy=0.904347
# Epoch[32] Batch [49]	Speed: 1021.640216 samples/sec	accuracy=0.956250
# Epoch[32] Batch [99]	Speed: 1005.391302 samples/sec	accuracy=0.955391
# Epoch[32] Batch [149]	Speed: 831.956858 samples/sec	accuracy=0.955937
# Epoch[32] Batch [199]	Speed: 1048.260703 samples/sec	accuracy=0.957109
# Epoch[32] Batch [249]	Speed: 922.855027 samples/sec	accuracy=0.957688
# Epoch[32] Batch [299]	Speed: 1056.221226 samples/sec	accuracy=0.958333
# Epoch[32] Batch [349]	Speed: 1064.856660 samples/sec	accuracy=0.958996
# [Epoch 32] training: accuracy=0.959475
# [Epoch 32] time cost: 52.683358
# [Epoch 32] validation: accuracy=0.908454
# Epoch[33] Batch [49]	Speed: 665.987178 samples/sec	accuracy=0.959844
# Epoch[33] Batch [99]	Speed: 1072.414175 samples/sec	accuracy=0.958516
# Epoch[33] Batch [149]	Speed: 808.680588 samples/sec	accuracy=0.957656
# Epoch[33] Batch [199]	Speed: 1089.838742 samples/sec	accuracy=0.957109
# Epoch[33] Batch [249]	Speed: 915.210834 samples/sec	accuracy=0.957375
# Epoch[33] Batch [299]	Speed: 777.090597 samples/sec	accuracy=0.957344
# Epoch[33] Batch [349]	Speed: 1100.305397 samples/sec	accuracy=0.957835
# [Epoch 33] training: accuracy=0.958240
# [Epoch 33] time cost: 52.498890
# [Epoch 33] validation: accuracy=0.908954
# Epoch[34] Batch [49]	Speed: 1087.452424 samples/sec	accuracy=0.957344
# Epoch[34] Batch [99]	Speed: 1009.267780 samples/sec	accuracy=0.958984
# Epoch[34] Batch [149]	Speed: 1024.791627 samples/sec	accuracy=0.957240
# Epoch[34] Batch [199]	Speed: 1052.205286 samples/sec	accuracy=0.957266
# Epoch[34] Batch [249]	Speed: 996.723041 samples/sec	accuracy=0.958187
# Epoch[34] Batch [299]	Speed: 1052.549787 samples/sec	accuracy=0.958646
# Epoch[34] Batch [349]	Speed: 872.032083 samples/sec	accuracy=0.958951
# [Epoch 34] training: accuracy=0.959319
# [Epoch 34] time cost: 51.126787
# [Epoch 34] validation: accuracy=0.910056
# Epoch[35] Batch [49]	Speed: 1064.571604 samples/sec	accuracy=0.958438
# Epoch[35] Batch [99]	Speed: 1059.794923 samples/sec	accuracy=0.957031
# Epoch[35] Batch [149]	Speed: 992.400694 samples/sec	accuracy=0.958542
# Epoch[35] Batch [199]	Speed: 870.702669 samples/sec	accuracy=0.958789
# Epoch[35] Batch [249]	Speed: 1093.334376 samples/sec	accuracy=0.958625
# Epoch[35] Batch [299]	Speed: 1079.812530 samples/sec	accuracy=0.958906
# Epoch[35] Batch [349]	Speed: 1084.574555 samples/sec	accuracy=0.959487
# [Epoch 35] training: accuracy=0.959776
# [Epoch 35] time cost: 52.494096
# [Epoch 35] validation: accuracy=0.907953
# Epoch[36] Batch [49]	Speed: 839.018116 samples/sec	accuracy=0.963281
# Epoch[36] Batch [99]	Speed: 993.219530 samples/sec	accuracy=0.959766
# Epoch[36] Batch [149]	Speed: 1081.459116 samples/sec	accuracy=0.959531
# Epoch[36] Batch [199]	Speed: 1075.066306 samples/sec	accuracy=0.959688
# Epoch[36] Batch [249]	Speed: 876.754399 samples/sec	accuracy=0.959750
# Epoch[36] Batch [299]	Speed: 1046.244428 samples/sec	accuracy=0.958880
# Epoch[36] Batch [349]	Speed: 912.758591 samples/sec	accuracy=0.959643
# [Epoch 36] training: accuracy=0.959779
# [Epoch 36] time cost: 51.828677
# [Epoch 36] validation: accuracy=0.904948
# Epoch[37] Batch [49]	Speed: 1000.516055 samples/sec	accuracy=0.959219
# Epoch[37] Batch [99]	Speed: 794.756767 samples/sec	accuracy=0.957031
# Epoch[37] Batch [149]	Speed: 826.198024 samples/sec	accuracy=0.957292
# Epoch[37] Batch [199]	Speed: 764.464109 samples/sec	accuracy=0.957695
# Epoch[37] Batch [249]	Speed: 1131.288192 samples/sec	accuracy=0.958438
# Epoch[37] Batch [299]	Speed: 1007.634927 samples/sec	accuracy=0.958281
# Epoch[37] Batch [349]	Speed: 1017.338541 samples/sec	accuracy=0.959196
# [Epoch 37] training: accuracy=0.959595
# [Epoch 37] time cost: 51.942686
# [Epoch 37] validation: accuracy=0.908053
# Epoch[38] Batch [49]	Speed: 1095.641506 samples/sec	accuracy=0.958594
# Epoch[38] Batch [99]	Speed: 773.351856 samples/sec	accuracy=0.957344
# Epoch[38] Batch [149]	Speed: 849.582800 samples/sec	accuracy=0.957344
# Epoch[38] Batch [199]	Speed: 1049.311748 samples/sec	accuracy=0.957734
# Epoch[38] Batch [249]	Speed: 1019.757881 samples/sec	accuracy=0.958250
# Epoch[38] Batch [299]	Speed: 1068.138370 samples/sec	accuracy=0.957630
# Epoch[38] Batch [349]	Speed: 1098.010042 samples/sec	accuracy=0.958415
# [Epoch 38] training: accuracy=0.958780
# [Epoch 38] time cost: 52.210346
# [Epoch 38] validation: accuracy=0.906250
# Epoch[39] Batch [49]	Speed: 1050.377233 samples/sec	accuracy=0.957344
# Epoch[39] Batch [99]	Speed: 1038.426999 samples/sec	accuracy=0.956562
# Epoch[39] Batch [149]	Speed: 865.580178 samples/sec	accuracy=0.956406
# Epoch[39] Batch [199]	Speed: 1112.512899 samples/sec	accuracy=0.956602
# Epoch[39] Batch [249]	Speed: 812.070100 samples/sec	accuracy=0.956937
# Epoch[39] Batch [299]	Speed: 993.261794 samples/sec	accuracy=0.957656
# Epoch[39] Batch [349]	Speed: 1062.670918 samples/sec	accuracy=0.957835
# [Epoch 39] training: accuracy=0.958160
# [Epoch 39] time cost: 52.423156
# [Epoch 39] validation: accuracy=0.905048

# %% [markdown]
# Finally, we fix $W_B$, $W_C$ and only train $\tilde a$ for another 10 epochs.

# %%
for k, p in sp_resnet.collect_params().items():
    if 'sp_data_weights' in k or 'sp_out_weights' in k:
        p.grad_req = 'null'

epochs = 10
learning_rate = 0.001
scheduler = None

train(sp_resnet, learning_rate, momentum, weight_decay, epochs, scheduler, ctx, train_data, val_data, log_interval)
# Out:
# Epoch[0] Batch [49]	Speed: 803.767555 samples/sec	accuracy=0.960000
# Epoch[0] Batch [99]	Speed: 1187.712323 samples/sec	accuracy=0.957031
# Epoch[0] Batch [149]	Speed: 999.350195 samples/sec	accuracy=0.957187
# Epoch[0] Batch [199]	Speed: 1145.439462 samples/sec	accuracy=0.957500
# Epoch[0] Batch [249]	Speed: 1179.003233 samples/sec	accuracy=0.958031
# Epoch[0] Batch [299]	Speed: 1135.910189 samples/sec	accuracy=0.959167
# Epoch[0] Batch [349]	Speed: 1168.841071 samples/sec	accuracy=0.959888
# [Epoch 0] training: accuracy=0.960377
# [Epoch 0] time cost: 47.362762
# [Epoch 0] validation: accuracy=0.909255
# Epoch[1] Batch [49]	Speed: 1119.558642 samples/sec	accuracy=0.960938
# Epoch[1] Batch [99]	Speed: 1220.438536 samples/sec	accuracy=0.959375
# Epoch[1] Batch [149]	Speed: 1152.179929 samples/sec	accuracy=0.958542
# Epoch[1] Batch [199]	Speed: 1152.669731 samples/sec	accuracy=0.958477
# Epoch[1] Batch [249]	Speed: 892.311663 samples/sec	accuracy=0.958812
# Epoch[1] Batch [299]	Speed: 925.125899 samples/sec	accuracy=0.958776
# Epoch[1] Batch [349]	Speed: 801.498449 samples/sec	accuracy=0.960089
# [Epoch 1] training: accuracy=0.960638
# [Epoch 1] time cost: 47.438348
# [Epoch 1] validation: accuracy=0.910156
# Epoch[2] Batch [49]	Speed: 1101.662355 samples/sec	accuracy=0.964844
# Epoch[2] Batch [99]	Speed: 817.136461 samples/sec	accuracy=0.961953
# Epoch[2] Batch [149]	Speed: 806.232326 samples/sec	accuracy=0.961719
# Epoch[2] Batch [199]	Speed: 886.556135 samples/sec	accuracy=0.961211
# Epoch[2] Batch [249]	Speed: 931.857241 samples/sec	accuracy=0.961688
# Epoch[2] Batch [299]	Speed: 946.138074 samples/sec	accuracy=0.961068
# Epoch[2] Batch [349]	Speed: 1127.314042 samples/sec	accuracy=0.961763
# [Epoch 2] training: accuracy=0.961817
# [Epoch 2] time cost: 48.742265
# [Epoch 2] validation: accuracy=0.910757
# Epoch[3] Batch [49]	Speed: 1150.254449 samples/sec	accuracy=0.960156
# Epoch[3] Batch [99]	Speed: 1173.803912 samples/sec	accuracy=0.959219
# Epoch[3] Batch [149]	Speed: 1157.530852 samples/sec	accuracy=0.959688
# Epoch[3] Batch [199]	Speed: 1111.405121 samples/sec	accuracy=0.960156
# Epoch[3] Batch [249]	Speed: 1105.803490 samples/sec	accuracy=0.960594
# Epoch[3] Batch [299]	Speed: 855.249519 samples/sec	accuracy=0.960703
# Epoch[3] Batch [349]	Speed: 1163.899833 samples/sec	accuracy=0.961496
# [Epoch 3] training: accuracy=0.961819
# [Epoch 3] time cost: 47.788285
# [Epoch 3] validation: accuracy=0.911558
# Epoch[4] Batch [49]	Speed: 946.815522 samples/sec	accuracy=0.960156
# Epoch[4] Batch [99]	Speed: 1155.704379 samples/sec	accuracy=0.959922
# Epoch[4] Batch [149]	Speed: 1158.900123 samples/sec	accuracy=0.960781
# Epoch[4] Batch [199]	Speed: 1090.626910 samples/sec	accuracy=0.959961
# Epoch[4] Batch [249]	Speed: 1117.247439 samples/sec	accuracy=0.960094
# Epoch[4] Batch [299]	Speed: 1202.700144 samples/sec	accuracy=0.960104
# Epoch[4] Batch [349]	Speed: 1091.400687 samples/sec	accuracy=0.960246
# [Epoch 4] training: accuracy=0.960878
# [Epoch 4] time cost: 47.562734
# [Epoch 4] validation: accuracy=0.911659
# Epoch[5] Batch [49]	Speed: 1064.867221 samples/sec	accuracy=0.959688
# Epoch[5] Batch [99]	Speed: 1114.165995 samples/sec	accuracy=0.959219
# Epoch[5] Batch [149]	Speed: 1167.704685 samples/sec	accuracy=0.959635
# Epoch[5] Batch [199]	Speed: 955.769307 samples/sec	accuracy=0.960039
# Epoch[5] Batch [249]	Speed: 883.841423 samples/sec	accuracy=0.961063
# Epoch[5] Batch [299]	Speed: 1131.862988 samples/sec	accuracy=0.960990
# Epoch[5] Batch [349]	Speed: 1160.990241 samples/sec	accuracy=0.961607
# [Epoch 5] training: accuracy=0.961899
# [Epoch 5] time cost: 46.824092
# [Epoch 5] validation: accuracy=0.911058
# Epoch[6] Batch [49]	Speed: 1277.190628 samples/sec	accuracy=0.965938
# Epoch[6] Batch [99]	Speed: 1200.070886 samples/sec	accuracy=0.961719
# Epoch[6] Batch [149]	Speed: 859.249172 samples/sec	accuracy=0.961250
# Epoch[6] Batch [199]	Speed: 1051.313110 samples/sec	accuracy=0.961562
# Epoch[6] Batch [249]	Speed: 915.574498 samples/sec	accuracy=0.961375
# Epoch[6] Batch [299]	Speed: 1159.773848 samples/sec	accuracy=0.961120
# Epoch[6] Batch [349]	Speed: 1163.274402 samples/sec	accuracy=0.961875
# [Epoch 6] training: accuracy=0.962336
# [Epoch 6] time cost: 47.920609
# [Epoch 6] validation: accuracy=0.911392
# Epoch[7] Batch [49]	Speed: 1149.815947 samples/sec	accuracy=0.961406
# Epoch[7] Batch [99]	Speed: 1143.270993 samples/sec	accuracy=0.960000
# Epoch[7] Batch [149]	Speed: 1289.810955 samples/sec	accuracy=0.961719
# Epoch[7] Batch [199]	Speed: 1189.288320 samples/sec	accuracy=0.960977
# Epoch[7] Batch [249]	Speed: 1181.106794 samples/sec	accuracy=0.961187
# Epoch[7] Batch [299]	Speed: 987.345172 samples/sec	accuracy=0.961380
# Epoch[7] Batch [349]	Speed: 970.798365 samples/sec	accuracy=0.962054
# [Epoch 7] training: accuracy=0.962996
# [Epoch 7] time cost: 46.526217
# [Epoch 7] validation: accuracy=0.911558
# Epoch[8] Batch [49]	Speed: 1170.699126 samples/sec	accuracy=0.963281
# Epoch[8] Batch [99]	Speed: 1054.710625 samples/sec	accuracy=0.960469
# Epoch[8] Batch [149]	Speed: 1034.680563 samples/sec	accuracy=0.960260
# Epoch[8] Batch [199]	Speed: 874.144837 samples/sec	accuracy=0.960703
# Epoch[8] Batch [249]	Speed: 1149.847961 samples/sec	accuracy=0.960969
# Epoch[8] Batch [299]	Speed: 1055.652168 samples/sec	accuracy=0.960547
# Epoch[8] Batch [349]	Speed: 1095.341968 samples/sec	accuracy=0.961429
# [Epoch 8] training: accuracy=0.962019
# [Epoch 8] time cost: 48.898592
# [Epoch 8] validation: accuracy=0.911959
# Epoch[9] Batch [49]	Speed: 941.488984 samples/sec	accuracy=0.965469
# Epoch[9] Batch [99]	Speed: 1173.829577 samples/sec	accuracy=0.961250
# Epoch[9] Batch [149]	Speed: 846.114913 samples/sec	accuracy=0.961198
# Epoch[9] Batch [199]	Speed: 1245.076849 samples/sec	accuracy=0.961016
# Epoch[9] Batch [249]	Speed: 1019.899300 samples/sec	accuracy=0.961719
# Epoch[9] Batch [299]	Speed: 1196.737742 samples/sec	accuracy=0.961823
# Epoch[9] Batch [349]	Speed: 1141.130122 samples/sec	accuracy=0.962768
# [Epoch 9] training: accuracy=0.963655
# [Epoch 9] time cost: 47.753119
# [Epoch 9] validation: accuracy=0.912059

# %% [markdown]
# The accuracy of the model with quantized $W_A$, $W_B$ should have a validation accuracy slighlty below that of the unquantized model.
#
# We finally save the paramters of the quantized model.

# %%
sp_resnet.collect_params().save('sp_resnet.params')

# %% [markdown]
# Done!

# %% [markdown]
# ### References
#
# [1] https://github.com/apache/incubator-mxnet/blob/master/docs/tutorials/gluon/customop.md
#
# [2] F. Li, B. Zhang, B. Liu, Ternary Weight Networks, 2016, https://arxiv.org/abs/1605.04711v2
#
# [3] K. He, X. Zhang, S. Ren, J. Sun, Deep Residual Learning for Image Recognition, 2016, http://arxiv.org/abs/1512.03385
#
# [4] https://github.com/apache/incubator-mxnet/blob/master/python/mxnet/gluon/model_zoo/vision/resnet.py
#
# [5] https://github.com/apache/incubator-mxnet/blob/master/example/gluon/image_classification.py
